# %% [markdown]
# ## 3.1. Distribuição espacial

# %% [markdown]
# <div style="text-align: justify"> Nesta seção, é apresentada a distribuição espacial dos pontos de monitoramento da qualidade do ar no Brasil e os status de operação. </div><br/>
#
# <div style="text-align: justify"> A Tabela 6 apresenta o número de estações de monitoramento reportadas pelos OEMAs nos anos de 2023 e 2024, bem como a variação no período. A Figura 23 apresenta um mapa interativo com a localização geográfica das estações de monitoramento no Brasil, onde as cores representam o status de operação (inativa em vermelho e ativa em verde). </div>
#
# ```{warning}
# Não foram obtidas as informações sobre status do monitoramento em 21 estações de monitoramento. Estas foram marcadas como “Não declarado”.
# ```

# %%
import scripts.flagTables as flagtab
flagtab.table06MMA()
# Out:
# <style type="text/css">
# #T_ecdb1 th {
#   text-align: center;
#   vertical-align: middle;
#   font-size: 8pt;
#   background-color: white;
#   color: black;
# }
# #T_ecdb1 td > img {
#   max-width: unset;
# }
# #T_ecdb1 th[colspan] {
#   border-bottom: 1px solid #ccc;
#   font-weight: bold;
#   text-transform: uppercase;
# }
# ...

# %% [markdown]
# <p style="text-align:center; color:#636D7D; font-size:15.5px;">
#   <em>Tabela 6 -</em>   Número total de estações de monitoramento da qualidade do ar no Brasil. Dados coletados no formulário aplicado pelo MMA.
# </p>

# %%
'''

import scripts.spatialFigures as spaFig
import importlib; importlib.reload(spaFig)
from matplotlib.colors import ListedColormap    
cmap = ListedColormap(["green", "red", 'gray']) 
spaFig.spatial_rede_monitoramento('Status',["ID_OEMA", "Status","Poluente","N° Poluentes Medidos",'Categoria','Funcionamento'],cmap)

'''

import scripts.spatialFigures as spaFig
import importlib; importlib.reload(spaFig)
from matplotlib.colors import ListedColormap 
tooltips = ["ID_OEMA", "STATUS", "POLUENTE", "N° Poluentes Medidos", "CATEGORIA", "OPERACAO"]
cmap = ListedColormap(["green", "red", 'gray']) 
m = spaFig.spatial_rede_monitoramento_new("STATUS", tooltips, cmap)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# <p style="text-align:center; color:#636D7D; font-size:15.5px;">
#   <em>Fig. 23</em> Distribuição espacial das estações de monitoramento da qualidade do ar no Brasil por status.
# </p>
