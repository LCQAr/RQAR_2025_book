# %% [markdown]
# ## 1.2. Origem dos dados
#
# <div style="text-align: justify">A Tabela 1 mostra a origem das informações sobre o monitoramento da qualidade do ar coletadas para a elaboração do presente relatório.</div><br/>
#
# <div style="text-align: justify">Apenas os estados do Piauí (PI), Sergipe (SE) e Goias (GO) alegaram não monitorar a qualidade do ar. Também não foram encontradas informações de monitoramento da qualidade do ar nesses estados a partir da busca na internet e na plataforma PurpleAir.</div><br/>

# %% [markdown]
# Tabela 1 – Origem das informações sobre o monitoramento da qualidade do ar pelos OEMAs.

# %%
import scripts.flagTables as flagtab
flagtab.table01()
# Out:
# <style type="text/css">
# #T_863c7 th {
#   text-align: center;
# }
# #T_863c7 td > img {
#   max-width: unset;
# }
# ...
