# %% [markdown]
# ## 3.1. Distribuição espacial

# %% [markdown]
# Nesta sessão, é apresentada a distribuição espacial dos pontos de monitoramento da qualidade do ar no Brasil e seus status de operação.
#
# A **Tabela 5** apresenta o número de estações de monitoramento da qualidade do ar reportadas pelos OEMAs nos anos de 2023 e 2024, bem como a variação no período.

# %% [markdown]
# <br>
#
# **Tabela 5 – Número total de estações de monitoramento da qualidade do ar no Brasil.Dados coletados no formulário aplicado pelo MMA.**

# %%
import scripts.flagTables as flagtab
flagtab.table06()
# Out:
# <style type="text/css">
# #T_cce64 th {
#   text-align: center;
# }
# #T_cce64 td > img {
#   max-width: unset;
# }
# ...

# %% [markdown]
# <br>
#
# A **Figura XXX** apresenta um mapa iterativo do posicionamento das estações de monitoramento no Brasil, onde as cores representam o status de operação (inativa em vermelho e ativa em verde).
#
# **Figura 1 - Distribuição espacial das estações de monitoramento da qualidade do ar no Brasil por status.**

# %%
import scripts.spatialFigures as spaFig
from matplotlib.colors import ListedColormap    
cmap = ListedColormap(["green", "red"]) 
spaFig.spatial_rede_monitoramento('Status',["ID_OEMA", "Status","Poluente","N° Poluentes Medidos",'Categoria','Funcionamento'],cmap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %% [markdown]
# <br>
# <br>
