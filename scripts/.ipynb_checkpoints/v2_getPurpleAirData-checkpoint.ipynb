# %% [markdown]
# #### Importar dados do PurpleAir

# %% [markdown]
# ##### 1. Página guia de como usar a API https://api.purpleair.com/#api-sensors-get-sensors-data
# ##### 2. Criar conta com e-mail Google https://develop.purpleair.com/dashboards/organization
# ##### 3. Criar API key para substituir no código e ter acesso às informaçôes

# %% [markdown]
# ##### Baixar dados API PurpleAir

# %%
import os, time, math, requests, pandas as pd
from datetime import datetime, timedelta, timezone

# %%
API_KEY = "CC7DC672-9555-11F0-BDE5-4201AC1DC121"  # put your PurpleAir Read key here
assert API_KEY and API_KEY != "YOUR_READ_KEY_HERE", "Add your PurpleAir API key"

# %%
BASE = "https://api.purpleair.com/v1"
HEADERS = {"X-API-Key": API_KEY}

# %%
# Brazil bounding box
BBOX = dict(
    nwlng = -73.990556,  # westmost
    nwlat =  5.271944,   # northmost
    selng = -34.792778,  # eastmost
    selat = -33.751944   # southmost
)

# %%
FIELDS = ",".join([
    "sensor_index","name","latitude","longitude", "voc","ozone1","pm1.0",
    "pm2.5","pm10.0","date_created", "last_seen","location_type", "private", "model", "altitude"
])

# %%
def fetch_sensors_in_bbox(fields, bbox, limit=1000, page=1):
    params = dict(fields=fields, **bbox, limit=limit, page=page)
    r = requests.get(f"{BASE}/sensors", headers=HEADERS, params=params, timeout=60)
    r.raise_for_status()
    return r.json()

# %%
resp = fetch_sensors_in_bbox(FIELDS, BBOX, limit=10000, page=1)

# %%
cols = resp.get("fields", [])
rows = resp.get("data", [])
df = pd.DataFrame(rows, columns=cols)

# %%
df
# Out:
#      sensor_index              date_created                 last_seen  \
# 0          262813 2025-01-30 23:16:47-03:00 2025-09-19 10:43:38-03:00
# 1          274372 2025-04-18 11:48:23-03:00 2025-09-19 10:43:22-03:00
# 2          275450 2025-04-24 17:36:19-03:00 2025-09-19 10:44:50-03:00
# 3          278965 2025-05-14 16:02:09-03:00 2025-09-19 10:43:18-03:00
# 4          280308 2025-05-22 14:09:47-03:00 2025-09-19 10:43:03-03:00
# ..            ...                       ...                       ...
# 283        246457 2024-10-07 13:11:10-03:00 2025-09-19 10:43:45-03:00
# 284        247259 2024-10-15 11:32:59-03:00 2025-09-18 15:20:04-03:00
# 285        251939 2024-11-20 18:14:32-03:00 2025-09-16 10:41:36-03:00
# 286        251937 2024-11-20 18:14:30-03:00 2025-09-19 10:43:13-03:00
# 287        260409 2025-01-21 23:36:39-03:00 2025-09-19 10:43:51-03:00
#
#      private                                             name  location_type  \
# 0          0                                        PELD-TANG              0
# 1          0                                             Casa              1
# 2          0                             Vielas da Água Preta              0
# 3          0                       DIAMANTINO QUALIDADE DO AR              0
# 4          0                                         El Monte              0
# ..       ...                                              ...            ...
# 283        0                   GEOHealth_CUS_CcapacmarcaOefa3              0
# 284        0                                        RIO401101              0
# 285        0                                  prueba aranjuez              0
# 286        0  Universidad Privada Boliviana, Campus Achocalla              0
# 287        0                                             UNIC              0
#
#           model                                           hardware   latitude  \
# 0      PA-II-SD  2.0+OPENLOG+31954 MB+DS3231+BME280+PMSX003-B+P... -13.062653
# 1     PA-II-ZEN  3.0+OPENLOG+NO-DISK+RV3028+BME68X+KX122+PMSX00... -33.359848
# 2     PA-II-ZEN  3.0+OPENLOG+NO-DISK+RV3028+BME68X+KX122+PMSX00... -23.536737
# 3     PA-II-ZEN  3.0+OPENLOG+NO-DISK+RV3028+BME68X+KX122+PMSX00... -14.399174
# 4         PA-II                     2.0+BME280+PMSX003-B+PMSX003-A -33.673256
# ..          ...                                                ...        ...
# 283  PA-II-FLEX  3.0+OPENLOG+62226 MB+RV3028+BME68X+PMSX003-A+P... -14.008719
# 284       PA-II                     2.0+BME280+PMSX003-B+PMSX003-A -22.911589
# 285  PA-II-FLEX  3.0+OPENLOG+7969 MB+RV3028+BME68X+PMSX003-A+PM... -16.555443
# 286  PA-II-FLEX  3.0+OPENLOG+31954 MB+RV3028+BME68X+PMSX003-A+P... -16.575330
# 287   PA-II-ZEN  3.0+OPENLOG+NO-DISK+RV3028+BME68X+KX122+PMSX00... -15.623796
#
#      longitude  altitude    voc ozone1  pm1.0  pm2.5  pm10.0
# 0   -52.380970      1190    NaN   None   21.0   31.2    33.5
# 1   -70.676420      1634   97.0   None   24.2   34.4    39.1
# 2   -46.692394      2435   58.0   None   19.9   26.3    29.4
# 3   -56.436085       950   87.0   None    8.4   10.1    10.9
# 4   -70.986206       962    NaN   None   14.3   19.9    20.5
# ..         ...       ...    ...    ...    ...    ...     ...
# 283 -72.001175     11774  118.0   None    7.6    9.6    10.8
# 284 -43.756820         2    NaN   None    1.9    3.8     5.1
# 285 -68.106530     10956   50.0   None    0.1    0.3     0.4
# 286 -68.126945     11548   97.0   None    9.1   13.3    14.2
# 287 -56.086617       514   63.0   None   17.7   22.4    23.7
#
# [288 rows x 16 columns]

# %% [markdown]
# ##### Filtrar apenas latitudes e longitudes dentro do polígno do Brasil

# %%
def df_brazil_only(df, lat_col="latitude", lon_col="longitude", drop_coords=True):
    gdf = gpd.GeoDataFrame(
        df,
        geometry=gpd.points_from_xy(df[lon_col], df[lat_col]),
        crs="EPSG:4326"
    )
    # alterar colunas de datas para datetime 
    df["date_created"] = pd.to_datetime(df["date_created"], unit="s", utc=True)
    df["date_created"]  = df["date_created"].dt.tz_convert("America/Sao_Paulo")
    df["last_seen"] = pd.to_datetime(df["last_seen"], unit="s", utc=True)
    df["last_seen"]  = df["last_seen"].dt.tz_convert("America/Sao_Paulo")
    
    # polígono do país para extrair contornos
    url = "https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_countries.zip"
    world = gpd.read_file(url)
    brazil_poly = world.loc[world["SOVEREIGNT"] == "Brazil", "geometry"].iloc[0]

    # cria mask para manter somente lat e long dentro do contorno
    mask = gdf.within(brazil_poly)
    gdf = gdf[mask].copy()
    
    return gdf

# %%
df_br = df_brazil_only(df)   # df_br contém somente as linhas lat e long dentro do Brasil
print("Shape sensores PurpleAir no Brasil: " +str(df_br.shape))
df_br.head()
# Out:
# Shape sensores PurpleAir no Brasil: (176, 17)
#     sensor_index              date_created                 last_seen  private  \
# 0         262813 2025-01-30 23:16:47-03:00 2025-09-19 10:43:38-03:00        0
# 2         275450 2025-04-24 17:36:19-03:00 2025-09-19 10:44:50-03:00        0
# 3         278965 2025-05-14 16:02:09-03:00 2025-09-19 10:43:18-03:00        0
# 21         25541 2019-01-22 22:03:48-02:00 2025-09-19 10:43:48-03:00        0
# 22         25551 2019-01-22 22:04:35-02:00 2025-09-19 10:43:44-03:00        0
#
#                               name  location_type      model  \
# 0                        PELD-TANG              0   PA-II-SD
# 2             Vielas da Água Preta              0  PA-II-ZEN
# 3       DIAMANTINO QUALIDADE DO AR              0  PA-II-ZEN
# 21  MPAC_PTA_01_Sec.infraestrutura              0   PA-II-SD
# 22          MPAC_FIJ_01_promotoria              0   PA-II-SD
#
#                                              hardware   latitude  longitude  \
# 0   2.0+OPENLOG+31954 MB+DS3231+BME280+PMSX003-B+P... -13.062653 -52.380970
# 2   3.0+OPENLOG+NO-DISK+RV3028+BME68X+KX122+PMSX00... -23.536737 -46.692394
# 3   3.0+OPENLOG+NO-DISK+RV3028+BME68X+KX122+PMSX00... -14.399174 -56.436085
# 21     2.0+OPENLOG+NO-DISK+BME280+PMSX003-B+PMSX003-A  -9.727080 -67.698020
# 22  2.0+OPENLOG+NO-DISK+DS3231+BME280+PMSX003-B+PM...  -8.170079 -70.355030
#
#     altitude   voc ozone1  pm1.0  pm2.5  pm10.0                     geometry
# 0       1190   NaN   None   21.0   31.2    33.5  POINT (-52.38097 -13.06265)
# 2       2435  58.0   None   19.9   26.3    29.4  POINT (-46.69239 -23.53674)
# 3        950  87.0   None    8.4   10.1    10.9  POINT (-56.43608 -14.39917)
# 21       677   NaN   None    4.7    6.5     6.9   POINT (-67.69802 -9.72708)
# 22       525   NaN   None    2.9    4.1     4.2   POINT (-70.35503 -8.17008)

# %%
df_br['start_year'] = df_br['date_created'].dt.year
df_br['end_year'] = df_br['last_seen'].dt.year

def get_years_in_range(row): # extrair todos os anos de medição de cada sensor
    return list(range(row['start_year'], row['end_year'] + 1))

df_br['years_in_range'] = df_br.apply(get_years_in_range, axis=1)

def years_to_list(v):
    if isinstance(v, (list, tuple, set)):
        return ",".join(str(x) for x in v)              
    return v                                            

df_br["years_in_range"] = df_br["years_in_range"].apply(years_to_list)

# %%
import numpy as np

# %%
cols = ["voc", "ozone1", "pm1.0", "pm2.5", "pm10.0"]  
labels = {"voc":"VOC", "pm1.0":"PM1", "pm2.5":"PM25", "pm10.0":"PM10", "ozone1":"OZONE"}

def get_pollutants(df_br, cols, labels):
    df_br["pollutants_all"] = df_br[cols].apply(
    lambda r: ",".join(labels[c] for c in cols if r[c] is not None) or pd.NA,
    axis=1
    )

    return df_br

# %%
df_br = get_pollutants(df_br, cols, labels)
df_br.head()
# Out:
#     sensor_index              date_created                 last_seen  private  \
# 0         262813 2025-01-30 23:16:47-03:00 2025-09-19 10:43:38-03:00        0
# 2         275450 2025-04-24 17:36:19-03:00 2025-09-19 10:44:50-03:00        0
# 3         278965 2025-05-14 16:02:09-03:00 2025-09-19 10:43:18-03:00        0
# 21         25541 2019-01-22 22:03:48-02:00 2025-09-19 10:43:48-03:00        0
# 22         25551 2019-01-22 22:04:35-02:00 2025-09-19 10:43:44-03:00        0
#
#                               name  location_type      model  \
# 0                        PELD-TANG              0   PA-II-SD
# 2             Vielas da Água Preta              0  PA-II-ZEN
# 3       DIAMANTINO QUALIDADE DO AR              0  PA-II-ZEN
# 21  MPAC_PTA_01_Sec.infraestrutura              0   PA-II-SD
# 22          MPAC_FIJ_01_promotoria              0   PA-II-SD
#
#                                              hardware   latitude  longitude  \
# 0   2.0+OPENLOG+31954 MB+DS3231+BME280+PMSX003-B+P... -13.062653 -52.380970
# 2   3.0+OPENLOG+NO-DISK+RV3028+BME68X+KX122+PMSX00... -23.536737 -46.692394
# 3   3.0+OPENLOG+NO-DISK+RV3028+BME68X+KX122+PMSX00... -14.399174 -56.436085
# 21     2.0+OPENLOG+NO-DISK+BME280+PMSX003-B+PMSX003-A  -9.727080 -67.698020
# 22  2.0+OPENLOG+NO-DISK+DS3231+BME280+PMSX003-B+PM...  -8.170079 -70.355030
#
#     ...   voc  ozone1 pm1.0  pm2.5  pm10.0                     geometry  \
# 0   ...   NaN    None  21.0   31.2    33.5  POINT (-52.38097 -13.06265)
# 2   ...  58.0    None  19.9   26.3    29.4  POINT (-46.69239 -23.53674)
# 3   ...  87.0    None   8.4   10.1    10.9  POINT (-56.43608 -14.39917)
# 21  ...   NaN    None   4.7    6.5     6.9   POINT (-67.69802 -9.72708)
# 22  ...   NaN    None   2.9    4.1     4.2   POINT (-70.35503 -8.17008)
#
#    start_year  end_year                      years_in_range     pollutants_all
# 0        2025      2025                                2025  VOC,PM1,PM25,PM10
# 2        2025      2025                                2025  VOC,PM1,PM25,PM10
# 3        2025      2025                                2025  VOC,PM1,PM25,PM10
# 21       2019      2025  2019,2020,2021,2022,2023,2024,2025  VOC,PM1,PM25,PM10
# 22       2019      2025  2019,2020,2021,2022,2023,2024,2025  VOC,PM1,PM25,PM10
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### Extrair nome da cidade e estado baseado na latitude e longitude

# %%
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderServiceError
from geopy.extra.rate_limiter import RateLimiter

# %%
geolocator = Nominatim(user_agent="bixtech-airquality", timeout=10)
reverse = RateLimiter(geolocator.reverse, min_delay_seconds=1.1, max_retries=2, error_wait_seconds=2)

# %%
def get_city_name(latitude, longitude):
    try:
        location = geolocator.reverse((latitude, longitude), exactly_one=True)
        if location and location.address:
            address_parts = location.raw.get('address', {})
            return address_parts.get('city')
        return None
    except (GeocoderTimedOut, GeocoderServiceError) as e:
        print(f"Error geocoding {latitude}, {longitude}: {e}")
        return None

# %%
def get_uf_name(latitude, longitude):
    try:
        location = geolocator.reverse((latitude, longitude), exactly_one=True)
        if location and location.address:
            address_parts = location.raw.get('address', {})
            return address_parts.get('state')
        return None
    except (GeocoderTimedOut, GeocoderServiceError) as e:
        print(f"Error geocoding {latitude}, {longitude}: {e}")
        return None

# %%
df_br['CIDADE'] = df_br.apply(lambda row: get_city_name(row['latitude'], row['longitude']), axis=1)
df_br['UF'] = df_br.apply(lambda row: get_uf_name(row['latitude'], row['longitude']), axis=1)

# %%
df_br.head()
# Out:
#     sensor_index              date_created                 last_seen  private  \
# 0         262813 2025-01-30 23:16:47-03:00 2025-09-19 10:43:38-03:00        0
# 2         275450 2025-04-24 17:36:19-03:00 2025-09-19 10:44:50-03:00        0
# 3         278965 2025-05-14 16:02:09-03:00 2025-09-19 10:43:18-03:00        0
# 21         25541 2019-01-22 22:03:48-02:00 2025-09-19 10:43:48-03:00        0
# 22         25551 2019-01-22 22:04:35-02:00 2025-09-19 10:43:44-03:00        0
#
#                               name  location_type      model  \
# 0                        PELD-TANG              0   PA-II-SD
# 2             Vielas da Água Preta              0  PA-II-ZEN
# 3       DIAMANTINO QUALIDADE DO AR              0  PA-II-ZEN
# 21  MPAC_PTA_01_Sec.infraestrutura              0   PA-II-SD
# 22          MPAC_FIJ_01_promotoria              0   PA-II-SD
#
#                                              hardware   latitude  longitude  \
# 0   2.0+OPENLOG+31954 MB+DS3231+BME280+PMSX003-B+P... -13.062653 -52.380970
# 2   3.0+OPENLOG+NO-DISK+RV3028+BME68X+KX122+PMSX00... -23.536737 -46.692394
# 3   3.0+OPENLOG+NO-DISK+RV3028+BME68X+KX122+PMSX00... -14.399174 -56.436085
# 21     2.0+OPENLOG+NO-DISK+BME280+PMSX003-B+PMSX003-A  -9.727080 -67.698020
# 22  2.0+OPENLOG+NO-DISK+DS3231+BME280+PMSX003-B+PM...  -8.170079 -70.355030
#
#     ...  pm1.0  pm2.5 pm10.0                     geometry  start_year  \
# 0   ...   21.0   31.2   33.5  POINT (-52.38097 -13.06265)        2025
# 2   ...   19.9   26.3   29.4  POINT (-46.69239 -23.53674)        2025
# 3   ...    8.4   10.1   10.9  POINT (-56.43608 -14.39917)        2025
# 21  ...    4.7    6.5    6.9   POINT (-67.69802 -9.72708)        2019
# 22  ...    2.9    4.1    4.2   POINT (-70.35503 -8.17008)        2019
#
#     end_year                      years_in_range     pollutants_all  \
# 0       2025                                2025  VOC,PM1,PM25,PM10
# 2       2025                                2025  VOC,PM1,PM25,PM10
# 3       2025                                2025  VOC,PM1,PM25,PM10
# 21      2025  2019,2020,2021,2022,2023,2024,2025  VOC,PM1,PM25,PM10
# 22      2025  2019,2020,2021,2022,2023,2024,2025  VOC,PM1,PM25,PM10
#
#        CIDADE           UF
# 0        None  Mato Grosso
# 2   São Paulo    São Paulo
# 3        None  Mato Grosso
# 21       None         Acre
# 22       None         Acre
#
# [5 rows x 23 columns]

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
import folium

m = folium.Map(location=[-14.235, -51.925], zoom_start=4)

for lat, lon in zip(df_br["latitude"], df_br["longitude"]):
    if pd.notna(lat) and pd.notna(lon):
        folium.CircleMarker(location=[lat, lon], radius=3).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19644c484856d68107e39336378ad6fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19644c484856d68107e39336378ad6fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19644c484856d68107e39336378ad6fc = L.map(
#                 &quot;map_19644c484856d68107e39336378ad6fc&quot;,
#                 {
#                     center: [-14.235, -51.925],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_97810cd78b28ad378a7af93dae199a4d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_97810cd78b28ad378a7af93dae199a4d.addTo(map_19644c484856d68107e39336378ad6fc);
#
#
#             var circle_marker_a90806b8abbeae822f5a13601b22bdd2 = L.circleMarker(
#                 [-13.062653, -52.38097],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19644c484856d68107e39336378ad6fc);
#
#
#             var circle_marker_46a660f0027d49641f3a8219212b2c69 = L.circleMarker(
#                 [-23.536737, -46.692394],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19644c484856d68107e39336378ad6fc);
#
#
#             var circle_marker_7da7679abaf9444833ac7cef843f7164 = L.circleMarker(
#                 [-14.399174, -56.436085],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19644c484856d68107e39336378ad6fc);
#
#
#             var circle_marker_eca4870c0a680d2652023aca48545db5 = L.circleMarker(
#                 [-9.72708, -67.69802],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19644c484856d68107e39336378ad6fc);
#
#
#             var circle_marker_c7e727efbcad7f981f9e35e28e1ff60e = L.circleMarker(
#                 [-8.170079, -70.35503],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19644c484856d68107e39336378ad6fc);
#
#
#             var circle_marker_2165f31a9c476cce69e8cfb30f16861a = L.circleMarker(
#                 [-9.829177, -67.95388],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quo

# %% [markdown]
# ##### Transformar dataframe conforme colunas do Monitoramento_QAr_BR

# %%
campos = ["UF","CIDADE","CD_MUN","ID_OEMA","ID_MMA","ID_MMA_COMPLETO","PROPRIETARIO",
          "PROP_ENTIDADE","OPERADOR","OP_ENTIDADE","FUNCIONAMENTO","CATEGORIA","METODO",
          "CALIBRACAO","MARCA","MODELO","POLUENTE","COD_POLUENTE","MOBILIDADE","REP_ESPACIAL",
          "FINALIDADE","STATUS","INICIO","FIM","LATITUDE","LONGITUDE","MONITORAR","FONTE",
          "CERTIFICACAO","COD_UF_IBGE","ANOS_MONITORADOS","BASE_DADOS","ELEVACAO"]

# %%
df_purple = pd.DataFrame(columns=campos)

# %%
manual_map = {
    "latitude":  "LATITUDE",
    "longitude": "LONGITUDE",
    "name": "ID_OEMA",
    "private": "PROP_ENTIDADE",
    "model": "MODELO",
    "years_in_range": "ANOS_MONITORADOS",
    "pollutants_all": "POLUENTE",
    "date_created": "INICIO",
    "last_seen": "FIM",
    "altitude": "ELEVACAO"
}

df_br = df_br.rename(columns=manual_map)

# %%
df_purple = df_purple.reindex(index=df_br.index)  
common = [c for c in campos if c in df_br.columns]
df_purple.loc[:, common] = df_br[common].values
df_purple.head()
# Out:
#              UF     CIDADE CD_MUN                         ID_OEMA ID_MMA  \
# 0   Mato Grosso       None    NaN                       PELD-TANG    NaN
# 2     São Paulo  São Paulo    NaN            Vielas da Água Preta    NaN
# 3   Mato Grosso       None    NaN      DIAMANTINO QUALIDADE DO AR    NaN
# 21         Acre       None    NaN  MPAC_PTA_01_Sec.infraestrutura    NaN
# 22         Acre       None    NaN          MPAC_FIJ_01_promotoria    NaN
#
#    ID_MMA_COMPLETO PROPRIETARIO PROP_ENTIDADE OPERADOR OP_ENTIDADE  ...  \
# 0              NaN          NaN             0      NaN         NaN  ...
# 2              NaN          NaN             0      NaN         NaN  ...
# 3              NaN          NaN             0      NaN         NaN  ...
# 21             NaN          NaN             0      NaN         NaN  ...
# 22             NaN          NaN             0      NaN         NaN  ...
#
#                           FIM   LATITUDE  LONGITUDE MONITORAR FONTE  \
# 0   2025-09-19 10:43:38-03:00 -13.062653  -52.38097       NaN   NaN
# 2   2025-09-19 10:44:50-03:00 -23.536737 -46.692394       NaN   NaN
# 3   2025-09-19 10:43:18-03:00 -14.399174 -56.436085       NaN   NaN
# 21  2025-09-19 10:43:48-03:00   -9.72708  -67.69802       NaN   NaN
# 22  2025-09-19 10:43:44-03:00  -8.170079  -70.35503       NaN   NaN
#
#    CERTIFICACAO COD_UF_IBGE                    ANOS_MONITORADOS BASE_DADOS  \
# 0           NaN         NaN                                2025        NaN
# 2           NaN         NaN                                2025        NaN
# 3           NaN         NaN                                2025        NaN
# 21          NaN         NaN  2019,2020,2021,2022,2023,2024,2025        NaN
# 22          NaN         NaN  2019,2020,2021,2022,2023,2024,2025        NaN
#
#    ELEVACAO
# 0      1190
# 2      2435
# 3       950
# 21      677
# 22      525
#
# [5 rows x 33 columns]

# %%
defaults = {
    "FUNCIONAMENTO": "Automatica",
    "CATEGORIA":     "Indicativa",
    "MARCA":         "PurpleAir",
    "FONTE":         "PurpleAir 2025",
}

df_purple = df_purple.fillna(value=defaults)

# %%
map_prop = {
    0: "Publico", 1: "Privada",
    False: "Publico", True: "Privado",
    "0": "Publico", "1": "Privado",
}

df_purple["PROP_ENTIDADE"] = df_purple["PROP_ENTIDADE"].replace(map_prop)
df_purple["PROP_ENTIDADE"] = df_purple["PROP_ENTIDADE"].astype("string")

# %%
import unicodedata

# %%
def _key(s):
    if pd.isna(s):
        return None
    s = str(s).strip()
    s = unicodedata.normalize("NFKD", s).encode("ASCII","ignore").decode("ASCII")
    return s.lower()

# %%
# mapa: nome da UF -> sigla
_name_to_sigla = {
    "acre":"AC","alagoas":"AL","amapa":"AP","amazonas":"AM","bahia":"BA","ceara":"CE",
    "distrito federal":"DF","espirito santo":"ES","goias":"GO","maranhao":"MA",
    "mato grosso":"MT","mato grosso do sul":"MS","minas gerais":"MG","para":"PA",
    "paraiba":"PB","parana":"PR","pernambuco":"PE","piaui":"PI","rio de janeiro":"RJ",
    "rio grande do norte":"RN","rio grande do sul":"RS","rondonia":"RO","roraima":"RR",
    "santa catarina":"SC","sao paulo":"SP","sergipe":"SE","tocantins":"TO"
}

# também aceitar quando a coluna já vier com a sigla
for sig in list(_name_to_sigla.values()):
    _name_to_sigla[sig.lower()] = sig

# códigos IBGE por sigla
_sigla_to_ibge = {
    "AC":"12","AL":"27","AP":"16","AM":"13","BA":"29","CE":"23","DF":"53","ES":"32",
    "GO":"52","MA":"21","MT":"51","MS":"50","MG":"31","PA":"15","PB":"25","PR":"41",
    "PE":"26","PI":"22","RN":"24","RS":"43","RJ":"33","RO":"11","RR":"14","SC":"42",
    "SP":"35","SE":"28","TO":"17"
}

# %%
# substituir nome por sigla na coluna UF
df_purple["UF"] = df_purple["UF"].apply(lambda x: _name_to_sigla.get(_key(x), pd.NA))

# preencher COD_UF_IBGE a partir da sigla
df_purple["COD_UF_IBGE"] = df_purple["UF"].map(_sigla_to_ibge)

# dtypes opcionais
df_purple["UF"] = df_purple["UF"].astype("string")
df_purple["COD_UF_IBGE"] = df_purple["COD_UF_IBGE"].astype("string")

# %%
df_purple.head()
# Out:
#     UF     CIDADE CD_MUN                         ID_OEMA ID_MMA  \
# 0   MT       None    NaN                       PELD-TANG    NaN
# 2   SP  São Paulo    NaN            Vielas da Água Preta    NaN
# 3   MT       None    NaN      DIAMANTINO QUALIDADE DO AR    NaN
# 21  AC       None    NaN  MPAC_PTA_01_Sec.infraestrutura    NaN
# 22  AC       None    NaN          MPAC_FIJ_01_promotoria    NaN
#
#    ID_MMA_COMPLETO PROPRIETARIO PROP_ENTIDADE OPERADOR OP_ENTIDADE  ...  \
# 0              NaN          NaN       Publico      NaN         NaN  ...
# 2              NaN          NaN       Publico      NaN         NaN  ...
# 3              NaN          NaN       Publico      NaN         NaN  ...
# 21             NaN          NaN       Publico      NaN         NaN  ...
# 22             NaN          NaN       Publico      NaN         NaN  ...
#
#                           FIM   LATITUDE  LONGITUDE MONITORAR           FONTE  \
# 0   2025-09-19 10:43:38-03:00 -13.062653  -52.38097       NaN  PurpleAir 2025
# 2   2025-09-19 10:44:50-03:00 -23.536737 -46.692394       NaN  PurpleAir 2025
# 3   2025-09-19 10:43:18-03:00 -14.399174 -56.436085       NaN  PurpleAir 2025
# 21  2025-09-19 10:43:48-03:00   -9.72708  -67.69802       NaN  PurpleAir 2025
# 22  2025-09-19 10:43:44-03:00  -8.170079  -70.35503       NaN  PurpleAir 2025
#
#    CERTIFICACAO COD_UF_IBGE                    ANOS_MONITORADOS BASE_DADOS  \
# 0           NaN          51                                2025        NaN
# 2           NaN          35                                2025        NaN
# 3           NaN          51                                2025        NaN
# 21          NaN          12  2019,2020,2021,2022,2023,2024,2025        NaN
# 22          NaN          12  2019,2020,2021,2022,2023,2024,2025        NaN
#
#    ELEVACAO
# 0      1190
# 2      2435
# 3       950
# 21      677
# 22      525
#
# [5 rows x 33 columns]

# %%
df_purple.groupby(["UF"]).count()
# Out:
#     CIDADE  CD_MUN  ID_OEMA  ID_MMA  ID_MMA_COMPLETO  PROPRIETARIO  \
# UF
# AC       5       0       15       0                0             0
# AM      19       0       65       0                0             0
# AP       2       0        6       0                0             0
# BA       1       0        1       0                0             0
# CE       1       0        1       0                0             0
# DF       3       0        5       0                0             0
# MS       1       0        2       0                0             0
# MT       6       0       19       0                0             0
# PA      18       0       23       0                0             0
# PR       7       0       14       0                0             0
# RJ       1       0        1       0                0             0
# RO       2       0        6       0                0             0
# RR       1       0        3       0                0             0
# SP       9       0       11       0                0             0
# TO       1       0        3       0                0             0
#
#     PROP_ENTIDADE  OPERADOR  OP_ENTIDADE  FUNCIONAMENTO  ...  FIM  LATITUDE  \
# UF                                                       ...
# AC             15         0            0             15  ...   15        15
# AM             65         0            0             65  ...   65        65
# AP              6         0            0              6  ...    6         6
# BA              1         0            0              1  ...    1         1
# CE              1         0            0              1  ...    1         1
# DF              5         0            0              5  ...    5         5
# MS              2         0            0              2  ...    2         2
# MT             19         0            0             19  ...   19        19
# PA             23         0            0             23  ...   23        23
# PR             14         0            0             14  ...   14        14
# RJ              1         0            0              1  ...    1         1
# RO              6         0            0              6  ...    6         6
# RR              3         0            0              3  ...    3         3
# SP             11         0            0             11  ...   11        11
# TO              3         0            0              3  ...    3         3
#
#     LONGITUDE  MONITORAR  FONTE  CERTIFICACAO  COD_UF_IBGE  ANOS_MONITORADOS  \
# UF
# AC         15          0     15             0           15                15
# AM         65          0     65             0           65                65
# AP          6          0      6             0            6                 6
# BA          1          0      1             0            1                 1
# CE          1          0      1             0            1                 1
# DF          5          0      5             0            5                 5
# MS          2          0      2             0            2                 2
# MT         19          0     19             0           19                19
# PA         23          0     23             0           23                23
# PR         14          0     14             0           14                14
# RJ          1          0      1             0            1                 1
# RO          6          0      6             0            6                 6
# RR          3          0      3             0            3                 3
# SP         11          0     11             0           11                11
# TO          3          0      3             0            3                 3
#
#     BASE_DADOS  ELEVACAO
# UF
# AC           0        15
# AM           0        65
# AP           0         6
# BA           0         1
# CE           0         1
# DF           0         5
# MS           0         2
# MT           0        19
# PA           0        23
# PR           0        14
# RJ           0         1
# RO           0         6
# RR           0         3
# SP           0        11
# TO           0         3
#
# [15 rows x 32 columns]

# %%
# from pathlib import Path

# base = Path.cwd().parent  # .../RQAR_2025_book
# out_dir = base / "data" / "DADOS_ESTACOES"
# out_dir.mkdir(parents=True, exist_ok=True)

# out_file = out_dir / "Compiled_PurpleAirStations.csv"
# df_purple.to_csv(out_file, index=False, encoding="utf-8")
# print("Saved to:", out_file.resolve())
# Out:
# Saved to: /home/nobre/Notebooks/RQAR_2025_book/data/DADOS_ESTACOES/Compiled_PurpleAirStations.csv

# %% [markdown]
# ##### Salvar um arquivo .csv por estado com os dados coletados via API PurpleAir

# %%
base = Path.cwd().parent  # .../RQAR_2025_book
out_dir = base / "data" / "DADOS_ESTACOES" / "UFs_indicativas"
out_dir.mkdir(parents=True, exist_ok=True)

def save_ufs_files(df_purple, uf_col="UF", base=base, out_dir=out_dir):
    dfx = df_purple.copy()

    for uf, sub in dfx.groupby(uf_col, dropna=False):
        #safe_uf = "".join(ch if ch.isalnum() or ch in (" ", "-", "_") else "_" for ch in str(uf))
        name_template=f"{uf}_indicativas.csv"
        fname = name_template.format(uf)
        sub.to_csv(out_dir / fname, index=False)

save_ufs_files(df_purple, uf_col="UF", base=base, out_dir=out_dir)

# %% [markdown]
# #### Comparar dados das UFs com base de dados PurpleAir

# %%
base = Path.cwd().parent  
out_dir = base / "data" 
out_dir.mkdir(parents=True, exist_ok=True)

df_mma = pd.read_csv(out_dir / "Monitoramento_QAr_BR.csv")
df_mma.columns
# Out:
# Index(['UF', 'CIDADE', 'CD_MUN', 'ID_OEMA', 'ID_MMA', 'ID_MMA_COMPLETO',
#        'PROPRIETARIO', 'PROP_ENTIDADE', 'OPERADOR', 'OP_ENTIDADE',
#        'FUNCIONAMENTO', 'CATEGORIA', 'METODO', 'CALIBRACAO', 'MARCA', 'MODELO',
#        'POLUENTE', 'COD_POLUENTE', 'MOBILIDADE', 'REP_ESPACIAL', 'FINALIDADE',
#        'STATUS', 'INICIO', 'FIM', 'LATITUDE', 'LONGITUDE', 'MONITORAR',
#        'FONTE', 'CERTIFICACAO', 'COD_UF_IBGE', 'ANOS_MONITORADOS',
#        'BASE_DADOS', 'ELEVACAO'],
#       dtype='object')

# %%
id_col = "ID_OEMA"

def norm(s: pd.Series) -> pd.Series:
    return s.astype("string").str.strip().str.upper()

# normalized ID columns
mma_id = norm(df_mma[id_col])
pur_id = norm(df_purple[id_col])

# IDs present in both dataframes
common_ids = pd.Index(mma_id.dropna()).intersection(pur_id.dropna())
print("IDs present in both:", len(common_ids))

# rows involved on each side
mma_overlap = df_mma[mma_id.isin(common_ids)]
pur_overlap = df_purple[pur_id.isin(common_ids)]
print("Rows in df_mma with overlapping ID_OEMA:", len(mma_overlap))
print("Rows in df_purple_exp with overlapping ID_OEMA:", len(pur_overlap))

# summary count per ID showing how many times it appears in each df
both = pd.concat(
    [
        pd.DataFrame({id_col: mma_id, "_src": "mma"}),
        pd.DataFrame({id_col: pur_id, "_src": "purple"}),
    ],
    ignore_index=True,
)
summary = (
    both.dropna(subset=[id_col])
        .groupby([id_col, "_src"]).size()
        .unstack(fill_value=0)
        .query("mma > 0 and purple > 0")
        .sort_index()
)
print("Overlapping unique IDs:", summary.shape[0])
# Out:
# IDs present in both: 44
# Rows in df_mma with overlapping ID_OEMA: 71
# Rows in df_purple_exp with overlapping ID_OEMA: 45
# Overlapping unique IDs: 44

# %% [markdown]
# ##### Overlap de mapas - Coordenadas MMA e PurpleAir

# %%
def add_points(df, lat_col="latitude", lon_col="longitude", color="blue", name="Layer"):
    fg = folium.FeatureGroup(name=name, show=True)
    for lat, lon in zip(df[lat_col], df[lon_col]):
        if pd.notna(lat) and pd.notna(lon):
            folium.CircleMarker(
                location=[lat, lon],
                radius=3,
                color=color,
                fill=True,
                fill_opacity=0.8,
                opacity=0.8
            ).add_to(fg)
    fg.add_to(m)

# Plot your two dataframes
add_points(df_purple,  lat_col="LATITUDE", lon_col="LONGITUDE", color="blue",  name="PurpleAir")
add_points(df_mma, lat_col="LATITUDE", lon_col="LONGITUDE", color="red",   name="MMA")

# Layer control to toggle visibility
folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19644c484856d68107e39336378ad6fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19644c484856d68107e39336378ad6fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19644c484856d68107e39336378ad6fc = L.map(
#                 &quot;map_19644c484856d68107e39336378ad6fc&quot;,
#                 {
#                     center: [-14.235, -51.925],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_97810cd78b28ad378a7af93dae199a4d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_97810cd78b28ad378a7af93dae199a4d.addTo(map_19644c484856d68107e39336378ad6fc);
#
#
#             var circle_marker_a90806b8abbeae822f5a13601b22bdd2 = L.circleMarker(
#                 [-13.062653, -52.38097],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19644c484856d68107e39336378ad6fc);
#
#
#             var circle_marker_46a660f0027d49641f3a8219212b2c69 = L.circleMarker(
#                 [-23.536737, -46.692394],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19644c484856d68107e39336378ad6fc);
#
#
#             var circle_marker_7da7679abaf9444833ac7cef843f7164 = L.circleMarker(
#                 [-14.399174, -56.436085],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19644c484856d68107e39336378ad6fc);
#
#
#             var circle_marker_eca4870c0a680d2652023aca48545db5 = L.circleMarker(
#                 [-9.72708, -67.69802],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19644c484856d68107e39336378ad6fc);
#
#
#             var circle_marker_c7e727efbcad7f981f9e35e28e1ff60e = L.circleMarker(
#                 [-8.170079, -70.35503],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19644c484856d68107e39336378ad6fc);
#
#
#             var circle_marker_2165f31a9c476cce69e8cfb30f16861a = L.circleMarker(
#                 [-9.829177, -67.95388],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quo

# %%
def plot_purple_mma_map(df_purple, df_mma, lat_col="LATITUDE", lon_col="LONGITUDE", uf_col="UF",
                    buffer_m=100, draw_buffers=False):
    # Clean coords
    df_purple  = df_purple.dropna(subset=[lat_col, lon_col]).copy()
    df_mma = df_mma.dropna(subset=[lat_col, lon_col]).copy()

    # GeoDataFrames in WGS84
    gdf_purple = gpd.GeoDataFrame(
        df_purple,
        geometry=gpd.points_from_xy(df_purple[lon_col], df_purple[lat_col]),
        crs="EPSG:4326"
    )
    gdf_mma = gpd.GeoDataFrame(
        df_mma,
        geometry=gpd.points_from_xy(df_mma[lon_col], df_mma[lat_col]),
        crs="EPSG:4326"
    )

    # Project to meters for accurate buffers
    gdf_purple_m  = gdf_purple.to_crs("EPSG:5880")
    gdf_mma_m = gdf_mma.to_crs("EPSG:5880")

    # Build buffers
    br_buf  = gdf_purple_m.copy()
    br_buf["geometry"] = br_buf.geometry.buffer(buffer_m)
    mma_buf = gdf_mma_m.copy()
    mma_buf["geometry"] = mma_buf.geometry.buffer(buffer_m)

    # Cross matches only
    match_br  = gpd.sjoin(br_buf[["geometry"]],  gdf_mma_m[["geometry"]], predicate="contains", how="inner")
    match_mma = gpd.sjoin(mma_buf[["geometry"]], gdf_purple_m[["geometry"]],  predicate="contains", how="inner")

    overlap_br_idx  = match_br.index.unique()
    overlap_mma_idx = match_mma.index.unique()

    gdf_purple_m["overlap_cross"]  = gdf_purple_m.index.isin(overlap_br_idx)
    gdf_mma_m["overlap_cross"] = gdf_mma_m.index.isin(overlap_mma_idx)

    # Back to lat lon for map
    gdf_purple_ll  = gdf_purple_m.to_crs("EPSG:4326")
    gdf_mma_ll = gdf_mma_m.to_crs("EPSG:4326")

    # Map
    m = folium.Map(location=[-14.235, -51.925], zoom_start=4, tiles="CartoDB positron")

    # Optionally draw buffer outlines
    if draw_buffers:
        for _, r in gdf_purple_ll.iterrows():
            folium.Circle(
                location=[r.geometry.y, r.geometry.x],
                radius=buffer_m,
                color="red",
                fill=False,
                opacity=0.3
            ).add_to(m)
        for _, r in gdf_mma_ll.iterrows():
            folium.Circle(
                location=[r.geometry.y, r.geometry.x],
                radius=buffer_m,
                color="blue",
                fill=False,
                opacity=0.3
            ).add_to(m)

    # Points: blue for BR, red for MMA, yellow if cross overlap
    for _, r in gdf_purple_ll.iterrows():
        lat, lon = r.geometry.y, r.geometry.x
        folium.CircleMarker(
            [lat, lon],
            radius=4,
            color="yellow" if r["overlap_cross"] else "blue",
            fill=True, fill_opacity=0.9, opacity=0.9,
            popup=f"br | {lat:.6f}, {lon:.6f}"
        ).add_to(m)

    for _, r in gdf_mma_ll.iterrows():
        lat, lon = r.geometry.y, r.geometry.x
        folium.CircleMarker(
            [lat, lon],
            radius=4,
            color="yellow" if r["overlap_cross"] else "red",
            fill=True, fill_opacity=0.9, opacity=0.9,
            popup=f"mma | {lat:.6f}, {lon:.6f}"
        ).add_to(m)

    folium.LayerControl(collapsed=False).add_to(m)

    # Table of yellow points
    yellow_br  = gdf_purple_ll.loc[gdf_purple_ll["overlap_cross"], ["geometry", "UF", "ID_OEMA"]].copy()
    yellow_mma  = gdf_purple_ll.loc[gdf_purple_ll["overlap_cross"], ["geometry", "UF", "ID_OEMA"]].copy()    
    
    yellow_br  = yellow_br.assign(
        source="br",
        latitude=yellow_br.geometry.y,
        longitude=yellow_br.geometry.x,
        uf="UF",
        oema="ID_OEMA"
    )[["source","latitude","longitude","UF"]]
    
    yellow_mma = yellow_mma.assign(
        source="mma",
        latitude=yellow_mma.geometry.y,
        longitude=yellow_mma.geometry.x,
        uf="UF",
        oema="ID_OEMA"
    )[["source","latitude","longitude","UF","ID_OEMA"]]
    
    frames = [f for f in (yellow_br, yellow_mma) if not f.empty]
    yellow = pd.concat(frames, ignore_index=True) if frames else pd.DataFrame(
        columns=["source","latitude","longitude","UF","ID_OEMA"]
    )

    # 1) Join BR buffers to MMA points -> all MMA points within 100 m of each BR point
    br_buf_i = br_buf[["geometry"]].reset_index().rename(columns={"index": "br_idx"})
    mma_pts  = gdf_mma_m.copy()
    mma_pts["mma_idx"] = mma_pts.index
    
    pairs_m = gpd.sjoin(
        br_buf_i, 
        mma_pts[["geometry", "mma_idx", *(["UF"] if "UF" in mma_pts.columns else []), *(["ID_OEMA"] if "ID_OEMA" in mma_pts.columns else [])]],
        predicate="contains",
        how="inner"
    )
    
    # 2) Keep only pair keys once
    pairs_keys = pairs_m[["br_idx", "mma_idx"]].drop_duplicates()
    
    # 3) Build lookup tables with attributes and lat/lon
    br_ll = gdf_purple_ll.copy()
    br_ll["br_idx"] = br_ll.index
    br_info = br_ll.assign(
        br_lat=br_ll.geometry.y,
        br_lon=br_ll.geometry.x,
        br_UF = br_ll["UF"] if "UF" in br_ll.columns else pd.NA,
        br_ID_OEMA = br_ll["ID_OEMA"] if "ID_OEMA" in br_ll.columns else pd.NA
    )[["br_idx","br_UF","br_ID_OEMA","br_lat","br_lon"]]
    
    mma_ll = gdf_mma_ll.copy()
    mma_ll["mma_idx"] = mma_ll.index
    mma_info = mma_ll.assign(
        mma_lat=mma_ll.geometry.y,
        mma_lon=mma_ll.geometry.x,
        mma_UF = mma_ll["UF"] if "UF" in mma_ll.columns else pd.NA,
        mma_ID_OEMA = mma_ll["ID_OEMA"] if "ID_OEMA" in mma_ll.columns else pd.NA
    )[["mma_idx","mma_UF","mma_ID_OEMA","mma_lat","mma_lon"]]
    
    # 4) Final pairs table
    pairs = pairs_keys.merge(br_info, on="br_idx", how="left").merge(mma_info, on="mma_idx", how="left")
    
    # Optional: distance in meters
    br_geom_m  = gdf_purple_m.geometry
    mma_geom_m = gdf_mma_m.geometry
    pairs["distance_m"] = pairs.apply(lambda r: br_geom_m[r.br_idx].distance(mma_geom_m[r.mma_idx]), axis=1).round(2)
    
    #print(pairs.head())

    return m, pairs

m, pairs = plot_purple_mma_map(df_purple, df_mma, draw_buffers=True)  
print(pairs)
# Out:
#     br_idx  mma_idx br_UF                      br_ID_OEMA     br_lat  \
# 0       21       12    AC  MPAC_PTA_01_Sec.infraestrutura  -9.727080
# 1       22       28    AC          MPAC_FIJ_01_promotoria  -8.170079
# 2       23        1    AC          MPAC_BJR_01_promotoria  -9.829177
# 3       24       21    AC          MPAC_BRL_01_promotoria -11.010512
# 4       25        5    AC                MPAC_TRC_02_ifac  -8.143146
# ..     ...      ...   ...                             ...        ...
# 83     273      760    MT                    SEMA-MT SEDE -15.570751
# 84     273      764    MT                    SEMA-MT SEDE -15.570751
# 85     273      763    MT                    SEMA-MT SEDE -15.570751
# 86     273      762    MT                    SEMA-MT SEDE -15.570751
# 87     273      761    MT                    SEMA-MT SEDE -15.570751
#
#        br_lon mma_UF                     mma_ID_OEMA   mma_lat   mma_lon  \
# 0  -67.698020     AC  MPAC_PTA_01_Sec.infraestrutura  -9.72710 -67.69800
# 1  -70.355030     AC          MPAC_FIJ_01_promotoria  -8.17000 -70.35490
# 2  -67.953880     AC          MPAC_BJR_01_promotoria  -9.82920 -67.95390
# 3  -68.742280     AC          MPAC_BRL_01_promotoria -11.01050 -68.74230
# 4  -70.770905     AC                MPAC_TRC_02_ifac  -8.14310 -70.77090
# ..        ...    ...                             ...       ...       ...
# 83 -56.074400     MT                CPA - SEMA - CBA -15.57004 -56.07392
# 84 -56.074400     MT                CPA - SEMA - CBA -15.57004 -56.07392
# 85 -56.074400     MT                CPA - SEMA - CBA -15.57004 -56.07392
# 86 -56.074400     MT                CPA - SEMA - CBA -15.57004 -56.07392
# 87 -56.074400     MT                CPA - SEMA - CBA -15.57004 -56.07392
#
#     distance_m
# 0         3.16
# 1        16.97
# 2         3.42
# 3         2.58
# 4         5.33
# ..         ...
# 83       94.06
# 84       94.06
# 85       94.06
# 86       94.06
# 87       94.06
#
# [88 rows x 11 columns]

# %%
pairs.groupby(["br_UF"]).count()
# Out:
#        br_idx  mma_idx  br_ID_OEMA  br_lat  br_lon  mma_UF  mma_ID_OEMA  \
# br_UF
# AC         12       12          12      12      12      12           12
# AM         48       48          48      48      48      48           48
# AP          1        1           1       1       1       1            1
# MT          7        7           7       7       7       7            7
# PA          2        2           2       2       2       2            2
# SP         18       18          18      18      18      18           18
#
#        mma_lat  mma_lon  distance_m
# br_UF
# AC          12       12          12
# AM          48       48          48
# AP           1        1           1
# MT           7        7           7
# PA           2        2           2
# SP          18       18          18

# %%
pairs.groupby("br_UF")["br_lat"].nunique()
# Out:
# br_UF
# AC    12
# AM    23
# AP     1
# MT     1
# PA     2
# SP     2
# Name: br_lat, dtype: int64

# %%
# base = Path.cwd().parent  # .../RQAR_2025_book
# out_dir = base / "data" / "DADOS_ESTACOES"
# out_dir.mkdir(parents=True, exist_ok=True)

# out_file = out_dir / "ParesIndicativas.csv"
# pairs.to_csv(out_file, index=False, encoding="utf-8")
# print("Saved to:", out_file.resolve())
# Out:
# Saved to: /home/nobre/Notebooks/RQAR_2025_book/data/DADOS_ESTACOES/ParesIndicativas.csv

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b75fc88538578b13c1343580b45d71f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b75fc88538578b13c1343580b45d71f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b75fc88538578b13c1343580b45d71f = L.map(
#                 &quot;map_2b75fc88538578b13c1343580b45d71f&quot;,
#                 {
#                     center: [-14.235, -51.925],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_795ec7eed4e5be6b434f2249447ba976 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_795ec7eed4e5be6b434f2249447ba976.addTo(map_2b75fc88538578b13c1343580b45d71f);
#
#
#             var circle_4cc07ed2f9cc51f76f0152fe82a39ba7 = L.circle(
#                 [-13.062653, -52.38097],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.3, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2b75fc88538578b13c1343580b45d71f);
#
#
#             var circle_e5ee278c069dbe157348e6c14d14b1d0 = L.circle(
#                 [-23.536737000000002, -46.692394],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.3, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2b75fc88538578b13c1343580b45d71f);
#
#
#             var circle_8739b21467c5d8e26150f303c5133dcb = L.circle(
#                 [-14.39917399999999, -56.43608499999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.3, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2b75fc88538578b13c1343580b45d71f);
#
#
#             var circle_d91d19f1e548533091974081deff7f28 = L.circle(
#                 [-9.727080000000003, -67.69802],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.3, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2b75fc88538578b13c1343580b45d71f);
#
#
#             var circle_5c40d4e7980d190a9b340e428d395954 = L.circle(
#                 [-8.170079000000001, -70.35503],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.3, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2b75fc88538578b13c1343580b45d71f);
#
#
#             var circle_eecb2d630b3ca67a2ea6370fbbd4967d = L.circle(
#                 [-9.829177, -67.95388],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;rou

# %% [markdown]
# ##### Criar novo dataframe único com informações do MMA e PurpleAir

# %%
# Garantir que os pares são únicos 
pairs_u = (pairs.drop_duplicates(subset=["br_lat"]))
pairs_u.count()
# Out:
# br_idx         41
# mma_idx        41
# br_UF          41
# br_ID_OEMA     41
# br_lat         41
# br_lon         41
# mma_UF         41
# mma_ID_OEMA    41
# mma_lat        41
# mma_lon        41
# distance_m     41
# dtype: int64

# %%
def unify_purple_mma(df_purple, df_mma, pairs_u):

    # ordem de colunas: df_purple primeiro, depois extras de df_mma
    out_cols = list(df_purple.columns) + [c for c in df_mma.columns if c not in df_purple.columns]

    # manter apenas índices que existem nos DFs atuais
    pairs_u = pairs_u[pairs_u["br_idx"].isin(df_purple.index) & pairs_u["mma_idx"].isin(df_mma.index)].copy()

    br_matched  = set(pairs_u["br_idx"])
    mma_matched = set(pairs_u["mma_idx"])

    # construir a linha mesclada de cada par: usa BR, senão MMA (não sobrescreve se ambos têm)
    merged_rows = []
    for _, pr in pairs_u.iterrows():
        br_row  = df_purple.loc[pr.br_idx]
        mma_row = df_mma.loc[pr.mma_idx]
        merged  = br_row.combine_first(mma_row)  # preenche só quando BR está NA
        merged  = merged.reindex(out_cols)
        merged["RECONHECIDA"] = "Sim"
        merged_rows.append(merged)

    merged_pairs_df = pd.DataFrame(merged_rows, columns=out_cols + ["RECONHECIDA"])

    # linhas sem par (dos dois lados), mantidas como estão
    br_un  = df_purple.loc[~df_purple.index.isin(br_matched)].reindex(columns=out_cols)
    br_un["RECONHECIDA"] = "Não"

    mma_un = df_mma.loc[~df_mma.index.isin(mma_matched)].reindex(columns=out_cols)
    mma_un["RECONHECIDA"] = ""

    # resultado final, mantendo a ordem de colunas
    df_final = pd.concat([merged_pairs_df, br_un, mma_un], ignore_index=True)
    
    return df_final[out_cols + ["RECONHECIDA"]]

# %%
merged_dfs = unify_purple_mma(df_purple, df_mma, pairs_u)
merged_dfs
# Out:
# /tmp/ipykernel_490652/3385200911.py:32: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_final = pd.concat([merged_pairs_df, br_un, mma_un], ignore_index=True)
#       UF                 CIDADE   CD_MUN                            ID_OEMA  \
# 0     AC             Porto Acre  1200807     MPAC_PTA_01_Sec.infraestrutura
# 1     AC                  Feijó  1200302             MPAC_FIJ_01_promotoria
# 2     AC                 Bujari  1200138             MPAC_BJR_01_promotoria
# 3     AC              Brasiléia  1200104             MPAC_BRL_01_promotoria
# 4     AC               Tarauacá  1200609                   MPAC_TRC_02_ifac
# ...   ..                    ...      ...                                ...
# 2375  SP              São Paulo  3550308                            Tatuapé
# 2376  SP              São Paulo  3550308                        Ibirapuera
# 2377  SP              São Paulo  3550308                     Campos Elíseos
# 2378  SP              São Paulo  3550308                     Campos Elíseos
# 2379  SP  São Bernardo do Campo  3548708  São Bernardo do Campo - Paulicéia
#
#       ID_MMA ID_MMA_COMPLETO PROPRIETARIO PROP_ENTIDADE OPERADOR OP_ENTIDADE  \
# 0        NaN             NaN          NaN       Publico      NaN         NaN
# 1        NaN             NaN          NaN       Publico      NaN         NaN
# 2     AC0009      AC0009A002          NaN       Publico      NaN         NaN
# 3        NaN             NaN          NaN       Publico      NaN         NaN
# 4        NaN             NaN          NaN       Publico      NaN         NaN
# ...      ...             ...          ...           ...      ...         ...
# 2375     NaN             NaN       CETESB           NaN      NaN         NaN
# 2376     NaN             NaN       CETESB           NaN      NaN         NaN
# 2377     NaN             NaN       CETESB           NaN      NaN         NaN
# 2378     NaN             NaN       CETESB           NaN      NaN         NaN
# 2379     NaN             NaN       CETESB           NaN      NaN         NaN
#
#       ...   LATITUDE  LONGITUDE MONITORAR            FONTE     CERTIFICACAO  \
# 0     ...   -9.72708  -67.69802       NaN   PurpleAir 2025  Não Certificada
# 1     ...  -8.170079  -70.35503       NaN   PurpleAir 2025  Não Certificada
# 2     ...  -9.829177  -67.95388       NaN   PurpleAir 2025  Não Certificada
# 3     ... -11.010512  -68.74228       NaN   PurpleAir 2025  Não Certificada
# 4     ...  -8.143146 -70.770905       NaN   PurpleAir 2025  Não Certificada
# ...   ...        ...        ...       ...              ...              ...
# 2375  ...  -23.53646  -46.57198       NaN  Coleta Interna       Certificada
# 2376  ...  -23.59184  -46.66069       NaN  Coleta Interna       Certificada
# 2377  ...  -23.53319   -46.6446       NaN  Coleta Interna       Certificada
# 2378  ...  -23.53319   -46.6446       NaN  Coleta Interna       Certificada
# 2379  ...  -23.67135  -46.58467       NaN  Coleta Interna       Certificada
#
#      COD_UF_IBGE                            ANOS_MONITORADOS  BASE_DADOS  \
# 0             12  [2019, 2020, 2021, 2022, 2023, 2024, 2025]       False
# 1             12  [2019, 2020, 2021, 2022, 2023, 2024, 2025]       False
# 2             12  [2019, 2020, 2021, 2022, 2023, 2024, 2025]       False
# 3             12  [2019, 2020, 2021, 2022, 2023, 2024, 2025]       False
# 4             12  [2019, 2020, 2021, 2022, 2023, 2024, 2025]       False
# ...          ...                                         ...         ...
# 2375          35                                         NaN       False
# 2376          35                                         NaN       False
# 2377          35                                         NaN       False
# 2378          35                                         NaN       False
# 2379          35                                         NaN       False
#
#      ELEVACAO RECONHECIDA
# 0         677         Sim
# 1         525         Sim
# 2         696         Sim
# 3         636         Sim
# 4         613         Sim
# ...       ...         ...
# 2375      755
# 2376      755
# 2377      752
# 2378      752
# 2379      756
#
# [2380 rows x 34 columns]

# %%
def explode_pollutants(df_purple, col="POLUENTE"):
    out = df_purple.copy()

    # turn "VOC,PM1, PM25 ,PM10" into ["VOC","PM1","PM25","PM10"]
    out[col] = (
        out[col]
        .astype("string")
        .fillna("")
        .apply(lambda s: [p.strip() for p in s.split(",") if p.strip()])
    )

    # explode to one row per pollutant
    out = out.explode(col, ignore_index=True)

    return out.reset_index(drop=True)

df_merged_exp = explode_pollutants(merged_dfs)

# %%
# base = Path.cwd().parent  # .../RQAR_2025_book
# out_dir = base / "data" / "DADOS_ESTACOES"
# out_dir.mkdir(parents=True, exist_ok=True)

# out_file = out_dir / "NEW_Monitoramento_QAr_BR.csv"
# df_merged_exp.to_csv(out_file, index=False, encoding="utf-8")
# print("Saved to:", out_file.resolve())
# Out:
# Saved to: /home/nobre/Notebooks/RQAR_2025_book/data/DADOS_ESTACOES/NEW_Monitoramento_QAr_BR.csv

# %% [markdown]
# #### Importar série histórica de dados

# %%
from dateutil import tz

# %%
def month_ranges_2024():
    return [(datetime(2024,m,1,tzinfo=timezone.utc),
             datetime(2024,m+1,1,tzinfo=timezone.utc) if m<12 else datetime(2025,1,1,tzinfo=timezone.utc))
            for m in range(1,13)]

history_fields = "pm2.5_atm"  
AVERAGE_MIN = 60

hist_frames = []
for sid in df_br["sensor_index"].head(20):  # raise gradually
    for start, end in month_ranges_2024():
        try:
            h = fetch_sensor_history(int(sid), history_fields, start, end, average=AVERAGE_MIN)
            rows, cols = h.get("data", []), h.get("fields", [])
            if not rows:
                continue
            hdf = pd.DataFrame(rows, columns=cols)
            hdf["sensor_index"] = int(sid)
            hist_frames.append(hdf)
            time.sleep(0.4)
        except requests.HTTPError as e:
            print(f"Sensor {sid} {start:%Y-%m} skipped:", e.response.text)
            time.sleep(0.6)

hist = pd.concat(hist_frames, ignore_index=True) if hist_frames else pd.DataFrame()
print(hist.shape)
# Out:
# (113334, 3)

# %%
def fetch_sensor_history(sensor_index, fields, start, end, average=10):
    params = {
        "fields": fields,
        "start_timestamp": int(start.timestamp()),
        "end_timestamp": int(end.timestamp()),
        "average": average
    }
    url = f"{BASE}/sensors/{sensor_index}/history"
    r = requests.get(url, headers=HEADERS, params=params, timeout=60)
    r.raise_for_status()
    return r.json()

# %%
import pandas as pd

# %%
history_fields = "pm2.5_atm"  # no time_stamp here
AVERAGE_MIN = 60  # hourly averages

def month_ranges_2024():
    return [(datetime(2024, m, 1, tzinfo=timezone.utc),
             datetime(2024, m+1, 1, tzinfo=timezone.utc) if m < 12 else datetime(2025, 1, 1, tzinfo=timezone.utc))
            for m in range(1, 13)]

hist_frames = []
for sid in df["sensor_index"].head(3):
    for start, end in month_ranges_2024():
        try:
            h = fetch_sensor_history(int(sid), history_fields, start, end, average=AVERAGE_MIN)
            cols = h.get("fields", [])
            rows = h.get("data", [])
            if not rows:
                continue
            hdf = pd.DataFrame(rows, columns=cols)
            # The response already includes a timestamp column (often named time_stamp)
            hdf["sensor_index"] = int(sid)  # add ID yourself
            hist_frames.append(hdf)
            time.sleep(0.4)
        except requests.HTTPError as e:
            print(f"Sensor {sid} {start:%Y-%m} skipped:", getattr(e, "response", None).text if getattr(e, "response", None) else e)
            time.sleep(0.6)

# %%
hist = pd.concat(hist_frames, ignore_index=True) if hist_frames else pd.DataFrame()
print(hist)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
