# %% [markdown]
# # Teste MT

# %%
import pandas as pd
import os
from collections import defaultdict
from datetime import datetime, timedelta
import re
import numpy as np
from pathlib import Path


os.chdir('/home/nobre/Notebooks/RQAR_2025_book/')

# %%
tabela_ids = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/Monitoramento_QAr_BR.csv')
tabela_pols = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/dicionarios/CODIGO_POLUENTES.csv')

# %%
funcoes = {
    
    'MT': rectify_MT,
}

lista_estados = ['MT']

tabela_ids = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/Monitoramento_QAr_BR.csv')
tabela_pols = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/dicionarios/CODIGO_POLUENTES.csv')

# %%
estado = 'DF'
  
path = os.getcwd()+'/data/DADOS_BRUTOS/' + estado + '/'

#df_ids = funcoes[estado](path)
    
#create_df_estacao(estado,df_ids)

# %%
dict_pols_stat = defaultdict(list)

files = os.listdir(path)

print(files)

for item in files:
    
    estacao = " ".join(item.split('-')[1].split('.')[0].split('_')[0:2])

    print(estacao)

    df = pd.read_excel(path+item)

    df = df.drop(columns=['Nome da estação'])

    lista_pols = set(df['Poluente'])

    for pol in lista_pols:

        df_pol = df[df["Poluente"] == pol]
        
        if pol in ['no2','so2','o3']:

            df_pol = ppb_to_ug(df_pol,pol)

        df_pol_hora = df_pol.groupby(["Ano", "Mes", "Dia", "Hora", "Unidade"])
        
        df_pol_hora = df_pol_hora.filter(lambda g: len(g) >= 9)
        
        df_pol = (
            df_pol_hora.groupby(["Ano", "Mes", "Dia", "Hora", "Unidade"], as_index=False)
                  .agg({"Valor": "mean"})
        )

        df_pol['QAQC_INTERNO'] = None

        df_pol = df_pol.rename(columns={'Ano':'ANO',
                                        'Mes':'MES',
                                        'Dia':'DIA',
                                        'Hora':'HORA',
                                        'Unidade':'UNIDADE',
                                        'Valor':'VALOR'})

        for col in ["ANO", "MES", "DIA", "HORA"]:
            df_pol[col] = pd.to_numeric(df_pol[col], errors="coerce").astype("Int64")
        
        dict_pols_stat[estacao+'_'+pol].append(df_pol)

# %%
def ppb_to_ug(df,pol):

    if pol == 'so2':

        df.loc[df["Unidade"] != "ug/m3", "Valor"] *= 2661260.49/10**6        

    elif pol == 'no2':

        df.loc[df["Unidade"] != "ug/m3", "Valor"] *= 1911038.92/10**6        

    elif pol == 'o3':

        df.loc[df["Unidade"] != "ug/m3", "Valor"] *= 1993889.17/10**6        
    
    df.loc[:, "Unidade"] = "ug/m3"

    return df

# %%
dict_pols_MT = {
    'co':'CO',
    'no2': 'NO2',
    'so2': 'SO2',
    'o3': 'O3',
    'pm2p5':'MP25',
    'pm10': 'MP10'
}

dict_formatado = {}

for chave in dict_pols_stat.keys():
    
    lista_dfs = dict_pols_stat[chave]
    
    df = pd.concat(lista_dfs, ignore_index=True)

    df["DATETIME"] = pd.to_datetime(
        df.apply(lambda r: f"{r.ANO}-{r.MES}-{r.DIA} {r.HORA}:00:00", axis=1)
    )
    df = df.set_index("DATETIME")

    df = df.sort_index()
    
    lista_horas = pd.date_range(
        start=df.index.min(), 
        end=df.index.max(), 
        freq='H').strftime('%Y-%m-%d %H:%M:%S').tolist()
    
    if len(lista_horas) != len(df):
        df = df.reindex(pd.DatetimeIndex(lista_horas))

    df['DATETIME'] = df.index

    df = df[['DATETIME','ANO','MES','DIA','HORA','VALOR','UNIDADE','QAQC_INTERNO']]
    
    dict_formatado[chave] = df

primeiros_valores = {}

for chave, df in dict_formatado.items():
    
    if ~df['VALOR'].isna().all() and (df['VALOR'] > 0).any(): 
        
        linha_valida = df[df["VALOR"].notna() & (df["VALOR"] > 0)].iloc[0]
        primeiros_valores[chave] = linha_valida["DATETIME"]

codigo_estacao_MT = {}

for chave in primeiros_valores.keys():
    
    station = chave.split('_')[0]
    data = primeiros_valores[chave]
    
    if station in codigo_estacao_MT:
        if data <= codigo_estacao_MT[station]:
            codigo_estacao_MT[station] = data
    else:
        codigo_estacao_MT[station] = data

sorted_items = sorted(
    codigo_estacao_MT.items(),
    key=lambda x: (x[1], x[0])
)

codigo_estacao_MT = {}
for i, (nome, ts) in enumerate(sorted_items, start=1):
    codigo = f"MT{i:04d}"
    codigo_estacao_MT[nome] = codigo
    
for chave, df in dict_formatado.items():
    
    estacao = codigo_estacao_MT[chave.split('_')[0]]
    
    cod_pol = tabela_pols.loc[tabela_pols['POLUENTE'] == dict_pols_MT[chave.split('_')[-1]], 'COD_POLUENTE'].values[0]
    
    nome_pasta = tabela_pols.loc[tabela_pols['COD_POLUENTE'] == int(cod_pol), 'NOME_PASTA'].values[0]
    
    df.to_csv('/home/nobre/Notebooks/RQAR_2025_book/data/MQAr/'+nome_pasta+'/'+estacao+'RA'+str(cod_pol).zfill(3)+'.csv',index=False)

df_ids = pd.DataFrame({
    'ID_OEMA': codigo_estacao_MT.keys(),
    'ID_MMA':list(codigo_estacao_MT.values())})

return df_ids

# %%
df_ids

# %%
from datetime import timedelta

def fix_24h(row):
    if isinstance(row, str) and row.startswith("24:"):
        # substitui 24: por 00:
        new_str = row.replace("24:", "00:", 1)
        # converte para datetime
        dt = pd.to_datetime(new_str, errors="coerce")
        # adiciona 1 dia
        if pd.notna(dt):
            dt += timedelta(days=1)
        return dt
    else:
        return pd.to_datetime(row, errors="coerce")

# %%
dict_stations_MT = {
        'Sema':'CPA - SEMA - CBA',
        'BEA CBA': 'Dom Aquino - BEA - CBA',
        'CBM VG': 'Água Limpa - CBM - VG',
        'Mae Bonifacia': 'Duque de Caxias - Pq Mãe Bonifácia - CBA',
        'UFMT':'Boa Esperança - UFMT - CBA'
    }
    
df_ids = pd.DataFrame({
    'ID_OEMA': codigo_estacao_MT.keys(),
    'ID_MMA':list(codigo_estacao_MT.values())})


df_ids["ID_OEMA"] = df_ids["ID_OEMA"].replace(dict_stations_MT)


df_ids['ID_OEMA']

# %%
df_ids

# %%
estado = 'DF'

# %%
path = os.getcwd()+'/data/DADOS_BRUTOS/' + estado + '/'

path = path + 'Monitor Report 2024_FINAL.xlsx'

df = pd.read_excel(path)

df.iloc[1] = df.iloc[1].ffill()

poluentes = ['CO_ppm','NO2_ug/m3','NO_ug/m3','NOx_ug/m3','O3_ug/m3','PM10','PM25','PTS','SO2_ug/m3']

dict_pols = {'CO_ppm':'CO',
             'NO2_ug/m3':'NO2',
             'NO_ug/m3':'NO',
             'NOx_ug/m3':'NOX',
             'O3_ug/m3':'O3',
             'PM10':'MP10',
             'PM25':'MP25',
             'PTS':'PTS',
             'SO2_ug/m3':'SO2'}

df.columns = df.iloc[1]

df = df.drop(index=[0, 1]).reset_index(drop=True)

df = df.rename(columns={'Date Time':'DATETIME'})

estacoes = set(df.columns[1:])

dict_pols_stat = defaultdict(list)

for estacao in estacoes:

    df_estacao = df[["DATETIME",estacao]]

    df_estacao.columns = [df_estacao.columns.tolist()[0]] + df_estacao.iloc[0, 1:].tolist()

    df_estacao = df_estacao.drop(index=[0]).reset_index(drop=True)

    for pol in poluentes:

        if pol in df_estacao.columns:
            
            df_pol = df_estacao[["DATETIME",pol]]

            df_pol['UNIDADE'] = df_pol[pol][0]

            df_pol = df_pol.drop(index=[0]).reset_index(drop=True)

            df_pol = df_pol[df_pol["DATETIME"].astype(str).str.contains(r"\d", na=False)].reset_index(drop=True)

            df_pol['DATETIME'] = df_pol['DATETIME'].apply(fix_24h)

            df_pol = df_pol.rename(columns={pol:'VALOR'})

            df_pol.index = df_pol['DATETIME']

            lista_horas = pd.date_range(
                start=df_pol.index.min(), 
                end=df_pol.index.max(), 
                freq='H').strftime('%Y-%m-%d %H:%M:%S').tolist()
            
            if len(lista_horas) != len(df_pol):
                df_pol = df_pol.reindex(pd.DatetimeIndex(lista_horas))
            
            df_pol['QAQC_INTERNO'] = None
            
            df_pol.insert(1, 'ANO', df_pol.index.year)
            df_pol.insert(2, 'MES', df_pol.index.month)
            df_pol.insert(3, 'DIA', df_pol.index.day)
            df_pol.insert(4, 'HORA', df_pol.index.hour)

            pol = dict_pols[pol]

            df_pol['VALOR'] = pd.to_numeric(df_pol['VALOR'], errors='coerce')

            df_pol = df_pol[['DATETIME','ANO','MES','DIA','HORA','VALOR','UNIDADE','QAQC_INTERNO']] 

            dict_pols_stat[estacao+'_'+pol] = df_pol

# %%
primeiros_valores = {}

for chave, df in dict_pols_stat.items():  
    
    if ~df['VALOR'].isna().all() and (df['VALOR'] > 0).any(): 
        
        linha_valida = df[df["VALOR"].notna() & (df["VALOR"] > 0)].iloc[0]
        primeiros_valores[chave] = linha_valida["DATETIME"]

codigo_estacao_DF = {}

for chave in primeiros_valores.keys():
    
    station = chave.split('_')[0]
    data = primeiros_valores[chave]
    
    if station in codigo_estacao_DF:
        if data <= codigo_estacao_DF[station]:
            codigo_estacao_DF[station] = data
    else:
        codigo_estacao_DF[station] = data

sorted_items = sorted(
    codigo_estacao_DF.items(),
    key=lambda x: (x[1], x[0])
)

codigo_estacao_DF = {}
for i, (nome, ts) in enumerate(sorted_items, start=1):
    codigo = f"DF{i:04d}"
    codigo_estacao_DF[nome] = codigo
    
for chave, df in dict_pols_stat.items():
    
    estacao = codigo_estacao_DF[chave.split('_')[0]]
    
    cod_pol = tabela_pols.loc[tabela_pols['POLUENTE'] == chave.split('_')[-1], 'COD_POLUENTE'].values[0]
    
    nome_pasta = tabela_pols.loc[tabela_pols['COD_POLUENTE'] == int(cod_pol), 'NOME_PASTA'].values[0]
    
    df.to_csv('/home/nobre/Notebooks/RQAR_2025_book/data/MQAr/'+nome_pasta+'/'+estacao+'RA'+str(cod_pol).zfill(3)+'.csv',index=False)

dict_oemas = {
    'Estação CRAS FERCAL': 'Fercal CRAS',
    'Estação Escola':	   'Fercal Escola'}

df_ids = pd.DataFrame({
    'ID_OEMA': codigo_estacao_DF.keys(),
    'ID_MMA':list(codigo_estacao_DF.values())})

df_ids['ID_OEMA'] = df_ids['ID_OEMA'].replace(dict_oema)

return df_ids

# %%
df_ufs = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/dicionarios/IBGE_UFS_CODIGOS.csv')
    
cod_uf =  df_ufs.loc[df_ufs['UF'] == uf, 'CODIGOS'].values[0]

print(cod_uf)

if os.path.exists('/home/nobre/Notebooks/RQAR_2025_book/data/DADOS_ESTACOES/'+uf+'_estacoes.csv'):

    df_estacao = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/DADOS_ESTACOES/'+uf+'_estacoes.csv')

    df_estacao['ID_MMA'] = df_estacao['ID_OEMA'].map(df_ids.set_index('ID_OEMA')['ID_MMA'])

else:

    colunas = ['ID_OEMA', 'UF', 'ID_MMA', 'COD_UF_IBGE', 'CIDADE', 'CD_MUN',
               'PROPRIETARIO', 'PROP_ENTIDADE', 'OPERADOR', 'OP_ENTIDADE', 'LATITUDE',
               'LONGITUDE', 'MOBILIDADE', 'REALOCACAO', 'MARCA', 'CATEGORIA',
               'FUNCIONAMENTO', 'METODO', 'FINALIDADE', 'POLUENTE',
               'INICIO', 'STATUS', 'FIM', 'CALIBRACAO', 'OBS_CALIBRACAO', 'MONITORAR',
               'FONTE', 'OBS_GERAIS','DADOS_MONITORAMENTO','RECONHECIDA','REP_ESPACIAL_DECLARADA']
    
    df_estacao = pd.DataFrame(columns=colunas)

df_ids = pol_to_station(df_ids)

mapa = dict(zip(df_ids['ID_MMA'], df_ids['POLUENTE']))

df_estacao['POLUENTE'] = df_estacao['ID_MMA'].map(mapa).fillna(df_estacao['POLUENTE'])

#df_estacao = df_estacao.reindex(df_ids.index)

#df_estacao[["ID_MMA", "ID_OEMA", "POLUENTE"]] = df_ids[["ID_MMA", "ID_OEMA", "POLUENTE"]].values

df_estacao.loc[:, "COD_UF_IBGE"] = cod_uf
df_estacao.loc[:, "UF"] = uf
    
#df_estacao.to_csv('/home/nobre/Notebooks/RQAR_2025_book/data/DADOS_ESTACOES/'+uf+'_estacoes_teste.csv', index=False)

# %%
df_estacao['POLUENTE']

# %%
def pol_to_station(df_ids):

    base_path = Path('/home/nobre/Notebooks/RQAR_2025_book/data/MQAr/')

    id_to_poluentes = {}
    
    for poluente_dir in base_path.iterdir():
        if poluente_dir.is_dir():
            poluente = poluente_dir.name
    
            arquivos = [arq.stem for arq in poluente_dir.glob("*")]
    
            for id_mma in df_ids["ID_MMA"]:
                if any(str(arq).startswith(id_mma) for arq in arquivos):
                    id_to_poluentes.setdefault(id_mma, []).append(poluente)
    
    df_ids["POLUENTE"] = df_ids["ID_MMA"].map(id_to_poluentes).fillna("").apply(lambda x: ",".join(x) if isinstance(x, list) else "")
    
    return(df_ids)

# %% [markdown]
# # Paraná

# %%
df = pd.read_csv(os.getcwd()+'/data/DADOS_BRUTOS/PR/2017/FOZ2017/2017.xls', sep='\t', engine='python', encoding='latin1', header=2 )

df

# %%
caminho = os.getcwd()+'/data/DADOS_BRUTOS/PR/2024/'
    
arquivo = 'CIC2024.xls'

if arquivo.endswith(('.xls', '.xlsx')):
    caminho_arquivo = os.path.join(caminho, arquivo)
    try:
        df = pd.read_excel(caminho_arquivo, header=3)
    except Exception as e:
        print(f"Tentando ler como texto: {arquivo}")
        df = pd.read_csv(caminho_arquivo, sep='\t', engine='python', encoding='latin1', header=2)
        print(len(df))
        
    col_data = next(c for c in df.columns if c.startswith('Data'))

    df = (
    df.replace('-', np.nan)
      .assign(**{
          c: pd.to_numeric(
              df[c].astype(str).str.replace(',', '.', regex=False),
              errors='coerce'
          )
          for c in df.columns if c != col_data
      })
      .groupby(col_data, as_index=False)
      .agg(lambda x: x.dropna().iloc[0] if len(x.dropna()) else np.nan)
    )
    
    if '5MIN' in arquivo:
        estacao = arquivo.split('_')[0]
    else:
        estacao = arquivo.split('2')[0]
    
    if df.columns[0] == 'Data/Hora':

        print(estacao)

# %%
print(len(df1))
print(len(df2))

# %%
def ler_dados_parana_2024(dicionario,ano):
    
    #caminho =  os.getcwd()+'/data/DADOS_BRUTOS/PR/2024/'

    caminho = os.getcwd()+'/data/DADOS_BRUTOS/PR/'+ano+'/'
    
    arquivos = os.listdir(caminho)
    
    for arquivo in arquivos:
    
        if arquivo.endswith(('.xls', '.xlsx')):
            caminho_arquivo = os.path.join(caminho, arquivo)
            try:
                df = pd.read_excel(caminho_arquivo, header=3)
            except Exception as e:
                print(f"Tentando ler como texto: {arquivo}")
                df = pd.read_csv(caminho_arquivo, sep='\t', engine='python', encoding='latin1', header=2)
                print(len(df))
                
            col_data = next(c for c in df.columns if c.startswith('Data'))
        
            df = (
            df.replace('-', np.nan)
              .assign(**{
                  c: pd.to_numeric(
                      df[c].astype(str).str.replace(',', '.', regex=False),
                      errors='coerce'
                  )
                  for c in df.columns if c != col_data
              })
              .groupby(col_data, as_index=False)
              .agg(lambda x: x.dropna().iloc[0] if len(x.dropna()) else np.nan)
            )
            
            if '5MIN' in arquivo:
                estacao = arquivo.split('_')[0]
            else:
                estacao = arquivo.split('2')[0]
            
            if df.columns[0] == 'Data/Hora':
        
                print(estacao)
    
                dicionario[ano][estacao] = df

            print(len(df))

    return dicionario

def adicionar_colunas_unidade(df):
    unidades = df.iloc[0]
    
    df = df.iloc[1:].reset_index(drop=True)
    
    for col, unidade in unidades.items():
        if pd.notna(unidade):
            df[f"{col}_UNIDADE"] = unidade
    
    return df

def num_para_hora(valor):
    try:
        h = int(valor)
        m = "30" if valor % 1 == 0.5 else "00"
        return f"{h}:{m}"
    except:
        return None
        
    return df

def ler_dados_parana_1998_2002(dicionario,ano):
    
    caminho = os.getcwd()+'/data/DADOS_BRUTOS/PR/'+ano+'/'
        
    arquivos = os.listdir(caminho)
    
    for arquivo in arquivos:

        print(arquivo)
    
        if any(Path(caminho+arquivo).iterdir()):
            pasta = os.listdir(caminho+arquivo)[0]
    
            df = pd.read_excel(caminho+arquivo+'/'+pasta,header=1)

            df = adicionar_colunas_unidade(df)

            for hora in ['H', 'HORA', 'Hora']:
                if hora in df.columns:
                    df[hora] = df[hora].astype(float).apply(num_para_hora)
                    break

            estacao = arquivo[:-4]
    
            dicionario[ano][estacao] = df 

            print(len(df))
    
        else:
            print('Não há nada em '+ caminho+arquivo)

    return dicionario

def ler_dados_mes_a_mes(caminho):

    tipos_arquivos_ignorar = ['.zip','.rar','.xls','.xlsx','.7z','testes','2016','.ipynb_checkpoints']

    df = pd.DataFrame()

    #print(caminho)
    #print(sorted(os.listdir(caminho)))

    estacao = caminho.split('/')[-2].split('2')[0]
    
    for arquivo in sorted(os.listdir(caminho)):
        df_mes = pd.DataFrame()
    
        if not any(p in arquivo for p in tipos_arquivos_ignorar) or any(p in arquivo for p in ['txt']):

            if '.txt' in arquivo:
                df_mes = pd.read_csv(caminho+arquivo, sep='\t', engine='python', encoding='latin1')
                #print(df_mes.head())
                #print(arquivo)
                df = pd.concat([df, df_mes], ignore_index=True)
            
            else:
                mes = arquivo[:2]
                base_path = os.path.join(caminho, arquivo)
                
                nomes_possiveis = [
                    [f"{estacao}1H_{mes}_{ano}.txt",0],
                    [f"{estacao}1H.txt",0],
                    [f"{estacao}1H_{mes}_{ano}.xls",3],
                    [f"{estacao}_1H.xls",2]
                ]

                for nome in nomes_possiveis:
                    full_path = os.path.join(base_path, nome[0])
                    
                    try:
                        df_mes = pd.read_csv(full_path, sep='\t', engine='python', encoding='latin1',header=nome[1])
                        break
                    except Exception:
                        try:
                            df_mes = pd.read_excel(full_path, engine='xlrd',header=nome[1])
                            break
                        except Exception:
                            continue

            if len(df_mes) == 0:

                print(caminho)
                #print(sorted(os.listdir(caminho)))
                #print(arquivo)
                print(df_mes.head())
                print('')
                
            df = pd.concat([df, df_mes], ignore_index=True)

            #df = pd.concat([df, df_mes], ignore_index=True)
           
    
    print('')
            
    
    return df

def verifica_numero(num):
    try:
        if num != np.nan:
            float(num)
            return True
    except (ValueError, TypeError):
        return False

def verifica_data(data):
    try:
        pd.to_datetime(data)
        return True
    except (ValueError, TypeError):
        return False

def ler_dados_parana_2003_2019(dicionario,ano):

    pastas_ignorar = ['IQA diário','IQA_IAP','2016','ARAUCARIA2018','ARAUCARIA2019','Thumbs.db','~$Validação_Maio_2014.xlsm','SIX1H_2017.zip','.ipynb_checkpoints']

    caminho = os.getcwd()+'/data/DADOS_BRUTOS/PR/'+ano+'/'
        
    arquivos = os.listdir(caminho)

    print('')
    print(ano)
    
    for arquivo in arquivos:

        if arquivo not in pastas_ignorar:

            print(arquivo)
            
            if any(nome.endswith(('.xls', '.xlsx')) for nome in os.listdir(caminho+arquivo)) and len(os.listdir(caminho+arquivo)) <= 3:
                print(os.listdir(caminho+arquivo))

                xlsx = [f for f in os.listdir(caminho+arquivo) if f.endswith('.xlsx')]
                xls = [f for f in os.listdir(caminho+arquivo) if f.endswith('.xls')]
                
                if xlsx:
                    estacao = xlsx[0] 
                elif xls:
                    estacao = xls[0]

                try:
                    if ano == '2003':
                        df = pd.read_excel(caminho+arquivo+'/'+estacao,header=1)
                    elif estacao == 'CIC2019.xlsx':
                        df = pd.read_excel(caminho+arquivo+'/'+estacao,header=2)
                    else:
                        df = pd.read_excel(caminho+arquivo+'/'+estacao)
                except Exception as e:
                    print(f"Tentando ler como texto: {arquivo}")
                    df = pd.read_csv(caminho+arquivo+'/'+estacao, sep='\t', engine='python', encoding='latin1', header=2)
                
                if not (verifica_numero(df[df.columns[0]].iloc[0]) or verifica_data(df[df.columns[0]].iloc[0])) or arquivo == 'SIX2017':

                    df = adicionar_colunas_unidade(df)

                print(len(df))
                    
                dicionario[ano][arquivo[:-4]] = df 

            elif 'IAP' not in arquivo:

                try:
                        
                    df = ler_dados_mes_a_mes(caminho+arquivo+'/')
                    
                    if not (verifica_numero(df[df.columns[0]].iloc[0]) or verifica_data(df[df.columns[0]].iloc[0])):
    
                        df = adicionar_colunas_unidade(df)
                
                    dicionario[ano][arquivo[:-4]] = df 

                    print(len(df))

                except Exception as e:
                    print(f"A seguinte pasta não existe: {caminho}{arquivo}")
                    
    return(dicionario)

# %%
len(pd.DataFrame())

# %%
estacoes_por_ano = {
    '1998': {},
    '1999': {},
    '2000': {},
    '2001': {},
    '2002': {},
    '2003': {},
    '2004': {},
    '2005': {},
    '2006': {},
    '2007': {},
    '2008': {},
    '2009': {},
    '2010': {},
    '2011': {},
    '2012': {},
    '2013': {},
    '2014': {},
    '2015': {},
    '2016': {},
    '2017': {},
    '2018': {},
    '2019': {},
    '2020': {},
    '2021': {},
    '2022': {},
    '2023': {},
    '2024': {}
}

for ano in ['1998','1999','2000',
            '2001','2002','2003','2004','2005','2006','2007','2008','2009','2010',
            '2011','2012','2013','2014','2015','2016','2017','2018','2019','2020',
            '2021','2022','2023','2024']:

    if ano in ['1998','1999','2000','2001','2002']:
        estacoes_por_ano = ler_dados_parana_1998_2002(estacoes_por_ano,ano)
    elif ano in ['2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']:
        estacoes_por_ano = ler_dados_parana_2003_2019(estacoes_por_ano,ano)
    elif ano in ['2020','2021','2022','2023','2024']:
        estacoes_por_ano = ler_dados_parana_2024(estacoes_por_ano,ano)

# %%
lista = []

def parse_datetime(x):
    for fmt in ('%Y-%m-%d %H:%M:%S', '%d/%m/%Y %H:%M', '%m/%d/%Y %I:%M:%S %p'):
        try:
            return pd.to_datetime(x, format=fmt)
        except:
            continue
    return pd.to_datetime(x, errors='coerce')
                
def criar_datetime(df,tipo):

    if tipo == 'D':

        df['A'] = pd.to_numeric(df['A'], errors='coerce')

        if df['A'].iloc[0] < 2000:

            df['A'] = df['A'] + 2000
                
        df['H'] = df['H'].astype(str).str.split(':').str[0]
        
        df[['A', 'M', 'D', 'H']] = df[['A', 'M', 'D', 'H']].apply(pd.to_numeric, errors='coerce')
        
        df['datetime'] = pd.to_datetime(
            dict(year=df['A'], month=df['M'], day=df['D'], hour=df['H'].clip(upper=23)),
            errors='coerce'
        )
        
        df.loc[df['H'] == 24, 'datetime'] = df.loc[df['H'] == 24, 'datetime'] + pd.Timedelta(hours=1)
    
    elif tipo == 'DATA':

        df['datetime'] = pd.to_datetime(df['DATA']) + pd.to_timedelta(df['HORA'] + ':00')

        df = df.drop(columns=[c for c in ['ANO', 'MES', 'DIA', 'HORA'] if c in df.columns])
    
    elif tipo == 'Data':

        try:
            df['Data'] = pd.to_datetime(df['Data']).dt.date
        except:
            print(1)

        print(df.loc[df['Data'].astype(str).str.contains('--', na=False)])

        df['datetime'] = pd.to_datetime(df['Data']) + pd.to_timedelta(df['Hora'] + ':00')

    elif tipo == 'Data/Hora':
        
        df['Data/Hora'] = df['Data/Hora'].apply(parse_datetime)
        
        df['Data/Hora'] = df['Data/Hora'].dt.strftime('%Y-%m-%d %H:%M:%S')

        df['datetime'] = pd.to_datetime(df['Data/Hora'])

    elif tipo == 'Date/Time':
        
        df['Date/Time'] = df['Date/Time'].apply(parse_datetime)
        
        df['Date/Time'] = df['Date/Time'].dt.strftime('%Y-%m-%d %H:%M:%S')

        df['datetime'] = pd.to_datetime(df['Date/Time'])
        
    df = df.set_index("datetime")

    df = df.sort_index()
    
    df.insert(0, 'DATETIME', df.index)
    df.insert(1, 'ANO', df.index.year)
    df.insert(2, 'MES', df.index.month)
    df.insert(3, 'DIA', df.index.day)
    df.insert(4, 'HORA', df.index.hour)

    return df

lista_colunas = []

for ano in estacoes_por_ano.keys():
    
    print(ano)

    for estacao in estacoes_por_ano[ano].keys():

        #print(estacao)
        
        lista.append(estacao)

        lista_colunas = lista_colunas + list(estacoes_por_ano[ano][estacao].columns)
        
        if any(item in ['D','DATA','Data','Date/Time','Data/Hora'] for item in estacoes_por_ano[ano][estacao].columns):

            if 'D' in estacoes_por_ano[ano][estacao].columns:
                print('D')
                estacoes_por_ano[ano][estacao] = criar_datetime(estacoes_por_ano[ano][estacao], 'D')
                #print(estacoes_por_ano[ano][estacao])
            elif 'DATA' in estacoes_por_ano[ano][estacao].columns:
                print('DATA')
                estacoes_por_ano[ano][estacao] = criar_datetime(estacoes_por_ano[ano][estacao], 'DATA')
                #print(estacoes_por_ano[ano][estacao])
            elif 'Data' in estacoes_por_ano[ano][estacao].columns:
                print('Data')
                estacoes_por_ano[ano][estacao] = criar_datetime(estacoes_por_ano[ano][estacao], 'Data')
                #print(estacoes_por_ano[ano][estacao])
            elif 'Date/Time' in estacoes_por_ano[ano][estacao].columns:
                print('Date/Time')
                estacoes_por_ano[ano][estacao] = criar_datetime(estacoes_por_ano[ano][estacao], 'Date/Time')
                #print(estacoes_por_ano[ano][estacao])
            elif 'Data/Hora' in estacoes_por_ano[ano][estacao].columns:
                print('Data/Hora')
                estacoes_por_ano[ano][estacao] = criar_datetime(estacoes_por_ano[ano][estacao], 'Data/Hora')
                #print(estacoes_por_ano[ano][estacao])
            else:
                print('ERRO')
    print('')

'''
lista1 = sorted(set(lista))

lista_pr = pd.read_csv(os.getcwd() + '/data/DADOS_ESTACOES/PR_estacoes.csv')

lista2 = sorted(lista_pr['ID_OEMA'])

iguais = sorted(set(lista1) & set(lista2))

so_lista1 = [x for x in lista1 if x not in iguais]
so_lista2 = [x for x in lista2 if x not in iguais]

col1 = iguais + so_lista1 + [np.nan] * len(so_lista2)
col2 = iguais + [np.nan] * len(so_lista1) + so_lista2

df = pd.DataFrame({'PR_dados': col1, 'PR_estacao': col2})

df'''

#print(lista_colunas)
print(len(list(set(lista_colunas))))

# %%
pol_estacao_ano['2015']['CIC']['NO']

# %%
df_col_pols = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/DADOS_BRUTOS/PR/colunas_pol_PR.csv',encoding='UTF-8')

pol_estacao_ano = {}

print(df_col_pols)

for ano in estacoes_por_ano.keys():

    pol_estacao_ano[ano] = {}

    for estacao in estacoes_por_ano[ano]:
    
        pol_estacao_ano[ano][estacao] = {}
        
        for pol in df_col_pols['col_pr']:

            if pol in estacoes_por_ano[ano][estacao].columns and 'UNIDADE' not in pol:

                poluente_mma = df_col_pols.loc[df_col_pols['col_pr'] == pol, 'col_mma'].iloc[0]

                qaqc_interno = np.nan
                
                if '(' in pol:
                    unidade = pol.split('(')[-1][:-1]
                    print(pol)
                    PR
                    print(unidade)

                    df = estacoes_por_ano[ano][estacao][['DATETIME','ANO','MES','DIA','HORA',pol]]

                    df['UNIDADE'] = unidade
                    df['QAQC_INTERNO'] = qaqc_interno

                    df.rename(columns={pol: 'VALOR'}, inplace=True)
                    
                elif (pol+'_UNIDADE') in estacoes_por_ano[ano][estacao].columns:
                    #print('')
                    #print(pol)
                    #print('')

                    df = estacoes_por_ano[ano][estacao][['DATETIME','ANO','MES','DIA','HORA',pol,pol+'_UNIDADE']]

                    df['QAQC_INTERNO'] = qaqc_interno

                    df.rename(columns={pol: 'VALOR',pol+'_UNIDADE':'UNIDADE'}, inplace=True)
                    
                else:

                    df = estacoes_por_ano[ano][estacao][['DATETIME','ANO','MES','DIA','HORA',pol]]
                    
                    df['UNIDADE'] = np.nan
                    df['QAQC_INTERNO'] = qaqc_interno

                    df.rename(columns={pol: 'VALOR'}, inplace=True)

                pol_estacao_ano[ano][estacao][poluente_mma] = df

# %%
import pandas as pd

pol_estacao = {}

for ano, estacoes in pol_estacao_ano.items():
    for estacao, poluentes in estacoes.items():
        for poluente, df in poluentes.items():
            pol_estacao.setdefault(estacao, {}).setdefault(poluente, [])
            pol_estacao[estacao][poluente].append(df)

estacoes_finais = {}

for estacao, poluentes in pol_estacao.items():
    for poluente, lista_dfs in poluentes.items():
        df_concat = pd.concat(lista_dfs, ignore_index=True)

        df_concat = df_concat[df_concat['DATETIME'].notna()]

        df_concat['VALOR'] = (
            df_concat['VALOR']
            .astype(str)           
            .str.replace(',', '.', regex=False)  
        )

        df_concat['VALOR'] = pd.to_numeric(df_concat['VALOR'], errors='coerce')

        df_media = (
            df_concat.groupby(['ANO', 'MES', 'DIA', 'HORA', 'UNIDADE'], as_index=False)['VALOR']
              .mean()
        )
        
        df_media["DATETIME"] = pd.to_datetime(
            df_media.apply(
                lambda r: f"{int(r.ANO):04d}-{int(r.MES):02d}-{int(r.DIA):02d} {int(r.HORA):02d}:00:00",
                axis=1
            )
        )

        df_media = df_media.drop(columns=['ANO', 'MES', 'DIA', 'HORA'])

        df_media = df_media.set_index("DATETIME")
    
        df_media = df_media.sort_index()

        df_media = df_media[~df_media.index.duplicated(keep='first')]
        
        lista_horas = pd.date_range(
            start=df_media.index.min(), 
            end=df_media.index.max(), 
            freq='H').strftime('%Y-%m-%d %H:%M:%S').tolist()
        
        if len(lista_horas) != len(df):
            df_media = df_media.reindex(pd.DatetimeIndex(lista_horas))

        df_media.insert(1, 'ANO', df_media.index.year)
        df_media.insert(2, 'MES', df_media.index.month)
        df_media.insert(3, 'DIA', df_media.index.day)
        df_media.insert(4, 'HORA', df_media.index.hour)
        
        df_media['DATETIME'] = df_media.index

        df_media['QAQC_INTERNO'] = None
        
        df_media = df_media[['DATETIME', 'ANO', 'MES', 'DIA', 'HORA', 'VALOR', 'UNIDADE', 'QAQC_INTERNO']]

        estacoes_finais[estacao+'_'+poluente] = df_media

# %%
estacoes_finais.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 estacoes_finais.keys()
#
# NameError: name 'estacoes_finais' is not defined

# %%
def create_QAQCMMA_VALOR(df,pol):

    df = df.rename(columns={'VALOR':'VALOR_ORIGINAL'})

    flags_invalidos = ['!', 'IF', 'IO', 'IC', 'I%', 'IL', 'IE', 'IS', 'IU', 'IM', 'IP', 'ID', 'IT', 'IR', 
                       'Fora da Faixa de Medição', 'Disabilitada Temporariamente', 'Inválido', 
                       'Insuficientes', 'Inexistente']

    df['QAQC_INTERNO'] = ~df['QAQC_INTERNO'].isin(flags_invalidos)
    
    DEFAULT_RANGE_LIMITS = {
        "O3": (0, 500),
        "CO": (0, 50),
        "NO2": (0, 1000),
        "NOX": (0, 2000),
        "SO2": (0, 1000),
        "MP25": (0, 1000),
        "MP10": (0, 2000),
    }

    df['QAQC_MMA'] = df['QAQC_INTERNO']

    if pol in list(DEFAULT_RANGE_LIMITS.keys()):
        lim_min = DEFAULT_RANGE_LIMITS[pol][0]
        lim_max = DEFAULT_RANGE_LIMITS[pol][1]
    else:
        lim_min = 0
        lim_max = np.inf

    df['VALOR'] = df['VALOR_ORIGINAL']

    df['VALOR'] = pd.to_numeric(df['VALOR'], errors='coerce')
    
    df.loc[df['VALOR'] == 985, 'VALOR'] = np.nan
    
    df.loc[df['QAQC_MMA'] & (df['VALOR'].isna() | (df['VALOR'] <= lim_min) | (df['VALOR'] >= lim_max)), 'QAQC_MMA'] = False
    
    df.loc[~df['QAQC_MMA'], 'VALOR'] = np.nan
    
    df = df[['DATETIME', 'ANO', 'MES', 'DIA', 'HORA', 'VALOR', 'VALOR_ORIGINAL', 'UNIDADE', 'QAQC_INTERNO', 'QAQC_MMA']]

    return df

primeiros_valores = {}

for chave, df in estacoes_finais.items():  
    
    if ~df['VALOR'].isna().all() and (df['VALOR'] > 0).any(): 
        
        linha_valida = df[df["VALOR"].notna() & (df["VALOR"] > 0)].iloc[0]
        primeiros_valores[chave] = linha_valida["DATETIME"]

codigo_estacao_PR = {}

for chave in primeiros_valores.keys():
    
    station = chave.split('_')[0]
    data = primeiros_valores[chave]
    
    if station in codigo_estacao_PR:
        if data <= codigo_estacao_PR[station]:
            codigo_estacao_PR[station] = data
    else:
        codigo_estacao_PR[station] = data

sorted_items = sorted(
    codigo_estacao_PR.items(),
    key=lambda x: (x[1], x[0])
)

codigo_estacao_PR = {}
for i, (nome, ts) in enumerate(sorted_items, start=1):
    codigo = f"PR{i:04d}"
    codigo_estacao_PR[nome] = codigo

for chave, df in estacoes_finais.items():
    
    estacao = codigo_estacao_PR[chave.split('_')[0]]

    if chave.split('_')[-1] != 'CS':
        
        cod_pol = tabela_pols.loc[tabela_pols['NOME_PASTA'] == chave.split('_')[-1], 'COD_POLUENTE'].values[0]
        
        nome_pasta = tabela_pols.loc[tabela_pols['COD_POLUENTE'] == int(cod_pol), 'NOME_PASTA'].values[0]
    
        df = create_QAQCMMA_VALOR(df,nome_pasta)

        df.to_csv('/home/nobre/Notebooks/RQAR_2025_book/data/MQAr/'+nome_pasta+'/'+estacao+'RA'+str(int(cod_pol)).zfill(3)+'.csv',index=False)

df_ids = pd.DataFrame({
    'ID_OEMA': codigo_estacao_PR.keys(),
    'ID_MMA':list(codigo_estacao_PR.values())})

print(df_ids)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 46
#      42     return df
#      44 primeiros_valores = {}
# ---> 46 for chave, df in estacoes_finais.items():
#      48     if ~df['VALOR'].isna().all() and (df['VALOR'] > 0).any():
#      50         linha_valida = df[df["VALOR"].notna() & (df["VALOR"] > 0)].iloc[0]
#
# NameError: name 'estacoes_finais' is not defined

# %%
df_ids
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_ids
#
# NameError: name 'df_ids' is not defined

# %%
df_ids
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_ids
#
# NameError: name 'df_ids' is not defined

# %%
monitoramento_QAr_BR.loc[monitoramento_QAr_BR['ID_OEMA'] == nome, 'ID_MMA']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 monitoramento_QAr_BR.loc[monitoramento_QAr_BR['ID_OEMA'] == nome, 'ID_MMA']
#
# NameError: name 'monitoramento_QAr_BR' is not defined

# %%
estacoes_dicionario.keys()

for chave in estacoes_dicionario.keys():

    print(chave)
    print(len(estacoes_dicionario[chave]))
    print(estacoes_dicionario[chave].columns[0])
    print(estacoes_dicionario[chave].iloc[0, 0])
    print(estacoes_dicionario[chave].iloc[-1, 0])
    print("")

    estacoes_por_ano
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 estacoes_dicionario.keys()
#       3 for chave in estacoes_dicionario.keys():
#       5     print(chave)
#
# NameError: name 'estacoes_dicionario' is not defined

# %% [markdown]
# # Update_MQAr_with_IEMA_MonitorAr

# %%
caminho = os.getcwd() + '/data/DADOS_BRUTOS/BRUTO_IEMA/'

estados_iema = os.listdir(caminho)

df_estacao_codigo = pd.DataFrame({
    'Estacao':[],
    'Codigo':[]
})

for estado in estados_iema:

    if '.csv' not in estado and '.ipynb_checkpoints' not in estado:

        lista_anos = os.listdir(caminho+estado)

        print(estado)
    
        print(lista_anos)
    
        df_estado = pd.DataFrame({
            'Data':[], 
            'Hora':[], 
            'Estacao':[], 
            'Codigo':[], 
            'Poluente':[], 
            'Valor':[], 
            'Unidade':[],
            'Tipo':[]})
    
        for ano in lista_anos:

            if '.csv' in ano:

                df = pd.read_csv(caminho+estado+'/'+ano, encoding='ISO-8859-1')
        
                df.columns.values[0] = 'Data'

                if 'Escola CecÃlia Meireles' in df['Estacao']:

                    print(ano)
        
                df_estado = pd.concat([df_estado, df], ignore_index=True)
    
        df_estacao_codigo = pd.concat([df_estacao_codigo,df_estado[['Estacao','Codigo']]], ignore_index=True)

df_estacao_codigo = df_estacao_codigo.drop_duplicates(subset=['Estacao', 'Codigo']).reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 caminho = os.getcwd() + '/data/DADOS_BRUTOS/BRUTO_IEMA/'
# ----> 3 estados_iema = os.listdir(caminho)
#       5 df_estacao_codigo = pd.DataFrame({
#       6     'Estacao':[],
#       7     'Codigo':[]
#       8 })
#      10 for estado in estados_iema:
#
# FileNotFoundError: [WinError 3] O sistema não pode encontrar o caminho especificado: 'C:\\MMA\\scripts/data/DADOS_BRUTOS/BRUTO_IEMA/'

# %%
df_estacao_codigo.to_csv(os.getcwd() + '/data/DADOS_BRUTOS/BRUTO_IEMA/IEMA_codigo_estacao.csv', encoding = 'UTF-8', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_estacao_codigo.to_csv(os.getcwd() + '/data/DADOS_BRUTOS/BRUTO_IEMA/IEMA_codigo_estacao.csv', encoding = 'UTF-8', index = False)
#
# NameError: name 'df_estacao_codigo' is not defined

# %%
import pandas as pd
import glob
import os
from unidecode import unidecode
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 4
#       2 import glob
#       3 import os
# ----> 4 from unidecode import unidecode
#
# ModuleNotFoundError: No module named 'unidecode'

# %%
df_estacoes = pd.read_csv(os.getcwd() + '/data/DADOS_BRUTOS/BRUTO_IEMA/IEMA_codigo_estacao.csv', encoding = 'UTF-8')

import pandas as pd
import glob
import os
from unidecode import unidecode

# Caminho da pasta com os arquivos CSV
pasta = os.getcwd() + '/data/DADOS_ESTACOES'

# DataFrame principal
df_principal = df_estacoes.copy()

# Garantir que são strings
df_principal["ID_OEMA"] = df_principal["ID_OEMA"].astype(str)
df_principal["ID_MMA"] = df_principal["ID_MMA"].astype(str)

# Função para remover acentos e padronizar texto
def normalizar(texto):
    if pd.isna(texto):
        return None
    return unidecode(str(texto)).strip().upper()

# Normalizar coluna no DataFrame principal
df_principal["ID_OEMA_norm"] = df_principal["ID_OEMA"].apply(normalizar)

# Criar dicionário de mapeamento OEMA → MMA
mapa_oema_mma = {}

for arquivo in glob.glob(os.path.join(pasta, "*.csv")):
    df = pd.read_csv(arquivo, dtype=str)
    
    if "ID_OEMA" in df.columns and "ID_MMA" in df.columns:
        # Normalizar também nos arquivos
        df["ID_OEMA_norm"] = df["ID_OEMA"].apply(normalizar)
        df["ID_MMA"] = df["ID_MMA"].astype(str)

        pares_validos = df.dropna(subset=["ID_OEMA_norm", "ID_MMA"])
        for _, linha in pares_validos.iterrows():
            mapa_oema_mma[linha["ID_OEMA_norm"]] = linha["ID_MMA"]

# Mapear no DataFrame principal (usando os IDs normalizados)
df_principal["ID_MMA_preenchido"] = df_principal["ID_OEMA_norm"].map(mapa_oema_mma)

# Preencher apenas onde estava vazio
df_principal["ID_MMA"] = df_principal["ID_MMA"].replace("nan", pd.NA)
df_principal["ID_MMA"] = df_principal["ID_MMA"].fillna(df_principal["ID_MMA_preenchido"])

# Remover coluna auxiliar
df_principal = df_principal.drop(columns=["ID_MMA_preenchido", "ID_OEMA_norm"])

df_principal.to_csv(os.getcwd() + '/data/DADOS_BRUTOS/BRUTO_IEMA/IEMA_codigo_estacao_teste.csv', encoding = 'UTF-8', index = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_estacoes = pd.read_csv(os.getcwd() + '/data/DADOS_BRUTOS/BRUTO_IEMA/IEMA_codigo_estacao.csv', encoding = 'UTF-8')
#       3 import pandas as pd
#       4 import glob
#
# File C:\MMA\amb_MMA\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File C:\MMA\amb_MMA\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File C:\MMA\amb_MMA\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File C:\MMA\amb_MMA\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File C:\MMA\amb_MMA\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\MMA\\scripts/data/DADOS_BRUTOS/BRUTO_IEMA/IEMA_codigo_estacao.csv'

# %%
df_estacoes = pd.read_csv(os.getcwd() + '/data/DADOS_BRUTOS/BRUTO_IEMA/IEMA_codigo_estacao_teste.csv', encoding = 'UTF-8')

df_estacoes

# %%
caminho = os.getcwd() + '/data/DADOS_BRUTOS/BRUTO_IEMA/'

df_est = pd.DataFrame({'Data':[],
                   'Hora'    :[],	
                   'Estacao' :[],
                   'Codigo'  :[],
                   'Poluente':[],
                   'Valor'   :[],	
                   'Unidade' :[],
                   'Tipo'    :[]})

arquivos = os.listdir(caminho)

for arquivo in arquivos:
    
    if '.csv' not in arquivo and 'checkpoints' not in arquivo:

        print(arquivo)

        anos = os.listdir(caminho+arquivo)

        for ano in anos:

            if '.csv' in ano:

                df = pd.read_csv(caminho+arquivo+'/'+ano, encoding='ISO-8859-1')

                df = df.rename(columns=lambda x: x.replace('ï»¿', ''))

                df = df.replace('MP2.5', 'MP25', regex=False)

                df_est = pd.concat([df, df_est], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 12
#       1 caminho = os.getcwd() + '/data/DADOS_BRUTOS/BRUTO_IEMA/'
#       3 df_est = pd.DataFrame({'Data':[],
#       4                    'Hora'    :[],
#       5                    'Estacao' :[],
#    (...)      9                    'Unidade' :[],
#      10                    'Tipo'    :[]})
# ---> 12 arquivos = os.listdir(caminho)
#      14 for arquivo in arquivos:
#      16     if '.csv' not in arquivo and 'checkpoints' not in arquivo:
#
# FileNotFoundError: [WinError 3] O sistema não pode encontrar o caminho especificado: 'C:\\MMA\\scripts/data/DADOS_BRUTOS/BRUTO_IEMA/'

# %%
df_est = df_est.merge(df_estacoes[['ID_OEMA', 'ID_MMA']], left_on='Estacao', right_on='ID_OEMA', how='left')

# %%
df_est
# Out:
# Empty DataFrame
# Columns: [Data, Hora, Estacao, Codigo, Poluente, Valor, Unidade, Tipo]
# Index: []

# %%
list(set(df_est['Unidade']))

lista_pols = list(set(df_est['Poluente']))

lista_pols
# Out:
# []

# %%
tabela_pols = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/dicionarios/CODIGO_POLUENTES.csv')

def create_QAQCMMA_VALOR(df,pol):

    df = df.rename(columns={'VALOR':'VALOR_ORIGINAL'})

    flags_invalidos = ['!', 'IF', 'IO', 'IC', 'I%', 'IL', 'IE', 'IS', 'IU', 'IM', 'IP', 'ID', 'IT', 'IR',
                       'IM', 'VU', 'ID', 'IF', 'VE', 'IC', 'IN', 'VR', 'IV', 'IO',
                       'Fora da Faixa de Medição', 'Disabilitada Temporariamente', 'Inválido', 
                       'Insuficientes', 'Inexistente', False]

    df['QAQC_INTERNO'] = ~df['QAQC_INTERNO'].isin(flags_invalidos)
    
    DEFAULT_RANGE_LIMITS = {
        "O3": (0, 500),
        "CO": (0, 50),
        "NO2": (0, 1000),
        "NOX": (0, 2000),
        "SO2": (0, 1000),
        "MP25": (0, 1000),
        "MP10": (0, 2000),
    }
    
    df['QAQC_MMA'] = df['QAQC_INTERNO']

    if pol in list(DEFAULT_RANGE_LIMITS.keys()):
        lim_min = DEFAULT_RANGE_LIMITS[pol][0]
        lim_max = DEFAULT_RANGE_LIMITS[pol][1]
    else:
        lim_min = 0
        lim_max = np.inf

    df['VALOR'] = df['VALOR_ORIGINAL']

    df['VALOR'] = pd.to_numeric(df['VALOR'], errors='coerce')
    
    df.loc[df['QAQC_MMA'] & (df['VALOR'].isna() | (df['VALOR'] <= lim_min) | (df['VALOR'] >= lim_max)), 'QAQC_MMA'] = False

    df.loc[df['VALOR'] == 985, 'VALOR'] = np.nan
    
    df.loc[~df['QAQC_MMA'], 'VALOR'] = np.nan
    
    df = df[['DATETIME', 'ANO', 'MES', 'DIA', 'HORA', 'VALOR', 'VALOR_ORIGINAL', 'UNIDADE', 'QAQC_INTERNO', 'QAQC_MMA']]

    return df

print(lista_pols)

def ajustar_hora24(row):
    if row['Hora'].startswith('24'):
        # passa para o dia seguinte
        nova_data = pd.to_datetime(row['Data']) + pd.Timedelta(days=1)
        return nova_data.strftime('%Y-%m-%d') + ' 00:00:00'
    else:
        return row['Data'] + ' ' + row['Hora']

def ug_to_ppm(df,pol):

    if pol == 'NO':

        df.loc[df["UNIDADE"] == "ppm", "VALOR_ORIGINAL"] *= 1225.6
        df.loc[df["UNIDADE"] == "ppb", "VALOR_ORIGINAL"] *= 1.2256
    
        df['UNIDADE'] = "µg/m³"
        

    elif pol == 'NO2':

        df.loc[df["UNIDADE"] == "ppm", "VALOR_ORIGINAL"] *= 191103.89/100
        df.loc[df["UNIDADE"] == "ppb", "VALOR_ORIGINAL"] *= 191.10389/100
    
        df['UNIDADE'] = "µg/m³"
        
    elif pol == 'O3':

        df.loc[df["UNIDADE"] == "ppm", "VALOR_ORIGINAL"] *= 199388.92/100
        df.loc[df["UNIDADE"] == "ppb", "VALOR_ORIGINAL"] *= 199.38892/100
    
        df['UNIDADE'] = "µg/m³"
        
    elif pol == 'SO2':

        df.loc[df["UNIDADE"] == "ppm", "VALOR_ORIGINAL"] *= 266126.05/100
        df.loc[df["UNIDADE"] == "ppb", "VALOR_ORIGINAL"] *= 266.12605/100
    
        df['UNIDADE'] = "µg/m³"

    elif pol == 'CO':

        df.loc[df["UNIDADE"] == "ug/m3", "VALOR_ORIGINAL"] *= 868.26/10**6
        df.loc[df["UNIDADE"] == "Âµg/mÂ", "VALOR_ORIGINAL"] *= 868.26/10**6
        df.loc[df["UNIDADE"] == "µg/m³", "VALOR_ORIGINAL"] *= 868.26/10**6
        df.loc[df["UNIDADE"] == "µg/m3", "VALOR_ORIGINAL"] *= 868.26/10**6
        df.loc[df["UNIDADE"] == "ppb", "VALOR_ORIGINAL"] *= 1/1000
        
        df['UNIDADE'] = "ppm"

    return df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 tabela_pols = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/dicionarios/CODIGO_POLUENTES.csv')
#       3 def create_QAQCMMA_VALOR(df,pol):
#       5     df = df.rename(columns={'VALOR':'VALOR_ORIGINAL'})
#
# File C:\MMA\amb_MMA\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File C:\MMA\amb_MMA\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File C:\MMA\amb_MMA\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File C:\MMA\amb_MMA\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File C:\MMA\amb_MMA\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nobre/Notebooks/RQAR_2025_book/data/dicionarios/CODIGO_POLUENTES.csv'

# %%
lista_pols = list(set(df_est['Poluente']))

dicionario_final_iema = {}
dicionario_iema = {}
dicionario_MQAr_iema = {}

for pol in lista_pols:

    print(pol)

    df_pol = df_est[df_est["Poluente"] == pol]

    lista_estacoes = list(set(df_pol['ID_MMA']))

    print(lista_estacoes)

    for estacao in lista_estacoes:

        if type(estacao) == str:

            cod_poluente = int(tabela_pols.loc[tabela_pols['POLUENTE'] == pol, 'COD_POLUENTE'].values[0])
           
            cod_poluente = f"{cod_poluente:03d}"

            print(cod_poluente)

            df_pol_est = df_pol[df_pol["ID_MMA"] == estacao]

            padrao = os.path.join(os.getcwd() + '/data/MQAr/'+pol+'/', f"{estacao}*.csv")
            arquivos = glob.glob(padrao)

            for arquivo in arquivos:

                print(arquivo)
                
                df_mma = pd.read_csv(arquivo, encoding = 'UTF-8')

                df_iema = df_pol_est[['Data','Hora','Valor','Unidade']]
                
                mask_24 = df_iema['Hora'].str.startswith('24')

                df_iema.loc[mask_24, 'Data'] = pd.to_datetime(df_iema.loc[mask_24, 'Data']) + pd.Timedelta(days=1)
                df_iema.loc[mask_24, 'Hora'] = '00:00:00'
                
                df_iema['Data'] = df_iema['Data'].astype(str)
                
                df_iema['DATETIME'] = pd.to_datetime(df_iema['Data'] + ' ' + df_iema['Hora'], errors='coerce')
                
                df_iema.drop(columns=['Data','Hora'], inplace=True)

                df_iema.rename(columns={'Valor':'VALOR_ORIGINAL','Unidade':'UNIDADE'},inplace=True)

                df_mma['DATETIME'] = pd.to_datetime(df_mma['DATETIME'], errors='coerce')
                df_iema['DATETIME'] = pd.to_datetime(df_iema['DATETIME'], errors='coerce')
                
                df_mma = df_mma.dropna(subset=['DATETIME'])
                df_iema = df_iema.dropna(subset=['DATETIME'])

                df_iema = ug_to_ppm(df_iema,pol)
                
                df_iema = (
                    df_iema.sort_values('VALOR_ORIGINAL', ascending=False)
                           .drop_duplicates(subset='DATETIME', keep='first')
                )
                
                df_final = df_mma.merge(df_iema, on='DATETIME', how='left', suffixes=('', '_df2'))
                
                df_final['VALOR_ORIGINAL'] = df_final['VALOR_ORIGINAL_df2'].combine_first(df_final['VALOR_ORIGINAL'])
                df_final['UNIDADE'] = df_final['UNIDADE_df2'].combine_first(df_final['UNIDADE'])

                df_final['VALOR'] = df_final['VALOR_ORIGINAL']

                df_final.drop(columns=['VALOR_ORIGINAL'], inplace=True)

                df_final = create_QAQCMMA_VALOR(df_final,pol)
                
                print('iema')
                print(df_iema.head())
                print('mma')
                print(df_mma.head())
                print('final')
                print(df_final.head())
                
                dicionario_final_iema[arquivo] = df_final
                dicionario_iema[arquivo] = df_iema
                dicionario_MQAr_iema[arquivo] = df_mma

                df_final.to_csv(arquivo, index=False)

# %%
for chave in dicionario_final_iema.keys():

    print(chave)
    
    df_final = dicionario_final_iema[chave]
    df_iema = dicionario_iema[chave]
    df_mma = dicionario_MQAr_iema[chave] 

    print(df_final['VALOR'].max())
    print(df_iema['VALOR_ORIGINAL'].max())
    print(df_mma['VALOR'].max())

# %%
dicionario_iema.keys()

# %%
arquivo

# %%
df_final = df_mma.merge(df_iema, on='DATETIME', how='left', suffixes=('', '_df2'))

df_mma = pd.read_csv(arquivo, encoding = 'UTF-8')

df_iema = df_pol_est[['Data','Hora','Valor','Unidade']]

mask_24 = df_iema['Hora'].str.startswith('24')

df_iema.loc[mask_24, 'Data'] = pd.to_datetime(df_iema.loc[mask_24, 'Data']) + pd.Timedelta(days=1)
df_iema.loc[mask_24, 'Hora'] = '00:00:00'

df_iema['Data'] = df_iema['Data'].astype(str)

df_iema['DATETIME'] = pd.to_datetime(df_iema['Data'] + ' ' + df_iema['Hora'], errors='coerce')

df_iema.drop(columns=['Data','Hora'], inplace=True)

df_iema.rename(columns={'Valor':'VALOR_ORIGINAL','Unidade':'UNIDADE'},inplace=True)

df_mma['DATETIME'] = pd.to_datetime(df_mma['DATETIME'], errors='coerce')
df_iema['DATETIME'] = pd.to_datetime(df_iema['DATETIME'], errors='coerce')

df_mma = df_mma.dropna(subset=['DATETIME'])
df_iema = df_iema.dropna(subset=['DATETIME'])

if pol == 'CO':
    df_iema = ug_to_ppm(df_iema)

df_iema = (
    df_iema.sort_values('VALOR_ORIGINAL', ascending=False)
           .drop_duplicates(subset='DATETIME', keep='first')
)

df_final = df_mma.merge(df_iema, on='DATETIME', how='left', suffixes=('', '_df2'))

# %%
caminho = os.getcwd()+'/data/DADOS_BRUTOS/BRUTO_MONITORAR/'

df_colunas_monitorar = pd.read_csv(caminho+'colunas_monitorar.csv')

estados = os.listdir(caminho)

lista = []

lista_validacao = []

mapeamento = dict(zip(df_colunas_monitorar["COLUNAS_MONITORAR"], df_colunas_monitorar["COLUNAS_MMA"]))

dict_estacao_pol = {}

def unit_pol(pol):

    if pol in ['NOX','NO2','PTS','O3','MP10','MP25','NO','ERT','SO2']:
        unidade = 'µg/m³'
    elif pol in ['HCT','H2S','NH3','HCNM','BENZENO','CO','CH4']:
        unidade = 'ppm'

    return unidade

def create_QAQCMMA_VALOR_MonitorAr(df,pol):

    flags_invalidos = ['!', 'IF', 'IO', 'IC', 'I%', 'IL', 'IE', 'IS', 'IU', 'IM', 'IP', 'ID', 'IT', 'IR',
                       'IM', 'VU', 'ID', 'IF', 'VE', 'IC', 'IN', 'VR', 'IV', 'IO',
                       'Fora da Faixa de Medição', 'Disabilitada Temporariamente', 'Inválido', 
                       'Insuficientes', 'Inexistente', False]

    df['QAQC_INTERNO'] = ~df['QAQC_INTERNO'].isin(flags_invalidos)

    df.loc[df['VALOR_ORIGINAL'] == 985, 'VALOR'] = np.nan
    
    df.loc[~df['QAQC_INTERNO'], 'VALOR_ORIGINAL'] = np.nan

    return df


dicionario_final_monitorar = {}
dicionario_monitorar = {}
dicionario_MQAr_monitorar = {}
    
for estado in estados:

    print(estado)
    
    if '.csv' not in estado and estado != '.ipynb_checkpoints':

        if estado == 'RJ' or estado == 'PA' or estado == 'RN':
            df_rj_ou_pa_estacao = pd.read_csv(os.getcwd()+'/data/DADOS_BRUTOS/BRUTO_MONITORAR/'+estado+'_ID_MMA_monitorar.csv')
        else:
            df_estado_estacao = pd.read_csv(os.getcwd()+'/data/DADOS_ESTACOES/'+estado+'_estacoes.csv')

        estacoes = os.listdir(caminho+estado)
    
        for estacao in estacoes:
    
            if estacao != '.ipynb_checkpoints':
    
                df = pd.read_csv(caminho+estado+'/'+estacao, sep = ';')
                    
                df = df.rename(columns=mapeamento)

                df = df.dropna(axis=1, how='all')
                
                df_consolidado = df.groupby(df.columns, axis=1).first() 

                print(estacao)

                for col in df_consolidado.columns:
    
                    if col != 'DATA' and col != 'HORA' and 'QAQC' not in col:

                        if df_consolidado[col].astype(str).str.contains(',').any():
                            
                            df_consolidado[col] = df_consolidado[col].apply(
                                lambda x: str(x).replace('.', '') if pd.notna(x) else x
                            )
                            df_consolidado[col] = df_consolidado[col].apply(
                                lambda x: str(x).replace(',', '.') if pd.notna(x) else x
                            ).astype(float)
                        else:
                            
                            df_consolidado[col] = pd.to_numeric(df_consolidado[col], errors='coerce')

                for pol in ['NOX','HCT','H2S','NO2','PTS','NH3','HCNM','HORA','O3','BENZENO','CO','MP10','MP25','CH4','NO','ERT','SO2']:
    
                    if pol in df_consolidado.columns and pol != 'HORA' and pol != 'DATA':
    
                        unidade = 'desconhecida'

                        print(pol)

                        qaqc = 'QAQC_'+pol
                        if qaqc in df_consolidado.columns:
                            print(df_consolidado.columns)
                            df_monitorar = df_consolidado[['DATA','HORA',pol,qaqc]]
                        else:
                            df_monitorar = df_consolidado[['DATA','HORA',pol]]

                        df_monitorar['DATA_HORA_STRING'] = df_monitorar['DATA'] + ' ' + df_monitorar['HORA']

                        df_monitorar['DATETIME'] = pd.to_datetime(
                            df_monitorar['DATA_HORA_STRING'],
                            format='%d/%m/%Y %H:%M'
                        )
                        
                        df_monitorar = df_monitorar.drop(columns=['DATA_HORA_STRING','DATA','HORA'])
    
                        df_monitorar.index = df_monitorar['DATETIME']
                        
                        df_monitorar.insert(1, 'ANO', df_monitorar.index.year)
                        df_monitorar.insert(2, 'MES', df_monitorar.index.month)
                        df_monitorar.insert(3, 'DIA', df_monitorar.index.day)
                        df_monitorar.insert(4, 'HORA', df_monitorar.index.hour)

                        df_monitorar['UNIDADE'] = unidade

                        dict_estacao_pol[estacao[:-4]+'_'+pol] = df_monitorar

                        if qaqc in df_monitorar.columns:
        
                            for validacao in list(set(df_monitorar[qaqc])):

                                lista_validacao.append(validacao)

                        print(estacao[:-4])
                        
                        if estado == 'RJ' or estado == 'PA' or estado == 'RN':
                            id_mma = df_rj_ou_pa_estacao.loc[df_rj_ou_pa_estacao['STATION']==estacao[:-4], 'ID_MMA'].iloc[0]
                        else:
                            mask = (df_estado_estacao['ID_OEMA']
                                .str.replace(' ', '', regex=False)
                                .str.replace('-', '', regex=False)
                                .str.lower()
                                == estacao[:-4].replace(' ', '').replace('-', '').lower()
                            )
                    
                            id_mma = df_estado_estacao.loc[mask, 'ID_MMA'].iloc[-1]
                            
                        print(id_mma)
                        
                        df_monitorar.rename(columns={pol:'VALOR_ORIGINAL','QAQC_'+pol:'QAQC_INTERNO'},inplace=True)

                        df_monitorar = create_QAQCMMA_VALOR_MonitorAr(df_monitorar,pol)

                        padrao = os.path.join(os.getcwd() + '/data/MQAr/'+pol+'/', f"{id_mma}*.csv")
                        arquivos = glob.glob(padrao)

                        if len(arquivos) == 0:

                            unidade = unit_pol(pol)

                            df_monitorar['UNIDADE'] = unidade
                
                            df_monitorar = create_QAQCMMA_VALOR(df_monitorar,pol)

                            cod_poluente = int(tabela_pols.loc[tabela_pols['POLUENTE'] == pol, 'COD_POLUENTE'].values[0])
                           
                            cod_poluente = f"{cod_poluente:03d}"
                            
                            dicionario_monitorar[arquivo] = df_monitorar

                            print(str(pol)+'/'+str(id_mma)+'ND'+cod_poluente+'.csv')
                            
                            df_monitorar.to_csv('/home/nobre/Notebooks/RQAR_2025_book/data/MQAr/'+pol+'/'+id_mma+'ND'+cod_poluente+'.csv', index=False)
                            
                        else:
                            for arquivo in arquivos:
                    
                                df_mma = pd.read_csv(arquivo, encoding = 'UTF-8')
                                
                                df_mma = df_mma.dropna(subset=['DATETIME'])
                                df_monitorar = df_monitorar.dropna(subset=['DATETIME'])
                                
                                df_monitorar = (
                                    df_monitorar.sort_values('VALOR_ORIGINAL', ascending=False)
                                           .drop_duplicates(subset='DATETIME', keep='first')
                                )

                                df_monitorar = df_monitorar.reset_index(drop=True)

                                df_mma['DATETIME'] = pd.to_datetime(df_mma['DATETIME'], errors='coerce')
                                df_monitorar['DATETIME'] = pd.to_datetime(df_monitorar['DATETIME'], errors='coerce')

                                unidade = unit_pol(pol)

                                df_monitorar['UNIDADE'] = unidade
                                
                                df_final = df_mma.merge(df_monitorar, on='DATETIME', how='left', suffixes=('', '_df2'))
                                
                                df_final['VALOR_ORIGINAL'] = df_final['VALOR_ORIGINAL_df2'].combine_first(df_final['VALOR_ORIGINAL'])
                                df_final['UNIDADE'] = df_final['UNIDADE_df2'].combine_first(df_final['UNIDADE'])
                
                                df_final['VALOR'] = df_final['VALOR_ORIGINAL']
                
                                df_final.drop(columns=['VALOR_ORIGINAL','ANO','MES','DIA','HORA'], inplace=True)
                                df_final=df_final.set_index('DATETIME')
                    
                                lista_horas = pd.date_range(
                                    start=df_final.index.min(), 
                                    end=df_final.index.max(), 
                                    freq='H').strftime('%Y-%m-%d %H:%M:%S').tolist()

                                df_final = df_final[~df_final.index.duplicated(keep='first')]
                                
                                if len(lista_horas) != len(df_final):
                                    df_final = df_final.reindex(pd.DatetimeIndex(lista_horas))
                                
                                df_final['DATETIME'] = df_final.index
                                
                                cols = ["DATETIME"] + [c for c in df_final.columns if c != "DATETIME"]
                                df_final = df_final[cols]
                                
                                df_final.index = df_final['DATETIME']
                                
                                df_final.insert(1, 'ANO', df_final.index.year)
                                df_final.insert(2, 'MES', df_final.index.month)
                                df_final.insert(3, 'DIA', df_final.index.day)
                                df_final.insert(4, 'HORA', df_final.index.hour)
                
                                df_final = create_QAQCMMA_VALOR(df_final,pol)
                                
                                print('iema')
                                print(df_monitorar.head())
                                print('mma')
                                print(df_mma.head())
                                print('final')
                                print(df_final.head())

                                dicionario_final_monitorar[arquivo] = df_final
                                dicionario_monitorar[arquivo] = df_monitorar
                                dicionario_MQAr_monitorar[arquivo] = df_mma
                                
                                df_final.to_csv(arquivo, index=False)
                            
                                                                
lista_colunas = list(set(lista))

lista_validacao = list(set(lista_validacao))

# %%
for chave in dicionario_final_monitorar.keys():

    print(chave)
    
    df_final = dicionario_final_monitorar[chave]
    df_moni = dicionario_monitorar[chave]
    df_mma = dicionario_MQAr_monitorar[chave] 

    print(df_final['VALOR'].max())
    print(df_moni['VALOR_ORIGINAL'].max())
    print(df_mma['VALOR'].max())

# %%
dicionario_final[arquivo] = df_final
dicionario_monitorar[arquivo] = df_monitorar
dicionario_MQAr[arquivo] = df_mma

# %%
dicionario_final['/home/nobre/Notebooks/RQAR_2025_book/data/MQAr/MP10/RJ1013RA001.csv']['VALOR'].min()

# %%
lista_validacao

# %%
df_monitorar.columns

# %%
df_consolidado

linhas_encontradas = df_consolidado[df_consolidado[col] == '2.645,499']

linhas_encontradas

# %%
pastas = ['MP10','MP25']

from unidecode import unidecode

dict_pols = {}

monitoramento_qar = pd.read_csv(os.getcwd()+'/data/Monitoramento_QAr_BR.csv')

for pasta in pastas:

    caminho = os.getcwd()+'/data/MQAr_averages/anual/'+pasta+'/'
    
    arquivos = os.listdir(caminho)

    dict_pols[pasta] = {}

    for arquivo in arquivos:

        if '.ipynb' not in arquivo and 'RJ10' not in arquivo:

            df = pd.read_csv(caminho+arquivo)

            dict_pols[pasta][arquivo[:6]] = df
    
    monitoramento_qar_pol = monitoramento_qar[monitoramento_qar['POLUENTE'] == pasta]

    menor_ano = min(df['ANO'].min() for df in dict_pols[pasta].values())

    cols = ['ESTADO','CIDADE','COD_CIDADE','NOME_ESTACAO','ID_MMA','LATITUDE','LONGITUDE']  + list(range(menor_ano, 2025))

    df_anos = pd.DataFrame(columns=cols)

    for estacao, df in dict_pols[pasta].items():

        print(estacao)

        if estacao == 'ES0016':
                
                linha = {'ESTADO': 'ES',
                         'CIDADE': 'Vitória',
                         'COD_CIDADE': '3205309',
                         'NOME_ESTACAO': 'EMQAR - RGV10 - Praia do Canto',
                         'ID_MMA': 'ES0016',
                         'LATITUDE': '-20.294211',
                         'LONGITUDE': '-40.535128',}
            
                existe = 'Sim'
        
            else:
            
                dados = monitoramento_qar.loc[monitoramento_qar['ID_MMA'] == estacao, ['UF', 'CIDADE','CD_MUN', 'ID_OEMA', 'ID_MMA', 'LATITUDE', 'LONGITUDE']]
    
                if len(dados)>=1:
        
                    dados = dados.rename(columns={
                        'UF': 'ESTADO',
                        'CIDADE': 'CIDADE',
                        'CD_MUN':'COD_CIDADE',
                        'ID_OEMA': 'NOME_ESTACAO',
                        'LATITUDE': 'LATITUDE',
                        'LONGITUDE': 'LONGITUDE'
                    })
        
                    linha = {'ESTADO': dados['ESTADO'].iloc[0],
                             'CIDADE': dados['CIDADE'].iloc[0],
                             'COD_CIDADE': dados['COD_CIDADE'].iloc[0],
                             'ID_MMA': dados['ID_MMA'].iloc[0],
                             'NOME_ESTACAO': dados['NOME_ESTACAO'].iloc[0],
                             'LATITUDE': dados['LATITUDE'].iloc[0],
                             'LONGITUDE': dados['LONGITUDE'].iloc[0],}

                    existe = 'Sim'
                    
                else: 
                    existe = 'Nao'

            if existe == 'Sim':
            
                anos = list(range(menor_ano, 2025))
                
                for _, row in df.iterrows():
                    ano = row['ANO']
                    valor = row['VALOR']
                    if ano in anos:
                        linha[ano] = valor
                
                df_anos = pd.concat([df_anos, pd.DataFrame([linha])], ignore_index=True)

    colunas_anos = list(range(menor_ano, 2025))
    
    df_anos.to_csv(os.getcwd()+'/data/dicionarios/MEDIAS_ANUAIS_ESTACOES_'+pasta+'.csv', index = False)

    df_anos['ESTADO'] = df_anos['ESTADO'].astype(str).map(lambda x: unidecode(x).upper())
    df_anos['CIDADE'] = df_anos['CIDADE'].astype(str).map(lambda x: unidecode(x).upper())
    
    df_muns_media = (
        df_anos.groupby(['ESTADO', 'CIDADE'])
        .agg(
            {**{col: 'mean' for col in colunas_anos}, 
             'LATITUDE': 'first',
             'LONGITUDE': 'first',
             'NOME_ESTACAO': 'count'} 
        )
        .rename(columns={'NOME_ESTACAO': 'QUANTIDADE_ESTACOES'})
        .reset_index()
    )

    df_muns_media = df_muns_media[['ESTADO', 'CIDADE', 'LATITUDE', 'LONGITUDE', 'QUANTIDADE_ESTACOES'] + colunas_anos]

    df_muns_max = (
        df_anos.groupby(['ESTADO', 'CIDADE'])
        .agg(
            {**{col: 'max' for col in colunas_anos},  
             'LATITUDE': 'first',
             'LONGITUDE': 'first',
             'NOME_ESTACAO': 'count'} 
        )
        .rename(columns={'NOME_ESTACAO': 'QUANTIDADE_ESTACOES'})
        .reset_index()
    )

    df_muns_max = df_muns_media[['ESTADO', 'CIDADE', 'LATITUDE', 'LONGITUDE', 'QUANTIDADE_ESTACOES'] + colunas_anos]

    df_muns_media.to_csv(os.getcwd()+'/data/dicionarios/MEDIAS_ANUAIS_MUNICIPIOS_'+pasta+'.csv', index = False)

    df_muns_max.to_csv(os.getcwd()+'/data/dicionarios/MAXIMAS_ANUAIS_MUNICIPIOS_'+pasta+'.csv', index = False)
# Out:
# SP0248
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0031
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0282
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0085
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0048
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0073
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0024
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RR0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0083
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0009
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0013
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0120
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0029
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MS0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PA1003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0118
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0051
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0057
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0007
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0082
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0281
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0103
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0037
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0012
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0077
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0096
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0071
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PA1001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0005
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0081
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0026
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0012
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS1001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0294
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0292
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0089
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0006
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA1007
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0053
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0084
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PE0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0054
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0063
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA1006
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA1003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0789
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0277
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0062
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0010
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA1001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0021
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0085
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0020
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RR0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0023
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0017
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0022
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0055
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0019
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0733
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0279
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0258
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0226
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0028
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS0015
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0039
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0011
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PA1002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0019
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0287
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0116
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS0012
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PE0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0012
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0008
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0086
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0032
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0290
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0063
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0059
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0050
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0079
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0066
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0098
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0117
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0289
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0039
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0021
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0092
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PB0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0015
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0034
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0031
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0006
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA0005
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0119
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MS0003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0264
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0054
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS0017
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0016
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0027
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS0019
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0068
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0029
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0012
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0281
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0052
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0086
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0299
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0038
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0295
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PE0003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0073
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0006
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0005
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0013
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0010
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0006
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0064
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0064
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0076
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0058
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA0006
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0018
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0064
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0036
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0266
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MS0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0608
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0007
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0262
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA1002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0042
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0067
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0070
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0270
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0016
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0094
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA1004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0013
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0291
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0018
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0637
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0049
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0296
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0107
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0010
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0114
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0012
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# CE0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0063
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0014
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0025
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0072
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0065
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0027
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0058
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0049
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0273
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0066
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SC0003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0060
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS0021
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SC0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0236
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0292
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# CE0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0043
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0057
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0035
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0221
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SC0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# CE0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0015
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0288
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0022
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PB0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0008
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0009
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0015
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# CE0003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS0020
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0219
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0007
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS0013
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0737
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0260
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0018
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0011
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0055
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0280
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0108
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0611
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0030
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0044
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0099
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0033
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0293
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0298
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0011
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0016
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0078
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0014
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0013
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA1005
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS0006
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0256
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0069
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0269
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0033
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0074
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0040
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0080
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PB0003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0047
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0030
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0106
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS0018
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0008
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# DF0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0113
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0011
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0014
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS0016
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0102
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0263
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0276
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0111
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0017
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0009
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0036
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0032
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA0003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PE0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0297
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0007
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0087
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# DF0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0010
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0061
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0019
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0061
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0110
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0091
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0254
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0023
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0060
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0097
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0026
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0105
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0067
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0009
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0056
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS0005
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0034
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0008
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0259
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0005
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0100
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0268
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0025
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0090
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0005
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0101
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0045
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0088
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0075
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0038
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0109
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0112
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0032
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0028
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0007
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0011
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0010
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA1002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0034
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA1001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0009
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0007
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0006
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0109
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0012
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0025
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0059
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0015
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0005
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0789
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS0018
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0031
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0038
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0052
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0068
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0065
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0217
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS0016
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0098
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0033
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0083
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MS0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0008
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0005
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0011
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RR0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0035
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PB0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0269
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0047
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0040
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0260
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0279
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0073
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0012
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0014
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0021
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0019
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0014
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0069
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0262
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PA1002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0012
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0266
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0070
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0010
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0293
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0019
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0005
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0096
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0020
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0039
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0022
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0008
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0029
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA0005
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0012
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0023
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0013
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0051
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0027
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MS0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0007
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# DF0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0294
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0050
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0024
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0007
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0063
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0020
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0108
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0010
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0023
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0280
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0044
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0277
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0008
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0018
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0272
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0273
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA1005
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# CE0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RS0022
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0072
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0099
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0016
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0086
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0017
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RR0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0060
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0103
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0097
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0005
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA0006
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0281
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0060
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PB0003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0015
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0022
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0013
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0116
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0017
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0013
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0016
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0095
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0061
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# CE0003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0058
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0008
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0006
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0291
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA1004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SC0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0012
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0015
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0009
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0011
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PA1001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0025
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0053
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0018
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0049
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA1003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0289
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0064
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0018
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0054
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0284
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RN1001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0113
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0017
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0011
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0120
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0057
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PA1003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PE0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0637
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA0003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# CE0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PB0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0009
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA1007
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0071
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0275
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0216
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SC0004
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0049
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0054
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0020
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MA0001
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0048
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0014
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0003
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0009
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0015
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0263
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0013
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0036
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0018
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# DF0002
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0066
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0008
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0087
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0016
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0085
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# PR0019
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0270
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# RJ0061
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0288
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0014
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0292
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0091
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# BA0014
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0264
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# ES0012
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# MG0055
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# SP0114
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []
# AC0006
# Empty DataFrame
# Columns: [ESTADO, CIDADE, COD_CIDADE, NOME_ESTACAO, ID_MMA, LATITUDE, LONGITUDE]
# Index: []

# %%
estacao
# Out:
# 'AC0006'

# %%
estacao
# Out:
# 'PR0006'

# %% [markdown]
# # Representatividade Temporal

# %%
import pandas as pd
import os
import numpy as np

os.chdir('/home/nobre/Notebooks/RQAR_2025_book/')

df_rep_temporal = pd.DataFrame({
    'POLUENTES': ['MP10','MP25','SO2','NO2','O3','FMC','CO','PTS','Pb'],
    'DIA': ['24','24','24','1','8','24','8','1',''],
    'MES': ['mensal','mensal','mensal','mensal','mensal','mensal','mensal','mensal_geom','mensal'],
    'ANO': ['anual','anual','anual','anual','anual','anual','anual','anual_geom','anual']
}).set_index("POLUENTES")

print(df_rep_temporal)

# %%
for ano, dados in df_dia.groupby(['ANO']):
    print(ano)
    qntd_valor = dados['VALOR'].notna().sum()
    if (ano[0] % 4 == 0 and ano[0] % 100 != 0) or (ano[0] % 400 == 0):
        dias = 366
    else:
        dias = 365
    prcnt_rep = (100*qntd_valor/dias)
    print(prcnt_rep)

# %%
def rep_temp(df,agrupamento,criterio,periodo_ref):

    resultados = []
    
    for chave, dados in df.groupby(agrupamento):
        qntd_valor = dados['VALOR'].notna().sum()  

        if criterio == 'HORA':
            qntd_tempo = 24
        elif criterio == 'DIA':
            if chave[1] in [4,6,9,11]:
                qntd_tempo = 30
            elif chave[1] in [1,3,5,7,8,10,12]:
                qntd_tempo = 31
            else:
                if (chave[0] % 4 == 0 and chave[0] % 100 != 0) or (chave[0] % 400 == 0):
                    qntd_tempo = 29
                else:
                    qntd_tempo = 28
        
        if qntd_valor >= (2/3) * qntd_tempo:
            if periodo_ref == "8horas":
                media = dados["VALOR"].rolling(window=8, min_periods=1).mean().max()
            else:
                media = periodo_ref(dados["VALOR"])
            rep = True
        else:
            media = np.nan   
            rep = False

        prcnt = 100*qntd_valor/qntd_tempo

        resultados.append((*chave, media, rep, prcnt))

    return resultados

def conta_dias_quadrimestre(ano,quadrimestre):

    if quadrimestre == 1:
        if (ano % 4 == 0 and ano % 100 != 0) or (ano % 400 == 0):
            dias = 121
        else:
            dias = 120
    elif quadrimestre == 2:
        dias = 123
    else:
        dias = 122

    return dias

def rep_temp_ano(df,agrupamento,criterio):

    resultados = []
    
    for chave, dados in df.groupby(agrupamento):
        qntd_valor = dados['VALOR'].notna().sum()
        qntd_tempo = conta_dias_quadrimestre(chave[0],chave[1])         
        
        if qntd_valor >= (1/2) * qntd_tempo:
            rep = True
        else:
            rep = False
    
        resultados.append((*chave, rep))

    return resultados
    
df_estacoes_rep_temporal = pd.DataFrame({
                    'ID_MMA_COMPLETO':[],
                    'PRCNT_REP_DIA':[],
                    'PRCNT_REP_MES':[],
                    'PRCNT_REP_ANO':[]
                })
                
for pol in df_rep_temporal.index:
    
    path = os.getcwd()+'/data/MQAr/' + pol + '/'

    print(pol)
    
    if os.path.isdir(path) and os.listdir(path):
        
        arquivos = os.listdir(path)
    
        for estacao in arquivos:

            if estacao.endswith('.csv'):

                print(estacao)

                df = pd.read_csv(path+estacao)

                df["VALOR"] = pd.to_numeric(df["VALOR"], errors="coerce")

                resultados_24 = rep_temp(df,['ANO','MES','DIA'],'HORA',np.mean)

                df_24 = pd.DataFrame(resultados_24, columns=['ANO', 'MES', 'DIA', 'VALOR', 'REP_DIA','PRCNT_REP'])

                df_24['DATETIME'] = pd.to_datetime(
                        dict(year=df_24["ANO"], month=df_24["MES"], day=df_24["DIA"])
                    )
            
                df_24 = df_24[['DATETIME','ANO','MES','DIA','VALOR','REP_DIA','PRCNT_REP']]

                if df_rep_temporal['DIA'][pol] == 'dia':
                    df_dia = df_24
                elif df_rep_temporal['DIA'][pol] == '8horas':
                    resultados_dia = rep_temp(df,['ANO','MES','DIA'],'HORA','8horas')

                    df_dia = pd.DataFrame(resultados_dia, columns=['ANO', 'MES', 'DIA', 'VALOR', 'REP_DIA','PRCNT_REP'])

                    df_dia['DATETIME'] = pd.to_datetime(dict(year=df_dia["ANO"], month=df_dia["MES"], day=df_dia["DIA"]))

                    df_dia = df_dia[['DATETIME','ANO','MES','DIA','VALOR','REP_DIA','PRCNT_REP']]
                        
                else:
                    resultados_dia = rep_temp(df,['ANO','MES','DIA'],'HORA',np.max)

                    df_dia = pd.DataFrame(resultados_dia, columns=['ANO', 'MES', 'DIA', 'VALOR', 'REP_DIA','PRCNT_REP'])

                    df_dia['DATETIME'] = pd.to_datetime(dict(year=df_dia["ANO"], month=df_dia["MES"], day=df_dia["DIA"]))

                    df_dia = df_dia[['DATETIME','ANO','MES','DIA','VALOR','REP_DIA','PRCNT_REP']]

                df_dia.to_csv(os.getcwd()+'/data/MQAr_averages/'+df_rep_temporal['DIA'][pol]+'/'+pol+'/'+estacao,index=False)

                resultados_mes = rep_temp(df_24,['ANO','MES'],'DIA',np.mean)

                df_mes = pd.DataFrame(resultados_mes, columns=['ANO', 'MES', 'VALOR', 'REP_MES','PRCNT_REP'])

                df_mes['DATETIME'] = pd.to_datetime(dict(year=df_mes["ANO"], month=df_mes["MES"], day=1))
            
                df_mes = df_mes[['DATETIME','ANO','MES','VALOR','REP_MES','PRCNT_REP']]

                df_mes.to_csv(os.getcwd()+'/data/MQAr_averages/'+df_rep_temporal['MES'][pol][:6]+'/'+pol+'/'+estacao,index=False)

                condicoes = [
                    (df_dia['MES'] <= 4),
                    (df_dia['MES'] >= 5) & (df_dia['MES'] <= 8),
                    (df_dia['MES'] >= 9)
                ]
                
                quadrimestre = [1, 2, 3]
                
                df_dia['QUADRIMESTRE'] = np.select(condicoes, quadrimestre)

                resultados_quad = rep_temp_ano(df_dia,['ANO','QUADRIMESTRE'],'QUADRIMESTRE')

                df_quad = pd.DataFrame(resultados_quad, columns=['ANO', 'QUADRIMESTRE', 'REP_QUAD'])
                
                df_ano_quad = df_quad.groupby("ANO", as_index=False).agg({"REP_QUAD": lambda x: x.sum() == 3})

                resultados = []
                
                for ano, dados in df_dia.groupby(['ANO']):
                    qntd_valor = dados['VALOR'].notna().sum()
                    if (ano[0] % 4 == 0 and ano[0] % 100 != 0) or (ano[0] % 400 == 0):
                        dias = 366
                    else:
                        dias = 365
                    prcnt_rep = (100*qntd_valor/dias)
                    if df_ano_quad.loc[df_ano_quad["ANO"] == ano[0], "REP_QUAD"].values[0] == True:
                        media = dados['VALOR'].mean()
                        rep = True
                    else:
                        media = np.nan
                        rep = False
                    resultados.append((*ano, media, rep, prcnt_rep))
                
                df_ano = pd.DataFrame(resultados, columns=['ANO', 'VALOR','REP_ANO','PRCNT_REP'])
                
                df_ano['DATETIME'] = pd.to_datetime(dict(year=df_ano["ANO"], month=1, day=1))
            
                df_ano = df_ano[['DATETIME','ANO','VALOR','REP_ANO','PRCNT_REP']]

                df_ano.to_csv(os.getcwd()+'/data/MQAr_averages/'+df_rep_temporal['ANO'][pol][:5]+'/'+pol+'/'+estacao, index=False)

                prcnt_dia = 100 * df_dia['VALOR'].notna().sum() / len(df_dia)
                prcnt_mes = 100 * df_mes['VALOR'].notna().sum() / len(df_mes)
                prcnt_ano = 100 * df_ano['VALOR'].notna().sum() / len(df_ano)

                prcnt_estacao = {'ID_MMA_COMPLETO': estacao[:-4], 'PRCNT_REP_DIA': prcnt_dia, 'PRCNT_REP_MES': prcnt_mes, 'PRCNT_REP_ANO': prcnt_ano}

                df_estacoes_rep_temporal = pd.concat([df_estacoes_rep_temporal, pd.DataFrame([prcnt_estacao])], ignore_index=True)

df_estacoes_rep_temporal.to_csv(os.getcwd()+'/data/MQAr_averages/REP_TEMPORAL.csv', index=False)

# %%
df_estacoes_rep_temporal

# %%
estacao

# %%
condicoes = [
    (df_dia['MES'] <= 4),
    (df_dia['MES'] >= 5) & (df_dia['MES'] <= 8),
    (df_dia['MES'] >= 9)
]

quadrimestre = [1, 2, 3]

df_dia['QUADRIMESTRE'] = np.select(condicoes, quadrimestre)

resultados_quad = rep_temp_ano(df_dia,['ANO','QUADRIMESTRE'],'QUADRIMESTRE')

df_quad = pd.DataFrame(resultados_quad, columns=['ANO', 'QUADRIMESTRE', 'REP_QUAD'])

df_ano_quad = df_quad.groupby("ANO", as_index=False).agg({"REP_QUAD": lambda x: x.sum() == 3})

# %%
df_ano

# %%
df_pivot = df_mes.pivot(index='ANO', columns='MES', values='PRCNT_REP')

df_pivot = df_pivot.reindex(sorted(df_pivot.columns), axis=1)

df_pivot = df_pivot.reset_index()

df_pivot

# %%
df = pd.read_csv(os.getcwd()+'/data/MQAr/MP10/ES0001RA001.csv')

def create_QAQCMMA_VALOR(df,pol):

    df = df.rename(columns={'VALOR':'VALOR_ORIGINAL'})

    flags_invalidos = ['!', 'IF', 'IO', 'IC', 'I%', 'IL', 'IE', 'IS', 'IU', 'IM', 'IP', 'ID', 'IT', 'IR', 
                       'Fora da Faixa de Medição', 'Disabilitada Temporariamente', 'Inválido', 
                       'Insuficientes', 'Inexistente']

    df['QAQC_INTERNO'] = ~df['QAQC_INTERNO'].isin(flags_invalidos)
    
    DEFAULT_RANGE_LIMITS = {
        "O3": (0, 500),
        "CO": (0, 50),
        "NO2": (0, 1000),
        "NOX": (0, 2000),
        "SO2": (0, 1000),
        "MP25": (0, 1000),
        "MP10": (0, 2000),
    }

    df['QAQC_MMA'] = df['QAQC_INTERNO']

    if pol in list(DEFAULT_RANGE_LIMITS.keys()):
        lim_min = DEFAULT_RANGE_LIMITS[pol][0]
        lim_max = DEFAULT_RANGE_LIMITS[pol][1]
    else:
        lim_min = 0
        lim_max = np.inf

    df['VALOR'] = df['VALOR_ORIGINAL']

    df['VALOR'] = pd.to_numeric(df['VALOR'], errors='coerce')
    
    df.loc[df['QAQC_MMA'] & (df['VALOR'].isna() | (df['VALOR'] < lim_min) | (df['VALOR'] > lim_max)), 'QAQC_MMA'] = False
    
    df.loc[~df['QAQC_MMA'], 'VALOR'] = np.nan
    
    df = df[['DATETIME', 'ANO', 'MES', 'DIA', 'HORA', 'VALOR', 'VALOR_ORIGINAL', 'UNIDADE', 'QAQC_INTERNO', 'QAQC_MMA']]

    return df

# %%
DEFAULT_RANGE_LIMITS = {
        "O3": (0, 500),
        "CO": (0, 50),
        "NO2": (0, 1000),
        "NOX": (0, 2000),
        "SO2": (0, 1000),
        "MP25": (0, 1000),
        "MP10": (0, 2000),
    }

DEFAULT_RANGE_LIMITS['MP10'][1]

# %%
list(DEFAULT_RANGE_LIMITS.keys())

# %%
pol = 'CCCC'

df['QAQC_MMA'] = df['QAQC_INTERNO']

if pol in list(DEFAULT_RANGE_LIMITS.keys()):
    lim_min = DEFAULT_RANGE_LIMITS[pol][0]
    lim_max = DEFAULT_RANGE_LIMITS[pol][1]
else:
    lim_min = 0
    lim_max = np.inf

# %%
df['VALOR'] = df['VALOR_ORIGINAL']

df['VALOR'] = pd.to_numeric(df['VALOR'], errors='coerce')

df.loc[df['QAQC_MMA'] & (df['VALOR'].isna() | (df['VALOR'] < lim_min) | (df['VALOR'] > lim_max)), 'QAQC_MMA'] = False

df.loc[~df['QAQC_MMA'], 'VALOR'] = np.nan

df = df[['DATETIME', 'ANO', 'MES', 'DIA', 'HORA', 'VALOR', 'VALOR_ORIGINAL', 'UNIDADE', 'QAQC_INTERNO', 'QAQC_MMA']]

# %%
df.columns

# %%
import pandas as pd
import os
from collections import defaultdict
from datetime import datetime, timedelta
import re
import numpy as np
from pathlib import Path

def ppb_to_ug(df,pol):

    if pol == 'so2':

        df.loc[df["Unidade"] != "ug/m3", "Valor"] *= 2661260.49/10**6        

    elif pol == 'no2':

        df.loc[df["Unidade"] != "ug/m3", "Valor"] *= 1911038.92/10**6        

    elif pol == 'o3':

        df.loc[df["Unidade"] != "ug/m3", "Valor"] *= 1993889.17/10**6        
    
    df.loc[:, "Unidade"] = "ug/m3"

    return df

def rectify_MT(path):

    dict_pols_stat = defaultdict(list)

    files = os.listdir(path)
    
    print(files)
    
    for item in files:
        
        estacao = " ".join(item.split('-')[1].split('.')[0].split('_')[0:2])
    
        print(estacao)
    
        df = pd.read_excel(path+item)
    
        df = df.drop(columns=['Nome da estação'])
    
        lista_pols = set(df['Poluente'])
    
        for pol in lista_pols:
    
            df_pol = df[df["Poluente"] == pol]
            
            if pol in ['no2','so2','o3']:
    
                df_pol = ppb_to_ug(df_pol,pol)
    
            df_pol_hora = df_pol.groupby(["Ano", "Mes", "Dia", "Hora", "Unidade"])
            
            df_pol_hora = df_pol_hora.filter(lambda g: len(g) >= 9)
            
            df_pol = (
                df_pol_hora.groupby(["Ano", "Mes", "Dia", "Hora", "Unidade"], as_index=False)
                      .agg({"Valor": "mean"})
            )
    
            df_pol['QAQC_INTERNO'] = None
    
            df_pol = df_pol.rename(columns={'Ano':'ANO',
                                            'Mes':'MES',
                                            'Dia':'DIA',
                                            'Hora':'HORA',
                                            'Unidade':'UNIDADE',
                                            'Valor':'VALOR'})
    
            for col in ["ANO", "MES", "DIA", "HORA"]:
                df_pol[col] = pd.to_numeric(df_pol[col], errors="coerce").astype("Int64")
            
            dict_pols_stat[estacao+'_'+pol].append(df_pol)

    dict_pols_MT = {
        'co':'CO',
        'no2': 'NO2',
        'so2': 'SO2',
        'o3': 'O3',
        'pm2p5':'MP25',
        'pm10': 'MP10'
    }

    dict_formatado = {}
    
    for chave in dict_pols_stat.keys():
        
        lista_dfs = dict_pols_stat[chave]
        
        df = pd.concat(lista_dfs, ignore_index=True)
    
        df["DATETIME"] = pd.to_datetime(
            df.apply(lambda r: f"{r.ANO}-{r.MES}-{r.DIA} {r.HORA}:00:00", axis=1)
        )
        df = df.set_index("DATETIME")
    
        df = df.sort_index()
        
        lista_horas = pd.date_range(
            start=df.index.min(), 
            end=df.index.max(), 
            freq='H').strftime('%Y-%m-%d %H:%M:%S').tolist()
        
        if len(lista_horas) != len(df):
            df = df.reindex(pd.DatetimeIndex(lista_horas))
    
        df['DATETIME'] = df.index
    
        df = df[['DATETIME','ANO','MES','DIA','HORA','VALOR','UNIDADE','QAQC_INTERNO']]
        
        dict_formatado[chave] = df
        
        primeiros_valores = {}
    
    for chave, df in dict_formatado.items():
        
        if ~df['VALOR'].isna().all() and (df['VALOR'] > 0).any(): 
            
            linha_valida = df[df["VALOR"].notna() & (df["VALOR"] > 0)].iloc[0]
            primeiros_valores[chave] = linha_valida["DATETIME"]
    
    codigo_estacao_MT = {}
    
    for chave in primeiros_valores.keys():
        
        station = chave.split('_')[0]
        data = primeiros_valores[chave]
        
        if station in codigo_estacao_MT:
            if data <= codigo_estacao_MT[station]:
                codigo_estacao_MT[station] = data
        else:
            codigo_estacao_MT[station] = data
    
    sorted_items = sorted(
        codigo_estacao_MT.items(),
        key=lambda x: (x[1], x[0])
    )
    
    codigo_estacao_MT = {}
    for i, (nome, ts) in enumerate(sorted_items, start=1):
        codigo = f"MT{i:04d}"
        codigo_estacao_MT[nome] = codigo
        
    for chave, df in dict_formatado.items():
        
        estacao = codigo_estacao_MT[chave.split('_')[0]]
        
        cod_pol = tabela_pols.loc[tabela_pols['POLUENTE'] == dict_pols_MT[chave.split('_')[-1]], 'COD_POLUENTE'].values[0]
        
        nome_pasta = tabela_pols.loc[tabela_pols['COD_POLUENTE'] == int(cod_pol), 'NOME_PASTA'].values[0]

        df = create_QAQCMMA_VALOR(df,nome_pasta)
        
        df.to_csv('/home/nobre/Notebooks/RQAR_2025_book/data/MQAr/'+nome_pasta+'/'+estacao+'IA'+str(cod_pol).zfill(3)+'.csv',index=False)

    dict_stations_MT = {
        'Sema':'CPA - SEMA - CBA',
        'BEA CBA': 'Dom Aquino - BEA - CBA',
        'CBM VG': 'Água Limpa - CBM - VG',
        'Mae Bonifacia': 'Duque de Caxias - Pq Mãe Bonifácia - CBA',
        'UFMT':'Boa Esperança - UFMT - CBA'
    }
    
    df_ids = pd.DataFrame({
        'ID_OEMA': codigo_estacao_MT.keys(),
        'ID_MMA':list(codigo_estacao_MT.values())})
    
    df_ids["ID_OEMA"] = df_ids["ID_OEMA"].replace(dict_stations_MT)

    print(df_ids)
    
    return df_ids

funcoes = {
    'MT': rectify_MT
}

#lista_estados = ['SC','RS','MT','DF','MA','BA','ES','MG','SP','RJ']
lista_estados = ['MT']

tabela_ids = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/Monitoramento_QAr_BR.csv')
tabela_pols = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/dicionarios/CODIGO_POLUENTES.csv')

for estado in lista_estados:
    
    path = os.getcwd()+'/data/DADOS_BRUTOS/' + estado + '/'

    df_ids = funcoes[estado](path)
    
    create_df_estacao(estado,df_ids)

# %%
df = df_dia.groupby(['ANO'])

# %%
tabela_pols = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/dicionarios/CODIGO_POLUENTES.csv')

# %%
for pol in tabela_pols['NOME_PASTA'].unique():
    print(pol)

# %%
import pandas as pd
import os
from collections import defaultdict
from datetime import datetime, timedelta
import re
import numpy as np
from pathlib import Path

os.chdir('/home/nobre/Notebooks/RQAR_2025_book/')

# %%
funcoes = {
    
    'MT': rectify_MT,
}

lista_estados = ['MT']

tabela_ids = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/Monitoramento_QAr_BR.csv')
tabela_pols = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/dicionarios/CODIGO_POLUENTES.csv')

# %%
estado = 'DF'
  
path = os.getcwd()+'/data/DADOS_BRUTOS/' + estado + '/'

#df_ids = funcoes[estado](path)
    
#create_df_estacao(estado,df_ids)

# %%
dict_pols_stat = defaultdict(list)

files = os.listdir(path)

print(files)

for item in files:
    
    estacao = " ".join(item.split('-')[1].split('.')[0].split('_')[0:2])

    print(estacao)

    df = pd.read_excel(path+item)

    df = df.drop(columns=['Nome da estação'])

    lista_pols = set(df['Poluente'])

    for pol in lista_pols:

        df_pol = df[df["Poluente"] == pol]
        
        if pol in ['no2','so2','o3']:

            df_pol = ppb_to_ug(df_pol,pol)

        df_pol_hora = df_pol.groupby(["Ano", "Mes", "Dia", "Hora", "Unidade"])
        
        df_pol_hora = df_pol_hora.filter(lambda g: len(g) >= 9)
        
        df_pol = (
            df_pol_hora.groupby(["Ano", "Mes", "Dia", "Hora", "Unidade"], as_index=False)
                  .agg({"Valor": "mean"})
        )

        df_pol['QAQC_INTERNO'] = None

        df_pol = df_pol.rename(columns={'Ano':'ANO',
                                        'Mes':'MES',
                                        'Dia':'DIA',
                                        'Hora':'HORA',
                                        'Unidade':'UNIDADE',
                                        'Valor':'VALOR'})

        for col in ["ANO", "MES", "DIA", "HORA"]:
            df_pol[col] = pd.to_numeric(df_pol[col], errors="coerce").astype("Int64")
        
        dict_pols_stat[estacao+'_'+pol].append(df_pol)

# %%
def ppb_to_ug(df,pol):

    if pol == 'so2':

        df.loc[df["Unidade"] != "ug/m3", "Valor"] *= 2661260.49/10**6        

    elif pol == 'no2':

        df.loc[df["Unidade"] != "ug/m3", "Valor"] *= 1911038.92/10**6        

    elif pol == 'o3':

        df.loc[df["Unidade"] != "ug/m3", "Valor"] *= 1993889.17/10**6        
    
    df.loc[:, "Unidade"] = "ug/m3"

    return df

# %%
dict_pols_MT = {
    'co':'CO',
    'no2': 'NO2',
    'so2': 'SO2',
    'o3': 'O3',
    'pm2p5':'MP25',
    'pm10': 'MP10'
}

dict_formatado = {}

for chave in dict_pols_stat.keys():
    
    lista_dfs = dict_pols_stat[chave]
    
    df = pd.concat(lista_dfs, ignore_index=True)

    df["DATETIME"] = pd.to_datetime(
        df.apply(lambda r: f"{r.ANO}-{r.MES}-{r.DIA} {r.HORA}:00:00", axis=1)
    )
    df = df.set_index("DATETIME")

    df = df.sort_index()
    
    lista_horas = pd.date_range(
        start=df.index.min(), 
        end=df.index.max(), 
        freq='H').strftime('%Y-%m-%d %H:%M:%S').tolist()
    
    if len(lista_horas) != len(df):
        df = df.reindex(pd.DatetimeIndex(lista_horas))

    df['DATETIME'] = df.index

    df = df[['DATETIME','ANO','MES','DIA','HORA','VALOR','UNIDADE','QAQC_INTERNO']]
    
    dict_formatado[chave] = df

primeiros_valores = {}

for chave, df in dict_formatado.items():
    
    if ~df['VALOR'].isna().all() and (df['VALOR'] > 0).any(): 
        
        linha_valida = df[df["VALOR"].notna() & (df["VALOR"] > 0)].iloc[0]
        primeiros_valores[chave] = linha_valida["DATETIME"]

codigo_estacao_MT = {}

for chave in primeiros_valores.keys():
    
    station = chave.split('_')[0]
    data = primeiros_valores[chave]
    
    if station in codigo_estacao_MT:
        if data <= codigo_estacao_MT[station]:
            codigo_estacao_MT[station] = data
    else:
        codigo_estacao_MT[station] = data

sorted_items = sorted(
    codigo_estacao_MT.items(),
    key=lambda x: (x[1], x[0])
)

codigo_estacao_MT = {}
for i, (nome, ts) in enumerate(sorted_items, start=1):
    codigo = f"MT{i:04d}"
    codigo_estacao_MT[nome] = codigo
    
for chave, df in dict_formatado.items():
    
    estacao = codigo_estacao_MT[chave.split('_')[0]]
    
    cod_pol = tabela_pols.loc[tabela_pols['POLUENTE'] == dict_pols_MT[chave.split('_')[-1]], 'COD_POLUENTE'].values[0]
    
    nome_pasta = tabela_pols.loc[tabela_pols['COD_POLUENTE'] == int(cod_pol), 'NOME_PASTA'].values[0]
    
    df.to_csv('/home/nobre/Notebooks/RQAR_2025_book/data/MQAr/'+nome_pasta+'/'+estacao+'RA'+str(cod_pol).zfill(3)+'.csv',index=False)

df_ids = pd.DataFrame({
    'ID_OEMA': codigo_estacao_MT.keys(),
    'ID_MMA':list(codigo_estacao_MT.values())})

return df_ids

# %%
df_ids

# %%
from datetime import timedelta

def fix_24h(row):
    if isinstance(row, str) and row.startswith("24:"):
        # substitui 24: por 00:
        new_str = row.replace("24:", "00:", 1)
        # converte para datetime
        dt = pd.to_datetime(new_str, errors="coerce")
        # adiciona 1 dia
        if pd.notna(dt):
            dt += timedelta(days=1)
        return dt
    else:
        return pd.to_datetime(row, errors="coerce")

# %%
dict_stations_MT = {
        'Sema':'CPA - SEMA - CBA',
        'BEA CBA': 'Dom Aquino - BEA - CBA',
        'CBM VG': 'Água Limpa - CBM - VG',
        'Mae Bonifacia': 'Duque de Caxias - Pq Mãe Bonifácia - CBA',
        'UFMT':'Boa Esperança - UFMT - CBA'
    }
    
df_ids = pd.DataFrame({
    'ID_OEMA': codigo_estacao_MT.keys(),
    'ID_MMA':list(codigo_estacao_MT.values())})


df_ids["ID_OEMA"] = df_ids["ID_OEMA"].replace(dict_stations_MT)


df_ids['ID_OEMA']

# %%
df_ids

# %%
estado = 'DF'

# %%
path = os.getcwd()+'/data/DADOS_BRUTOS/' + estado + '/'

path = path + 'Monitor Report 2024_FINAL.xlsx'

df = pd.read_excel(path)

df.iloc[1] = df.iloc[1].ffill()

poluentes = ['CO_ppm','NO2_ug/m3','NO_ug/m3','NOx_ug/m3','O3_ug/m3','PM10','PM25','PTS','SO2_ug/m3']

dict_pols = {'CO_ppm':'CO',
             'NO2_ug/m3':'NO2',
             'NO_ug/m3':'NO',
             'NOx_ug/m3':'NOX',
             'O3_ug/m3':'O3',
             'PM10':'MP10',
             'PM25':'MP25',
             'PTS':'PTS',
             'SO2_ug/m3':'SO2'}

df.columns = df.iloc[1]

df = df.drop(index=[0, 1]).reset_index(drop=True)

df = df.rename(columns={'Date Time':'DATETIME'})

estacoes = set(df.columns[1:])

dict_pols_stat = defaultdict(list)

for estacao in estacoes:

    df_estacao = df[["DATETIME",estacao]]

    df_estacao.columns = [df_estacao.columns.tolist()[0]] + df_estacao.iloc[0, 1:].tolist()

    df_estacao = df_estacao.drop(index=[0]).reset_index(drop=True)

    for pol in poluentes:

        if pol in df_estacao.columns:
            
            df_pol = df_estacao[["DATETIME",pol]]

            df_pol['UNIDADE'] = df_pol[pol][0]

            df_pol = df_pol.drop(index=[0]).reset_index(drop=True)

            df_pol = df_pol[df_pol["DATETIME"].astype(str).str.contains(r"\d", na=False)].reset_index(drop=True)

            df_pol['DATETIME'] = df_pol['DATETIME'].apply(fix_24h)

            df_pol = df_pol.rename(columns={pol:'VALOR'})

            df_pol.index = df_pol['DATETIME']

            lista_horas = pd.date_range(
                start=df_pol.index.min(), 
                end=df_pol.index.max(), 
                freq='H').strftime('%Y-%m-%d %H:%M:%S').tolist()
            
            if len(lista_horas) != len(df_pol):
                df_pol = df_pol.reindex(pd.DatetimeIndex(lista_horas))
            
            df_pol['QAQC_INTERNO'] = None
            
            df_pol.insert(1, 'ANO', df_pol.index.year)
            df_pol.insert(2, 'MES', df_pol.index.month)
            df_pol.insert(3, 'DIA', df_pol.index.day)
            df_pol.insert(4, 'HORA', df_pol.index.hour)

            pol = dict_pols[pol]

            df_pol['VALOR'] = pd.to_numeric(df_pol['VALOR'], errors='coerce')

            df_pol = df_pol[['DATETIME','ANO','MES','DIA','HORA','VALOR','UNIDADE','QAQC_INTERNO']] 

            dict_pols_stat[estacao+'_'+pol] = df_pol

# %%
primeiros_valores = {}

for chave, df in dict_pols_stat.items():  
    
    if ~df['VALOR'].isna().all() and (df['VALOR'] > 0).any(): 
        
        linha_valida = df[df["VALOR"].notna() & (df["VALOR"] > 0)].iloc[0]
        primeiros_valores[chave] = linha_valida["DATETIME"]

codigo_estacao_DF = {}

for chave in primeiros_valores.keys():
    
    station = chave.split('_')[0]
    data = primeiros_valores[chave]
    
    if station in codigo_estacao_DF:
        if data <= codigo_estacao_DF[station]:
            codigo_estacao_DF[station] = data
    else:
        codigo_estacao_DF[station] = data

sorted_items = sorted(
    codigo_estacao_DF.items(),
    key=lambda x: (x[1], x[0])
)

codigo_estacao_DF = {}
for i, (nome, ts) in enumerate(sorted_items, start=1):
    codigo = f"DF{i:04d}"
    codigo_estacao_DF[nome] = codigo
    
for chave, df in dict_pols_stat.items():
    
    estacao = codigo_estacao_DF[chave.split('_')[0]]
    
    cod_pol = tabela_pols.loc[tabela_pols['POLUENTE'] == chave.split('_')[-1], 'COD_POLUENTE'].values[0]
    
    nome_pasta = tabela_pols.loc[tabela_pols['COD_POLUENTE'] == int(cod_pol), 'NOME_PASTA'].values[0]
    
    df.to_csv('/home/nobre/Notebooks/RQAR_2025_book/data/MQAr/'+nome_pasta+'/'+estacao+'RA'+str(cod_pol).zfill(3)+'.csv',index=False)

dict_oemas = {
    'Estação CRAS FERCAL': 'Fercal CRAS',
    'Estação Escola':	   'Fercal Escola'}

df_ids = pd.DataFrame({
    'ID_OEMA': codigo_estacao_DF.keys(),
    'ID_MMA':list(codigo_estacao_DF.values())})

df_ids['ID_OEMA'] = df_ids['ID_OEMA'].replace(dict_oema)

return df_ids

# %%
df_ufs = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/dicionarios/IBGE_UFS_CODIGOS.csv')
    
cod_uf =  df_ufs.loc[df_ufs['UF'] == uf, 'CODIGOS'].values[0]

print(cod_uf)

if os.path.exists('/home/nobre/Notebooks/RQAR_2025_book/data/DADOS_ESTACOES/'+uf+'_estacoes.csv'):

    df_estacao = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/DADOS_ESTACOES/'+uf+'_estacoes.csv')

    df_estacao['ID_MMA'] = df_estacao['ID_OEMA'].map(df_ids.set_index('ID_OEMA')['ID_MMA'])

else:

    colunas = ['ID_OEMA', 'UF', 'ID_MMA', 'COD_UF_IBGE', 'CIDADE', 'CD_MUN',
               'PROPRIETARIO', 'PROP_ENTIDADE', 'OPERADOR', 'OP_ENTIDADE', 'LATITUDE',
               'LONGITUDE', 'MOBILIDADE', 'REALOCACAO', 'MARCA', 'CATEGORIA',
               'FUNCIONAMENTO', 'METODO', 'FINALIDADE', 'POLUENTE',
               'INICIO', 'STATUS', 'FIM', 'CALIBRACAO', 'OBS_CALIBRACAO', 'MONITORAR',
               'FONTE', 'OBS_GERAIS','DADOS_MONITORAMENTO','RECONHECIDA','REP_ESPACIAL_DECLARADA']
    
    df_estacao = pd.DataFrame(columns=colunas)

df_ids = pol_to_station(df_ids)

mapa = dict(zip(df_ids['ID_MMA'], df_ids['POLUENTE']))

df_estacao['POLUENTE'] = df_estacao['ID_MMA'].map(mapa).fillna(df_estacao['POLUENTE'])

#df_estacao = df_estacao.reindex(df_ids.index)

#df_estacao[["ID_MMA", "ID_OEMA", "POLUENTE"]] = df_ids[["ID_MMA", "ID_OEMA", "POLUENTE"]].values

df_estacao.loc[:, "COD_UF_IBGE"] = cod_uf
df_estacao.loc[:, "UF"] = uf
    
#df_estacao.to_csv('/home/nobre/Notebooks/RQAR_2025_book/data/DADOS_ESTACOES/'+uf+'_estacoes_teste.csv', index=False)

# %%
df_estacao['POLUENTE']

# %%
def pol_to_station(df_ids):

    base_path = Path('/home/nobre/Notebooks/RQAR_2025_book/data/MQAr/')

    id_to_poluentes = {}
    
    for poluente_dir in base_path.iterdir():
        if poluente_dir.is_dir():
            poluente = poluente_dir.name
    
            arquivos = [arq.stem for arq in poluente_dir.glob("*")]
    
            for id_mma in df_ids["ID_MMA"]:
                if any(str(arq).startswith(id_mma) for arq in arquivos):
                    id_to_poluentes.setdefault(id_mma, []).append(poluente)
    
    df_ids["POLUENTE"] = df_ids["ID_MMA"].map(id_to_poluentes).fillna("").apply(lambda x: ",".join(x) if isinstance(x, list) else "")
    
    return(df_ids)

# %%
df = pd.read_csv(os.getcwd()+'/data/DADOS_BRUTOS/PR/2017/FOZ2017/2017.xls', sep='\t', engine='python', encoding='latin1', header=2 )

df

# %%
def ler_dados_parana_2024(dicionario,ano):
    
    #caminho =  os.getcwd()+'/data/DADOS_BRUTOS/PR/2024/'

    caminho = os.getcwd()+'/data/DADOS_BRUTOS/PR/'+ano+'/'
    
    arquivos = os.listdir(caminho)
    
    for arquivo in arquivos:
    
        if arquivo.endswith(('.xls', '.xlsx')):
            caminho_arquivo = os.path.join(caminho, arquivo)
            try:
                df = pd.read_excel(caminho_arquivo, header=3)
            except Exception as e:
                print(f"Tentando ler como texto: {arquivo}")
                df = pd.read_csv(caminho_arquivo, sep='\t', engine='python', encoding='latin1', header=2, on_bad_lines='skip')
                
            col_data = next(c for c in df.columns if c.startswith('Data'))
    
            df = (
                df.replace('-', np.nan)
                  .assign(**{c: pd.to_numeric(df[c], errors='coerce') for c in df.columns if c != col_data})
                  .groupby(col_data, as_index=False)
                  .agg(lambda x: x.dropna().iloc[0] if len(x.dropna()) else np.nan)
            )

            if '5MIN' in arquivo:
                estacao = arquivo.split('_')[0]
            else:
                estacao = arquivo.split('2')[0]

            if df.columns[0] == 'Data/Hora':

                print(estacao)

                df = df[pd.to_datetime(df[col_data], errors='coerce').notna()]
    
                dicionario[ano][estacao] = df

            print(len(df))

    return dicionario

def adicionar_colunas_unidade(df):
    unidades = df.iloc[0]
    
    df = df.iloc[1:].reset_index(drop=True)
    
    for col, unidade in unidades.items():
        if pd.notna(unidade):
            df[f"{col}_UNIDADE"] = unidade
    
    return df

def num_para_hora(valor):
    try:
        h = int(valor)
        m = "30" if valor % 1 == 0.5 else "00"
        return f"{h}:{m}"
    except:
        return None
        
    return df

def ler_dados_parana_1998_2002(dicionario,ano):
    
    caminho = os.getcwd()+'/data/DADOS_BRUTOS/PR/'+ano+'/'
        
    arquivos = os.listdir(caminho)
    
    for arquivo in arquivos:

        print(arquivo)
    
        if any(Path(caminho+arquivo).iterdir()):
            pasta = os.listdir(caminho+arquivo)[0]
    
            df = pd.read_excel(caminho+arquivo+'/'+pasta,header=1)

            df = adicionar_colunas_unidade(df)

            for hora in ['H', 'HORA', 'Hora']:
                if hora in df.columns:
                    df[hora] = df[hora].astype(float).apply(num_para_hora)
                    break

            estacao = arquivo[:-4]
    
            dicionario[ano][estacao] = df 

            print(len(df))
    
        else:
            print('Não há nada em '+ caminho+arquivo)

    return dicionario

def ler_dados_mes_a_mes(caminho):

    tipos_arquivos_ignorar = ['.zip','.rar','.xls','.xlsx','.7z','testes','2016','.ipynb_checkpoints']

    df = pd.DataFrame()

    #print(caminho)
    #print(sorted(os.listdir(caminho)))

    estacao = caminho.split('/')[-2].split('2')[0]
    
    for arquivo in sorted(os.listdir(caminho)):
        df_mes = pd.DataFrame()
    
        if not any(p in arquivo for p in tipos_arquivos_ignorar) or any(p in arquivo for p in ['txt']):

            if '.txt' in arquivo:
                df_mes = pd.read_csv(caminho+arquivo, sep='\t', engine='python', encoding='latin1')
                #print(df_mes.head())
                #print(arquivo)
                df = pd.concat([df, df_mes], ignore_index=True)
            
            else:
                mes = arquivo[:2]
                base_path = os.path.join(caminho, arquivo)
                
                nomes_possiveis = [
                    [f"{estacao}1H_{mes}_{ano}.txt",0],
                    [f"{estacao}1H.txt",0],
                    [f"{estacao}1H_{mes}_{ano}.xls",3],
                    [f"{estacao}_1H.xls",2]
                ]

                for nome in nomes_possiveis:
                    full_path = os.path.join(base_path, nome[0])
                    
                    try:
                        df_mes = pd.read_csv(full_path, sep='\t', engine='python', encoding='latin1',header=nome[1])
                        break
                    except Exception:
                        try:
                            df_mes = pd.read_excel(full_path, engine='xlrd',header=nome[1])
                            break
                        except Exception:
                            continue

            if len(df_mes) == 0:

                print(caminho)
                #print(sorted(os.listdir(caminho)))
                #print(arquivo)
                print(df_mes.head())
                print('')
                
            df = pd.concat([df, df_mes], ignore_index=True)

            #df = pd.concat([df, df_mes], ignore_index=True)
           
    
    print('')
            
    
    return df

def verifica_numero(num):
    try:
        if num != np.nan:
            float(num)
            return True
    except (ValueError, TypeError):
        return False

def verifica_data(data):
    try:
        pd.to_datetime(data)
        return True
    except (ValueError, TypeError):
        return False

def ler_dados_parana_2003_2019(dicionario,ano):

    pastas_ignorar = ['IQA diário','IQA_IAP','2016','ARAUCARIA2018','ARAUCARIA2019','Thumbs.db','~$Validação_Maio_2014.xlsm','SIX1H_2017.zip','.ipynb_checkpoints']

    caminho = os.getcwd()+'/data/DADOS_BRUTOS/PR/'+ano+'/'
        
    arquivos = os.listdir(caminho)

    print('')
    print(ano)
    
    for arquivo in arquivos:

        if arquivo not in pastas_ignorar:

            print(arquivo)
            
            if any(nome.endswith(('.xls', '.xlsx')) for nome in os.listdir(caminho+arquivo)) and len(os.listdir(caminho+arquivo)) <= 3:
                print(os.listdir(caminho+arquivo))

                xlsx = [f for f in os.listdir(caminho+arquivo) if f.endswith('.xlsx')]
                xls = [f for f in os.listdir(caminho+arquivo) if f.endswith('.xls')]
                
                if xlsx:
                    estacao = xlsx[0] 
                elif xls:
                    estacao = xls[0]

                try:
                    if ano == '2003':
                        df = pd.read_excel(caminho+arquivo+'/'+estacao,header=1)
                    elif estacao == 'CIC2019.xlsx':
                        df = pd.read_excel(caminho+arquivo+'/'+estacao,header=2)
                    else:
                        df = pd.read_excel(caminho+arquivo+'/'+estacao)
                except Exception as e:
                    print(f"Tentando ler como texto: {arquivo}")
                    df = pd.read_csv(caminho+arquivo+'/'+estacao, sep='\t', engine='python', encoding='latin1', header=2)
                
                if not (verifica_numero(df[df.columns[0]].iloc[0]) or verifica_data(df[df.columns[0]].iloc[0])) or arquivo == 'SIX2017':

                    df = adicionar_colunas_unidade(df)

                print(len(df))
                    
                dicionario[ano][arquivo[:-4]] = df 

            elif 'IAP' not in arquivo:

                try:
                        
                    df = ler_dados_mes_a_mes(caminho+arquivo+'/')
                    
                    if not (verifica_numero(df[df.columns[0]].iloc[0]) or verifica_data(df[df.columns[0]].iloc[0])):
    
                        df = adicionar_colunas_unidade(df)
                
                    dicionario[ano][arquivo[:-4]] = df 

                    print(len(df))

                except Exception as e:
                    print(f"A seguinte pasta não existe: {caminho}{arquivo}")
                    
    return(dicionario)

# %%
len(pd.DataFrame())

# %%
estacoes_por_ano = {
    '1998': {},
    '1999': {},
    '2000': {},
    '2001': {},
    '2002': {},
    '2003': {},
    '2004': {},
    '2005': {},
    '2006': {},
    '2007': {},
    '2008': {},
    '2009': {},
    '2010': {},
    '2011': {},
    '2012': {},
    '2013': {},
    '2014': {},
    '2015': {},
    '2016': {},
    '2017': {},
    '2018': {},
    '2019': {},
    '2020': {},
    '2021': {},
    '2022': {},
    '2023': {},
    '2024': {}
}

for ano in ['1998','1999','2000',
            '2001','2002','2003','2004','2005','2006','2007','2008','2009','2010',
            '2011','2012','2013','2014','2015','2016','2017','2018','2019','2024']:

    if ano in ['1998','1999','2000','2001','2002']:
        estacoes_por_ano = ler_dados_parana_1998_2002(estacoes_por_ano,ano)
    elif ano in ['2003','2004','2005','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']:
        estacoes_por_ano = ler_dados_parana_2003_2019(estacoes_por_ano,ano)
    elif ano in ['2024']:
        estacoes_por_ano = ler_dados_parana_2024(estacoes_por_ano,ano)

# %%
lista = []

def parse_datetime(x):
    for fmt in ('%Y-%m-%d %H:%M:%S', '%d/%m/%Y %H:%M', '%m/%d/%Y %I:%M:%S %p'):
        try:
            return pd.to_datetime(x, format=fmt)
        except:
            continue
    return pd.to_datetime(x, errors='coerce')
                
def criar_datetime(df,tipo):

    if tipo == 'D':

        df['A'] = pd.to_numeric(df['A'], errors='coerce')

        if df['A'].iloc[0] < 2000:

            df['A'] = df['A'] + 2000
                
        df['H'] = df['H'].astype(str).str.split(':').str[0]
        
        df[['A', 'M', 'D', 'H']] = df[['A', 'M', 'D', 'H']].apply(pd.to_numeric, errors='coerce')
        
        df['datetime'] = pd.to_datetime(
            dict(year=df['A'], month=df['M'], day=df['D'], hour=df['H'].clip(upper=23)),
            errors='coerce'
        )
        
        df.loc[df['H'] == 24, 'datetime'] = df.loc[df['H'] == 24, 'datetime'] + pd.Timedelta(hours=1)
    
    elif tipo == 'DATA':

        df['datetime'] = pd.to_datetime(df['DATA']) + pd.to_timedelta(df['HORA'] + ':00')

        df = df.drop(columns=[c for c in ['ANO', 'MES', 'DIA', 'HORA'] if c in df.columns])
    
    elif tipo == 'Data':

        try:
            df['Data'] = pd.to_datetime(df['Data']).dt.date
        except:
            print(1)

        print(df.loc[df['Data'].astype(str).str.contains('--', na=False)])

        df['datetime'] = pd.to_datetime(df['Data']) + pd.to_timedelta(df['Hora'] + ':00')

    elif tipo == 'Data/Hora':
        
        df['Data/Hora'] = df['Data/Hora'].apply(parse_datetime)
        
        df['Data/Hora'] = df['Data/Hora'].dt.strftime('%Y-%m-%d %H:%M:%S')

        df['datetime'] = pd.to_datetime(df['Data/Hora'])

    elif tipo == 'Date/Time':
        
        df['Date/Time'] = df['Date/Time'].apply(parse_datetime)
        
        df['Date/Time'] = df['Date/Time'].dt.strftime('%Y-%m-%d %H:%M:%S')

        df['datetime'] = pd.to_datetime(df['Date/Time'])
        
    df = df.set_index("datetime")

    df = df.sort_index()
    
    df.insert(0, 'DATETIME', df.index)
    df.insert(1, 'ANO', df.index.year)
    df.insert(2, 'MES', df.index.month)
    df.insert(3, 'DIA', df.index.day)
    df.insert(4, 'HORA', df.index.hour)

    return df

lista_colunas = []

for ano in estacoes_por_ano.keys():
    
    print(ano)

    for estacao in estacoes_por_ano[ano].keys():

        #print(estacao)
        
        lista.append(estacao)

        lista_colunas = lista_colunas + list(estacoes_por_ano[ano][estacao].columns)
        
        if any(item in ['D','DATA','Data','Date/Time','Data/Hora'] for item in estacoes_por_ano[ano][estacao].columns):

            if 'D' in estacoes_por_ano[ano][estacao].columns:
                print('D')
                #estacoes_por_ano[ano][estacao] = criar_datetime(estacoes_por_ano[ano][estacao], 'D')
                #print(estacoes_por_ano[ano][estacao])
            elif 'DATA' in estacoes_por_ano[ano][estacao].columns:
                print('DATA')
                #estacoes_por_ano[ano][estacao] = criar_datetime(estacoes_por_ano[ano][estacao], 'DATA')
                #print(estacoes_por_ano[ano][estacao])
            elif 'Data' in estacoes_por_ano[ano][estacao].columns:
                print('Data')
                #estacoes_por_ano[ano][estacao] = criar_datetime(estacoes_por_ano[ano][estacao], 'Data')
                #print(estacoes_por_ano[ano][estacao])
            elif 'Date/Time' in estacoes_por_ano[ano][estacao].columns:
                print('Date/Time')
                #estacoes_por_ano[ano][estacao] = criar_datetime(estacoes_por_ano[ano][estacao], 'Date/Time')
                #print(estacoes_por_ano[ano][estacao])
            elif 'Data/Hora' in estacoes_por_ano[ano][estacao].columns:
                print('Data/Hora')
                #estacoes_por_ano[ano][estacao] = criar_datetime(estacoes_por_ano[ano][estacao], 'Data/Hora')
                #print(estacoes_por_ano[ano][estacao])
            else:
                print('ERRO')
    print('')

'''
lista1 = sorted(set(lista))

lista_pr = pd.read_csv(os.getcwd() + '/data/DADOS_ESTACOES/PR_estacoes.csv')

lista2 = sorted(lista_pr['ID_OEMA'])

iguais = sorted(set(lista1) & set(lista2))

so_lista1 = [x for x in lista1 if x not in iguais]
so_lista2 = [x for x in lista2 if x not in iguais]

col1 = iguais + so_lista1 + [np.nan] * len(so_lista2)
col2 = iguais + [np.nan] * len(so_lista1) + so_lista2

df = pd.DataFrame({'PR_dados': col1, 'PR_estacao': col2})

df'''

print(lista_colunas)
print(len(list(set(lista_colunas))))

# %%
estacoes_dicionario.keys()

for chave in estacoes_dicionario.keys():

    print(chave)
    print(len(estacoes_dicionario[chave]))
    print(estacoes_dicionario[chave].columns[0])
    print(estacoes_dicionario[chave].iloc[0, 0])
    print(estacoes_dicionario[chave].iloc[-1, 0])
    print("")

    estacoes_por_ano

# %%
list(estacoes_por_ano[ano][estacao].columns)

# %%
def rep_temp(df,agrupamento,criterio,periodo_ref):

    resultados = []
    
    for chave, dados in df.groupby(agrupamento):
        qntd_valor = dados['VALOR'].notna().sum()  

        if criterio == 'HORA':
            qntd_tempo = 24
        elif criterio == 'DIA':
            if chave[1] in [4,6,9,11]:
                qntd_tempo = 30
            elif chave[1] in [1,3,5,7,8,10,12]:
                qntd_tempo = 31
            else:
                if (chave[0] % 4 == 0 and chave[0] % 100 != 0) or (chave[0] % 400 == 0):
                    qntd_tempo = 29
                else:
                    qntd_tempo = 28
        
        if qntd_valor >= (2/3) * qntd_tempo:
            if periodo_ref == "8horas":
                media = dados["VALOR"].rolling(window=8, min_periods=1).mean().max()
            else:
                media = periodo_ref(dados["VALOR"])
            rep = True
        else:
            media = np.nan   
            rep = False

        prcnt = 100*qntd_valor/qntd_tempo

        resultados.append((*chave, media, rep, prcnt))

    return resultados

def conta_dias_quadrimestre(ano,quadrimestre):

    if quadrimestre == 1:
        if (ano % 4 == 0 and ano % 100 != 0) or (ano % 400 == 0):
            dias = 121
        else:
            dias = 120
    elif quadrimestre == 2:
        dias = 123
    else:
        dias = 122

    return dias

def rep_temp_ano(df,agrupamento,criterio):

    resultados = []
    
    for chave, dados in df.groupby(agrupamento):
        qntd_valor = dados['VALOR'].notna().sum()
        qntd_tempo = conta_dias_quadrimestre(chave[0],chave[1])         
        
        if qntd_valor >= (1/2) * qntd_tempo:
            rep = True
        else:
            rep = False
    
        resultados.append((*chave, rep))

    return resultados
    
df_estacoes_rep_temporal = pd.DataFrame({
                    'ID_MMA_COMPLETO':[],
                    'PRCNT_REP_DIA':[],
                    'PRCNT_REP_MES':[],
                    'PRCNT_REP_ANO':[]
                })
                
for pol in df_rep_temporal.index:
    
    path = os.getcwd()+'/data/MQAr/' + pol + '/'

    print(pol)
    
    if os.path.isdir(path) and os.listdir(path):
        
        arquivos = os.listdir(path)
    
        for estacao in arquivos:

            if estacao.endswith('.csv'):

                print(estacao)

                df = pd.read_csv(path+estacao)

                df["VALOR"] = pd.to_numeric(df["VALOR"], errors="coerce")

                resultados_24 = rep_temp(df,['ANO','MES','DIA'],'HORA',np.mean)

                df_24 = pd.DataFrame(resultados_24, columns=['ANO', 'MES', 'DIA', 'VALOR', 'REP_DIA','PRCNT_REP'])

                df_24['DATETIME'] = pd.to_datetime(
                        dict(year=df_24["ANO"], month=df_24["MES"], day=df_24["DIA"])
                    )
            
                df_24 = df_24[['DATETIME','ANO','MES','DIA','VALOR','REP_DIA','PRCNT_REP']]

                if df_rep_temporal['DIA'][pol] == 'dia':
                    df_dia = df_24
                elif df_rep_temporal['DIA'][pol] == '8horas':
                    resultados_dia = rep_temp(df,['ANO','MES','DIA'],'HORA','8horas')

                    df_dia = pd.DataFrame(resultados_dia, columns=['ANO', 'MES', 'DIA', 'VALOR', 'REP_DIA','PRCNT_REP'])

                    df_dia['DATETIME'] = pd.to_datetime(dict(year=df_dia["ANO"], month=df_dia["MES"], day=df_dia["DIA"]))

                    df_dia = df_dia[['DATETIME','ANO','MES','DIA','VALOR','REP_DIA','PRCNT_REP']]
                        
                else:
                    resultados_dia = rep_temp(df,['ANO','MES','DIA'],'HORA',np.max)

                    df_dia = pd.DataFrame(resultados_dia, columns=['ANO', 'MES', 'DIA', 'VALOR', 'REP_DIA','PRCNT_REP'])

                    df_dia['DATETIME'] = pd.to_datetime(dict(year=df_dia["ANO"], month=df_dia["MES"], day=df_dia["DIA"]))

                    df_dia = df_dia[['DATETIME','ANO','MES','DIA','VALOR','REP_DIA','PRCNT_REP']]

                df_dia.to_csv(os.getcwd()+'/data/MQAr_averages/'+df_rep_temporal['DIA'][pol]+'/'+pol+'/'+estacao,index=False)

                resultados_mes = rep_temp(df_24,['ANO','MES'],'DIA',np.mean)

                df_mes = pd.DataFrame(resultados_mes, columns=['ANO', 'MES', 'VALOR', 'REP_MES','PRCNT_REP'])

                df_mes['DATETIME'] = pd.to_datetime(dict(year=df_mes["ANO"], month=df_mes["MES"], day=1))
            
                df_mes = df_mes[['DATETIME','ANO','MES','VALOR','REP_MES','PRCNT_REP']]

                df_mes.to_csv(os.getcwd()+'/data/MQAr_averages/'+df_rep_temporal['MES'][pol][:6]+'/'+pol+'/'+estacao,index=False)

                condicoes = [
                    (df_dia['MES'] <= 4),
                    (df_dia['MES'] >= 5) & (df_dia['MES'] <= 8),
                    (df_dia['MES'] >= 9)
                ]
                
                quadrimestre = [1, 2, 3]
                
                df_dia['QUADRIMESTRE'] = np.select(condicoes, quadrimestre)

                resultados_quad = rep_temp_ano(df_dia,['ANO','QUADRIMESTRE'],'QUADRIMESTRE')

                df_quad = pd.DataFrame(resultados_quad, columns=['ANO', 'QUADRIMESTRE', 'REP_QUAD'])
                
                df_ano_quad = df_quad.groupby("ANO", as_index=False).agg({"REP_QUAD": lambda x: x.sum() == 3})

                resultados = []
                
                for ano, dados in df_dia.groupby(['ANO']):
                    qntd_valor = dados['VALOR'].notna().sum()
                    if (ano[0] % 4 == 0 and ano[0] % 100 != 0) or (ano[0] % 400 == 0):
                        dias = 366
                    else:
                        dias = 365
                    prcnt_rep = (100*qntd_valor/dias)
                    if df_ano_quad.loc[df_ano_quad["ANO"] == ano[0], "REP_QUAD"].values[0] == True:
                        media = dados['VALOR'].mean()
                        rep = True
                    else:
                        media = np.nan
                        rep = False
                    resultados.append((*ano, media, rep, prcnt_rep))
                
                df_ano = pd.DataFrame(resultados, columns=['ANO', 'VALOR','REP_ANO','PRCNT_REP'])
                
                df_ano['DATETIME'] = pd.to_datetime(dict(year=df_ano["ANO"], month=1, day=1))
            
                df_ano = df_ano[['DATETIME','ANO','VALOR','REP_ANO','PRCNT_REP']]

                df_ano.to_csv(os.getcwd()+'/data/MQAr_averages/'+df_rep_temporal['ANO'][pol][:5]+'/'+pol+'/'+estacao, index=False)

                prcnt_dia = 100 * df_dia['VALOR'].notna().sum() / len(df_dia)
                prcnt_mes = 100 * df_mes['VALOR'].notna().sum() / len(df_mes)
                prcnt_ano = 100 * df_ano['VALOR'].notna().sum() / len(df_ano)

                prcnt_estacao = {'ID_MMA_COMPLETO': estacao[:-4], 'PRCNT_REP_DIA': prcnt_dia, 'PRCNT_REP_MES': prcnt_mes, 'PRCNT_REP_ANO': prcnt_ano}

                df_estacoes_rep_temporal = pd.concat([df_estacoes_rep_temporal, pd.DataFrame([prcnt_estacao])], ignore_index=True)

df_estacoes_rep_temporal.to_csv(os.getcwd()+'/data/MQAr_averages/REP_TEMPORAL.csv', index=False)

# %%
df_estacoes_rep_temporal

# %%
estacao

# %%
condicoes = [
    (df_dia['MES'] <= 4),
    (df_dia['MES'] >= 5) & (df_dia['MES'] <= 8),
    (df_dia['MES'] >= 9)
]

quadrimestre = [1, 2, 3]

df_dia['QUADRIMESTRE'] = np.select(condicoes, quadrimestre)

resultados_quad = rep_temp_ano(df_dia,['ANO','QUADRIMESTRE'],'QUADRIMESTRE')

df_quad = pd.DataFrame(resultados_quad, columns=['ANO', 'QUADRIMESTRE', 'REP_QUAD'])

df_ano_quad = df_quad.groupby("ANO", as_index=False).agg({"REP_QUAD": lambda x: x.sum() == 3})

# %%
df_ano

# %%
df_pivot = df_mes.pivot(index='ANO', columns='MES', values='PRCNT_REP')

df_pivot = df_pivot.reindex(sorted(df_pivot.columns), axis=1)

df_pivot = df_pivot.reset_index()

df_pivot

# %%
df = pd.read_csv(os.getcwd()+'/data/MQAr/MP10/ES0001RA001.csv')

def create_QAQCMMA_VALOR(df,pol):

    df = df.rename(columns={'VALOR':'VALOR_ORIGINAL'})

    flags_invalidos = ['!', 'IF', 'IO', 'IC', 'I%', 'IL', 'IE', 'IS', 'IU', 'IM', 'IP', 'ID', 'IT', 'IR', 
                       'Fora da Faixa de Medição', 'Disabilitada Temporariamente', 'Inválido', 
                       'Insuficientes', 'Inexistente']

    df['QAQC_INTERNO'] = ~df['QAQC_INTERNO'].isin(flags_invalidos)
    
    DEFAULT_RANGE_LIMITS = {
        "O3": (0, 500),
        "CO": (0, 50),
        "NO2": (0, 1000),
        "NOX": (0, 2000),
        "SO2": (0, 1000),
        "MP25": (0, 1000),
        "MP10": (0, 2000),
    }

    df['QAQC_MMA'] = df['QAQC_INTERNO']

    if pol in list(DEFAULT_RANGE_LIMITS.keys()):
        lim_min = DEFAULT_RANGE_LIMITS[pol][0]
        lim_max = DEFAULT_RANGE_LIMITS[pol][1]
    else:
        lim_min = 0
        lim_max = np.inf

    df['VALOR'] = df['VALOR_ORIGINAL']

    df['VALOR'] = pd.to_numeric(df['VALOR'], errors='coerce')
    
    df.loc[df['QAQC_MMA'] & (df['VALOR'].isna() | (df['VALOR'] < lim_min) | (df['VALOR'] > lim_max)), 'QAQC_MMA'] = False
    
    df.loc[~df['QAQC_MMA'], 'VALOR'] = np.nan
    
    df = df[['DATETIME', 'ANO', 'MES', 'DIA', 'HORA', 'VALOR', 'VALOR_ORIGINAL', 'UNIDADE', 'QAQC_INTERNO', 'QAQC_MMA']]

    return df

# %%
DEFAULT_RANGE_LIMITS = {
        "O3": (0, 500),
        "CO": (0, 50),
        "NO2": (0, 1000),
        "NOX": (0, 2000),
        "SO2": (0, 1000),
        "MP25": (0, 1000),
        "MP10": (0, 2000),
    }

DEFAULT_RANGE_LIMITS['MP10'][1]

# %%
list(DEFAULT_RANGE_LIMITS.keys())

# %%
pol = 'CCCC'

df['QAQC_MMA'] = df['QAQC_INTERNO']

if pol in list(DEFAULT_RANGE_LIMITS.keys()):
    lim_min = DEFAULT_RANGE_LIMITS[pol][0]
    lim_max = DEFAULT_RANGE_LIMITS[pol][1]
else:
    lim_min = 0
    lim_max = np.inf

# %%
df['VALOR'] = df['VALOR_ORIGINAL']

df['VALOR'] = pd.to_numeric(df['VALOR'], errors='coerce')

df.loc[df['QAQC_MMA'] & (df['VALOR'].isna() | (df['VALOR'] < lim_min) | (df['VALOR'] > lim_max)), 'QAQC_MMA'] = False

df.loc[~df['QAQC_MMA'], 'VALOR'] = np.nan

df = df[['DATETIME', 'ANO', 'MES', 'DIA', 'HORA', 'VALOR', 'VALOR_ORIGINAL', 'UNIDADE', 'QAQC_INTERNO', 'QAQC_MMA']]

# %%
df.columns

# %%
import pandas as pd
import os
from collections import defaultdict
from datetime import datetime, timedelta
import re
import numpy as np
from pathlib import Path

def ppb_to_ug(df,pol):

    if pol == 'so2':

        df.loc[df["Unidade"] != "ug/m3", "Valor"] *= 2661260.49/10**6        

    elif pol == 'no2':

        df.loc[df["Unidade"] != "ug/m3", "Valor"] *= 1911038.92/10**6        

    elif pol == 'o3':

        df.loc[df["Unidade"] != "ug/m3", "Valor"] *= 1993889.17/10**6        
    
    df.loc[:, "Unidade"] = "ug/m3"

    return df

def rectify_MT(path):

    dict_pols_stat = defaultdict(list)

    files = os.listdir(path)
    
    print(files)
    
    for item in files:
        
        estacao = " ".join(item.split('-')[1].split('.')[0].split('_')[0:2])
    
        print(estacao)
    
        df = pd.read_excel(path+item)
    
        df = df.drop(columns=['Nome da estação'])
    
        lista_pols = set(df['Poluente'])
    
        for pol in lista_pols:
    
            df_pol = df[df["Poluente"] == pol]
            
            if pol in ['no2','so2','o3']:
    
                df_pol = ppb_to_ug(df_pol,pol)
    
            df_pol_hora = df_pol.groupby(["Ano", "Mes", "Dia", "Hora", "Unidade"])
            
            df_pol_hora = df_pol_hora.filter(lambda g: len(g) >= 9)
            
            df_pol = (
                df_pol_hora.groupby(["Ano", "Mes", "Dia", "Hora", "Unidade"], as_index=False)
                      .agg({"Valor": "mean"})
            )
    
            df_pol['QAQC_INTERNO'] = None
    
            df_pol = df_pol.rename(columns={'Ano':'ANO',
                                            'Mes':'MES',
                                            'Dia':'DIA',
                                            'Hora':'HORA',
                                            'Unidade':'UNIDADE',
                                            'Valor':'VALOR'})
    
            for col in ["ANO", "MES", "DIA", "HORA"]:
                df_pol[col] = pd.to_numeric(df_pol[col], errors="coerce").astype("Int64")
            
            dict_pols_stat[estacao+'_'+pol].append(df_pol)

    dict_pols_MT = {
        'co':'CO',
        'no2': 'NO2',
        'so2': 'SO2',
        'o3': 'O3',
        'pm2p5':'MP25',
        'pm10': 'MP10'
    }

    dict_formatado = {}
    
    for chave in dict_pols_stat.keys():
        
        lista_dfs = dict_pols_stat[chave]
        
        df = pd.concat(lista_dfs, ignore_index=True)
    
        df["DATETIME"] = pd.to_datetime(
            df.apply(lambda r: f"{r.ANO}-{r.MES}-{r.DIA} {r.HORA}:00:00", axis=1)
        )
        df = df.set_index("DATETIME")
    
        df = df.sort_index()
        
        lista_horas = pd.date_range(
            start=df.index.min(), 
            end=df.index.max(), 
            freq='H').strftime('%Y-%m-%d %H:%M:%S').tolist()
        
        if len(lista_horas) != len(df):
            df = df.reindex(pd.DatetimeIndex(lista_horas))
    
        df['DATETIME'] = df.index
    
        df = df[['DATETIME','ANO','MES','DIA','HORA','VALOR','UNIDADE','QAQC_INTERNO']]
        
        dict_formatado[chave] = df
        
        primeiros_valores = {}
    
    for chave, df in dict_formatado.items():
        
        if ~df['VALOR'].isna().all() and (df['VALOR'] > 0).any(): 
            
            linha_valida = df[df["VALOR"].notna() & (df["VALOR"] > 0)].iloc[0]
            primeiros_valores[chave] = linha_valida["DATETIME"]
    
    codigo_estacao_MT = {}
    
    for chave in primeiros_valores.keys():
        
        station = chave.split('_')[0]
        data = primeiros_valores[chave]
        
        if station in codigo_estacao_MT:
            if data <= codigo_estacao_MT[station]:
                codigo_estacao_MT[station] = data
        else:
            codigo_estacao_MT[station] = data
    
    sorted_items = sorted(
        codigo_estacao_MT.items(),
        key=lambda x: (x[1], x[0])
    )
    
    codigo_estacao_MT = {}
    for i, (nome, ts) in enumerate(sorted_items, start=1):
        codigo = f"MT{i:04d}"
        codigo_estacao_MT[nome] = codigo
        
    for chave, df in dict_formatado.items():
        
        estacao = codigo_estacao_MT[chave.split('_')[0]]
        
        cod_pol = tabela_pols.loc[tabela_pols['POLUENTE'] == dict_pols_MT[chave.split('_')[-1]], 'COD_POLUENTE'].values[0]
        
        nome_pasta = tabela_pols.loc[tabela_pols['COD_POLUENTE'] == int(cod_pol), 'NOME_PASTA'].values[0]

        df = create_QAQCMMA_VALOR(df,nome_pasta)
        
        df.to_csv('/home/nobre/Notebooks/RQAR_2025_book/data/MQAr/'+nome_pasta+'/'+estacao+'IA'+str(cod_pol).zfill(3)+'.csv',index=False)

    dict_stations_MT = {
        'Sema':'CPA - SEMA - CBA',
        'BEA CBA': 'Dom Aquino - BEA - CBA',
        'CBM VG': 'Água Limpa - CBM - VG',
        'Mae Bonifacia': 'Duque de Caxias - Pq Mãe Bonifácia - CBA',
        'UFMT':'Boa Esperança - UFMT - CBA'
    }
    
    df_ids = pd.DataFrame({
        'ID_OEMA': codigo_estacao_MT.keys(),
        'ID_MMA':list(codigo_estacao_MT.values())})
    
    df_ids["ID_OEMA"] = df_ids["ID_OEMA"].replace(dict_stations_MT)

    print(df_ids)
    
    return df_ids

funcoes = {
    'MT': rectify_MT
}

#lista_estados = ['SC','RS','MT','DF','MA','BA','ES','MG','SP','RJ']
lista_estados = ['MT']

tabela_ids = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/Monitoramento_QAr_BR.csv')
tabela_pols = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/dicionarios/CODIGO_POLUENTES.csv')

for estado in lista_estados:
    
    path = os.getcwd()+'/data/DADOS_BRUTOS/' + estado + '/'

    df_ids = funcoes[estado](path)
    
    create_df_estacao(estado,df_ids)

# %%
df = df_dia.groupby(['ANO'])

# %%
tabela_pols = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/dicionarios/CODIGO_POLUENTES.csv')

# %%
for pol in tabela_pols['NOME_PASTA'].unique():
    print(pol)

# %%
import pandas as pd
import os
from collections import defaultdict
from datetime import datetime, timedelta
import re
import numpy as np
from pathlib import Path

os.chdir('/home/nobre/Notebooks/RQAR_2025_book/')

# %%
funcoes = {
    
    'MT': rectify_MT,
}

lista_estados = ['MT']

tabela_ids = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/Monitoramento_QAr_BR.csv')
tabela_pols = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/dicionarios/CODIGO_POLUENTES.csv')

# %%
estado = 'DF'
  
path = os.getcwd()+'/data/DADOS_BRUTOS/' + estado + '/'

#df_ids = funcoes[estado](path)
    
#create_df_estacao(estado,df_ids)

# %%
dict_pols_stat = defaultdict(list)

files = os.listdir(path)

print(files)

for item in files:
    
    estacao = " ".join(item.split('-')[1].split('.')[0].split('_')[0:2])

    print(estacao)

    df = pd.read_excel(path+item)

    df = df.drop(columns=['Nome da estação'])

    lista_pols = set(df['Poluente'])

    for pol in lista_pols:

        df_pol = df[df["Poluente"] == pol]
        
        if pol in ['no2','so2','o3']:

            df_pol = ppb_to_ug(df_pol,pol)

        df_pol_hora = df_pol.groupby(["Ano", "Mes", "Dia", "Hora", "Unidade"])
        
        df_pol_hora = df_pol_hora.filter(lambda g: len(g) >= 9)
        
        df_pol = (
            df_pol_hora.groupby(["Ano", "Mes", "Dia", "Hora", "Unidade"], as_index=False)
                  .agg({"Valor": "mean"})
        )

        df_pol['QAQC_INTERNO'] = None

        df_pol = df_pol.rename(columns={'Ano':'ANO',
                                        'Mes':'MES',
                                        'Dia':'DIA',
                                        'Hora':'HORA',
                                        'Unidade':'UNIDADE',
                                        'Valor':'VALOR'})

        for col in ["ANO", "MES", "DIA", "HORA"]:
            df_pol[col] = pd.to_numeric(df_pol[col], errors="coerce").astype("Int64")
        
        dict_pols_stat[estacao+'_'+pol].append(df_pol)

# %%
def ppb_to_ug(df,pol):

    if pol == 'so2':

        df.loc[df["Unidade"] != "ug/m3", "Valor"] *= 2661260.49/10**6        

    elif pol == 'no2':

        df.loc[df["Unidade"] != "ug/m3", "Valor"] *= 1911038.92/10**6        

    elif pol == 'o3':

        df.loc[df["Unidade"] != "ug/m3", "Valor"] *= 1993889.17/10**6        
    
    df.loc[:, "Unidade"] = "ug/m3"

    return df

# %%
dict_pols_MT = {
    'co':'CO',
    'no2': 'NO2',
    'so2': 'SO2',
    'o3': 'O3',
    'pm2p5':'MP25',
    'pm10': 'MP10'
}

dict_formatado = {}

for chave in dict_pols_stat.keys():
    
    lista_dfs = dict_pols_stat[chave]
    
    df = pd.concat(lista_dfs, ignore_index=True)

    df["DATETIME"] = pd.to_datetime(
        df.apply(lambda r: f"{r.ANO}-{r.MES}-{r.DIA} {r.HORA}:00:00", axis=1)
    )
    df = df.set_index("DATETIME")

    df = df.sort_index()
    
    lista_horas = pd.date_range(
        start=df.index.min(), 
        end=df.index.max(), 
        freq='H').strftime('%Y-%m-%d %H:%M:%S').tolist()
    
    if len(lista_horas) != len(df):
        df = df.reindex(pd.DatetimeIndex(lista_horas))

    df['DATETIME'] = df.index

    df = df[['DATETIME','ANO','MES','DIA','HORA','VALOR','UNIDADE','QAQC_INTERNO']]
    
    dict_formatado[chave] = df

primeiros_valores = {}

for chave, df in dict_formatado.items():
    
    if ~df['VALOR'].isna().all() and (df['VALOR'] > 0).any(): 
        
        linha_valida = df[df["VALOR"].notna() & (df["VALOR"] > 0)].iloc[0]
        primeiros_valores[chave] = linha_valida["DATETIME"]

codigo_estacao_MT = {}

for chave in primeiros_valores.keys():
    
    station = chave.split('_')[0]
    data = primeiros_valores[chave]
    
    if station in codigo_estacao_MT:
        if data <= codigo_estacao_MT[station]:
            codigo_estacao_MT[station] = data
    else:
        codigo_estacao_MT[station] = data

sorted_items = sorted(
    codigo_estacao_MT.items(),
    key=lambda x: (x[1], x[0])
)

codigo_estacao_MT = {}
for i, (nome, ts) in enumerate(sorted_items, start=1):
    codigo = f"MT{i:04d}"
    codigo_estacao_MT[nome] = codigo
    
for chave, df in dict_formatado.items():
    
    estacao = codigo_estacao_MT[chave.split('_')[0]]
    
    cod_pol = tabela_pols.loc[tabela_pols['POLUENTE'] == dict_pols_MT[chave.split('_')[-1]], 'COD_POLUENTE'].values[0]
    
    nome_pasta = tabela_pols.loc[tabela_pols['COD_POLUENTE'] == int(cod_pol), 'NOME_PASTA'].values[0]
    
    df.to_csv('/home/nobre/Notebooks/RQAR_2025_book/data/MQAr/'+nome_pasta+'/'+estacao+'RA'+str(cod_pol).zfill(3)+'.csv',index=False)

df_ids = pd.DataFrame({
    'ID_OEMA': codigo_estacao_MT.keys(),
    'ID_MMA':list(codigo_estacao_MT.values())})

return df_ids

# %%
df_ids

# %%
from datetime import timedelta

def fix_24h(row):
    if isinstance(row, str) and row.startswith("24:"):
        # substitui 24: por 00:
        new_str = row.replace("24:", "00:", 1)
        # converte para datetime
        dt = pd.to_datetime(new_str, errors="coerce")
        # adiciona 1 dia
        if pd.notna(dt):
            dt += timedelta(days=1)
        return dt
    else:
        return pd.to_datetime(row, errors="coerce")

# %%
dict_stations_MT = {
        'Sema':'CPA - SEMA - CBA',
        'BEA CBA': 'Dom Aquino - BEA - CBA',
        'CBM VG': 'Água Limpa - CBM - VG',
        'Mae Bonifacia': 'Duque de Caxias - Pq Mãe Bonifácia - CBA',
        'UFMT':'Boa Esperança - UFMT - CBA'
    }
    
df_ids = pd.DataFrame({
    'ID_OEMA': codigo_estacao_MT.keys(),
    'ID_MMA':list(codigo_estacao_MT.values())})


df_ids["ID_OEMA"] = df_ids["ID_OEMA"].replace(dict_stations_MT)


df_ids['ID_OEMA']

# %%
df_ids

# %%
estado = 'DF'

# %%
path = os.getcwd()+'/data/DADOS_BRUTOS/' + estado + '/'

path = path + 'Monitor Report 2024_FINAL.xlsx'

df = pd.read_excel(path)

df.iloc[1] = df.iloc[1].ffill()

poluentes = ['CO_ppm','NO2_ug/m3','NO_ug/m3','NOx_ug/m3','O3_ug/m3','PM10','PM25','PTS','SO2_ug/m3']

dict_pols = {'CO_ppm':'CO',
             'NO2_ug/m3':'NO2',
             'NO_ug/m3':'NO',
             'NOx_ug/m3':'NOX',
             'O3_ug/m3':'O3',
             'PM10':'MP10',
             'PM25':'MP25',
             'PTS':'PTS',
             'SO2_ug/m3':'SO2'}

df.columns = df.iloc[1]

df = df.drop(index=[0, 1]).reset_index(drop=True)

df = df.rename(columns={'Date Time':'DATETIME'})

estacoes = set(df.columns[1:])

dict_pols_stat = defaultdict(list)

for estacao in estacoes:

    df_estacao = df[["DATETIME",estacao]]

    df_estacao.columns = [df_estacao.columns.tolist()[0]] + df_estacao.iloc[0, 1:].tolist()

    df_estacao = df_estacao.drop(index=[0]).reset_index(drop=True)

    for pol in poluentes:

        if pol in df_estacao.columns:
            
            df_pol = df_estacao[["DATETIME",pol]]

            df_pol['UNIDADE'] = df_pol[pol][0]

            df_pol = df_pol.drop(index=[0]).reset_index(drop=True)

            df_pol = df_pol[df_pol["DATETIME"].astype(str).str.contains(r"\d", na=False)].reset_index(drop=True)

            df_pol['DATETIME'] = df_pol['DATETIME'].apply(fix_24h)

            df_pol = df_pol.rename(columns={pol:'VALOR'})

            df_pol.index = df_pol['DATETIME']

            lista_horas = pd.date_range(
                start=df_pol.index.min(), 
                end=df_pol.index.max(), 
                freq='H').strftime('%Y-%m-%d %H:%M:%S').tolist()
            
            if len(lista_horas) != len(df_pol):
                df_pol = df_pol.reindex(pd.DatetimeIndex(lista_horas))
            
            df_pol['QAQC_INTERNO'] = None
            
            df_pol.insert(1, 'ANO', df_pol.index.year)
            df_pol.insert(2, 'MES', df_pol.index.month)
            df_pol.insert(3, 'DIA', df_pol.index.day)
            df_pol.insert(4, 'HORA', df_pol.index.hour)

            pol = dict_pols[pol]

            df_pol['VALOR'] = pd.to_numeric(df_pol['VALOR'], errors='coerce')

            df_pol = df_pol[['DATETIME','ANO','MES','DIA','HORA','VALOR','UNIDADE','QAQC_INTERNO']] 

            dict_pols_stat[estacao+'_'+pol] = df_pol

# %%
primeiros_valores = {}

for chave, df in dict_pols_stat.items():  
    
    if ~df['VALOR'].isna().all() and (df['VALOR'] > 0).any(): 
        
        linha_valida = df[df["VALOR"].notna() & (df["VALOR"] > 0)].iloc[0]
        primeiros_valores[chave] = linha_valida["DATETIME"]

codigo_estacao_DF = {}

for chave in primeiros_valores.keys():
    
    station = chave.split('_')[0]
    data = primeiros_valores[chave]
    
    if station in codigo_estacao_DF:
        if data <= codigo_estacao_DF[station]:
            codigo_estacao_DF[station] = data
    else:
        codigo_estacao_DF[station] = data

sorted_items = sorted(
    codigo_estacao_DF.items(),
    key=lambda x: (x[1], x[0])
)

codigo_estacao_DF = {}
for i, (nome, ts) in enumerate(sorted_items, start=1):
    codigo = f"DF{i:04d}"
    codigo_estacao_DF[nome] = codigo
    
for chave, df in dict_pols_stat.items():
    
    estacao = codigo_estacao_DF[chave.split('_')[0]]
    
    cod_pol = tabela_pols.loc[tabela_pols['POLUENTE'] == chave.split('_')[-1], 'COD_POLUENTE'].values[0]
    
    nome_pasta = tabela_pols.loc[tabela_pols['COD_POLUENTE'] == int(cod_pol), 'NOME_PASTA'].values[0]
    
    df.to_csv('/home/nobre/Notebooks/RQAR_2025_book/data/MQAr/'+nome_pasta+'/'+estacao+'RA'+str(cod_pol).zfill(3)+'.csv',index=False)

dict_oemas = {
    'Estação CRAS FERCAL': 'Fercal CRAS',
    'Estação Escola':	   'Fercal Escola'}

df_ids = pd.DataFrame({
    'ID_OEMA': codigo_estacao_DF.keys(),
    'ID_MMA':list(codigo_estacao_DF.values())})

df_ids['ID_OEMA'] = df_ids['ID_OEMA'].replace(dict_oema)

return df_ids

# %%
df_ufs = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/dicionarios/IBGE_UFS_CODIGOS.csv')
    
cod_uf =  df_ufs.loc[df_ufs['UF'] == uf, 'CODIGOS'].values[0]

print(cod_uf)

if os.path.exists('/home/nobre/Notebooks/RQAR_2025_book/data/DADOS_ESTACOES/'+uf+'_estacoes.csv'):

    df_estacao = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/DADOS_ESTACOES/'+uf+'_estacoes.csv')

    df_estacao['ID_MMA'] = df_estacao['ID_OEMA'].map(df_ids.set_index('ID_OEMA')['ID_MMA'])

else:

    colunas = ['ID_OEMA', 'UF', 'ID_MMA', 'COD_UF_IBGE', 'CIDADE', 'CD_MUN',
               'PROPRIETARIO', 'PROP_ENTIDADE', 'OPERADOR', 'OP_ENTIDADE', 'LATITUDE',
               'LONGITUDE', 'MOBILIDADE', 'REALOCACAO', 'MARCA', 'CATEGORIA',
               'FUNCIONAMENTO', 'METODO', 'FINALIDADE', 'POLUENTE',
               'INICIO', 'STATUS', 'FIM', 'CALIBRACAO', 'OBS_CALIBRACAO', 'MONITORAR',
               'FONTE', 'OBS_GERAIS','DADOS_MONITORAMENTO','RECONHECIDA','REP_ESPACIAL_DECLARADA']
    
    df_estacao = pd.DataFrame(columns=colunas)

df_ids = pol_to_station(df_ids)

mapa = dict(zip(df_ids['ID_MMA'], df_ids['POLUENTE']))

df_estacao['POLUENTE'] = df_estacao['ID_MMA'].map(mapa).fillna(df_estacao['POLUENTE'])

#df_estacao = df_estacao.reindex(df_ids.index)

#df_estacao[["ID_MMA", "ID_OEMA", "POLUENTE"]] = df_ids[["ID_MMA", "ID_OEMA", "POLUENTE"]].values

df_estacao.loc[:, "COD_UF_IBGE"] = cod_uf
df_estacao.loc[:, "UF"] = uf
    
#df_estacao.to_csv('/home/nobre/Notebooks/RQAR_2025_book/data/DADOS_ESTACOES/'+uf+'_estacoes_teste.csv', index=False)

# %%
df_estacao['POLUENTE']

# %%
def pol_to_station(df_ids):

    base_path = Path('/home/nobre/Notebooks/RQAR_2025_book/data/MQAr/')

    id_to_poluentes = {}
    
    for poluente_dir in base_path.iterdir():
        if poluente_dir.is_dir():
            poluente = poluente_dir.name
    
            arquivos = [arq.stem for arq in poluente_dir.glob("*")]
    
            for id_mma in df_ids["ID_MMA"]:
                if any(str(arq).startswith(id_mma) for arq in arquivos):
                    id_to_poluentes.setdefault(id_mma, []).append(poluente)
    
    df_ids["POLUENTE"] = df_ids["ID_MMA"].map(id_to_poluentes).fillna("").apply(lambda x: ",".join(x) if isinstance(x, list) else "")
    
    return(df_ids)

# %% [markdown]
# # Varrer MQAr

# %%
caminho_MQAr = os.getcwd() + '/data/MQAr/'

lista_pols = os.listdir(caminho_MQAr)

arquivos_MQAr = pd.DataFrame({'ID_MMA_COMPLETO':[]})

for pol in lista_pols:

    if '.ipynb' not in pol and pol != 'METEREOLOGICO':

        caminho_pol = caminho_MQAr+pol

        estacoes_pols = os.listdir(caminho_pol)

        print(pol)

        for estacao in estacoes_pols:

            if estacao != '.ipynb_checkpoints':

                arquivos_MQAr.loc[len(arquivos_MQAr)] = estacao[:-4]

arquivos_MQAr['ID_MMA'] = arquivos_MQAr['ID_MMA_COMPLETO'].str[:6]

# %%
Monitoramento_MQAr = pd.read_csv(os.getcwd()+'/data/Monitoramento_QAr_BR.csv')

df_monitoramento = pd.DataFrame({'ID_MMA_COMPLETO':Monitoramento_MQAr['ID_MMA_COMPLETO']})

df_monitoramento['ID_MMA'] = df_monitoramento['ID_MMA_COMPLETO'].str[:6]

arquivos_MQAr['BANCO_DADOS'] = arquivos_MQAr['ID_MMA'].isin(df_monitoramento['ID_MMA']).map({True: 'Sim', False: 'Nao'})

print(arquivos_MQAr)

# %%
df_monitoramento

# %%
num_sim = (arquivos_MQAr['BANCO_DADOS'] == 'Sim').sum()
print(num_sim)

# %%
df_nao = arquivos_MQAr[arquivos_MQAr['BANCO_DADOS'] == 'Nao']
print(df_nao)

for id_mma_comp in df_nao['ID_MMA_COMPLETO']:
    print(id_mma_comp)

# %% [markdown]
# # Apagar MQAr valores ruins

# %%
import numpy as np
import pandas as pd

caminho = os.getcwd() + '/data/MQAr/'

print(caminho)

poluentes = os.listdir(caminho)

df_estacoes_invalidas = pd.DataFrame(columns=['ESTACAO','POLUENTE', 'PRCNTG_INVALIDO'])

for pol in poluentes:

    if pol != '.ipynb_checkpoints' and pol != 'METEOROLOGICO':

        print(pol)

        estacoes = os.listdir(caminho+pol)

        for estacao in estacoes:

            if 'I' in estacao:

                df = pd.read_csv(caminho+pol+'/'+estacao)

                porcent_nan = df['VALOR'].isna().mean() * 100

                df_estacoes_invalidas.loc[len(df_estacoes_invalidas)] = [estacao[:-4],pol, porcent_nan]

                #os.remove(caminho+pol+'/'+estacao)

print(df_estacoes_invalidas)
# Out:
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/
# MP10
# NO
# FORMAL
# HCT
# BENZENO
# CO
# H2S
# ACETAL
# PTS
# CH4
# MP1
# O3
# ETILBENZENO
# SO2
# NO2
# TOLUENO
# VOC
# CHUMBO
# NH3
# OXILENO
# HCNM
# NOX
# ERT
# MPXILENO
# MP25
# XILENO
#         ESTACAO POLUENTE  PRCNTG_INVALIDO
# 0   MT0003IA001     MP10        17.495106
# 1   MT0005IA001     MP10         0.918897
# 2   MT0004IA001     MP10         0.495719
# 3   MT0002IA001     MP10         1.403360
# 4   MT0001IA001     MP10         1.401948
# 5   MT0001IA007       CO         1.548858
# 6   MT0002IA007       CO         1.403360
# 7   MT0004IA007       CO        30.238846
# 8   MT0003IA007       CO        17.495106
# 9   MT0005IA007       CO        24.770276
# 10  MT0005IA005       O3        72.552936
# 11  MT0003IA005       O3        25.768150
# 12  MT0002IA005       O3         3.886881
# 13  MT0001IA005       O3         3.786098
# 14  MT0004IA005       O3        89.139252
# 15  MT0002IA003      SO2        70.665533
# 16  MT0001IA003      SO2        92.629281
# 17  MT0005IA003      SO2        10.747103
# 18  MT0004IA003      SO2        16.899504
# 19  MT0003IA003      SO2        67.409992
# 20  MT0002IA004      NO2         5.507123
# 21  MT0003IA004      NO2        23.210486
# 22  MT0004IA004      NO2         0.946372
# 23  MT0005IA004      NO2         0.918897
# 24  MT0001IA004      NO2        46.893889
# 25  MT0004IA002     MP25         0.495719
# 26  MT0002IA002     MP25         1.403360
# 27  MT0003IA002     MP25        17.495106
# 28  MT0001IA002     MP25         1.401948
# 29  MT0005IA002     MP25         0.918897

# %%
import numpy as np
import pandas as pd

caminho = os.getcwd() + '/data/MQAr/'

print(caminho)

poluentes = os.listdir(caminho)

df_estacoes_invalidas = pd.DataFrame(columns=['ESTACAO','POLUENTE', 'PRCNTG_INVALIDO'])

for pol in poluentes:

    if pol != '.ipynb_checkpoints' and pol != 'METEOROLOGICO':

        print(pol)

        estacoes = os.listdir(caminho+pol)

        for estacao in estacoes:

            if 'I' in estacao:

                df = pd.read_csv(caminho+pol+'/'+estacao)

                porcent_nan = df['VALOR'].isna().mean() * 100

                df_estacoes_invalidas.loc[len(df_estacoes_invalidas)] = [estacao[:-4],pol, porcent_nan]

                #os.remove(caminho+pol+'/'+estacao)

print(df_estacoes_invalidas)
# Out:
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/
# MP10
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/MP10/MT0003IA001.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/MP10/MT0005IA001.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/MP10/MT0004IA001.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/MP10/MT0002IA001.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/MP10/MT0001IA001.csv
# NO
# FORMAL
# HCT
# BENZENO
# CO
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/CO/MT0001IA007.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/CO/MT0002IA007.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/CO/MT0004IA007.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/CO/MT0003IA007.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/CO/MT0005IA007.csv
# H2S
# ACETAL
# PTS
# CH4
# MP1
# O3
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/O3/MT0005IA005.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/O3/MT0003IA005.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/O3/MT0002IA005.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/O3/MT0001IA005.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/O3/MT0004IA005.csv
# ETILBENZENO
# SO2
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/SO2/MT0002IA003.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/SO2/MT0001IA003.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/SO2/MT0005IA003.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/SO2/MT0004IA003.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/SO2/MT0003IA003.csv
# NO2
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/NO2/MT0002IA004.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/NO2/MT0003IA004.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/NO2/MT0004IA004.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/NO2/MT0005IA004.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/NO2/MT0001IA004.csv
# TOLUENO
# VOC
# CHUMBO
# NH3
# OXILENO
# HCNM
# NOX
# ERT
# MPXILENO
# MP25
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/MP25/MT0004IA002.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/MP25/MT0002IA002.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/MP25/MT0003IA002.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/MP25/MT0001IA002.csv
# /home/nobre/Notebooks/RQAR_2025_book/data/MQAr/MP25/MT0005IA002.csv
# XILENO
#         ESTACAO POLUENTE  PRCNTG_INVALIDO
# 0   MT0003IA001     MP10        17.495106
# 1   MT0005IA001     MP10         0.918897
# 2   MT0004IA001     MP10         0.495719
# 3   MT0002IA001     MP10         1.403360
# 4   MT0001IA001     MP10         1.401948
# 5   MT0001IA007       CO         1.548858
# 6   MT0002IA007       CO         1.403360
# 7   MT0004IA007       CO        30.238846
# 8   MT0003IA007       CO        17.495106
# 9   MT0005IA007       CO        24.770276
# 10  MT0005IA005       O3        72.552936
# 11  MT0003IA005       O3        25.768150
# 12  MT0002IA005       O3         3.886881
# 13  MT0001IA005       O3         3.786098
# 14  MT0004IA005       O3        89.139252
# 15  MT0002IA003      SO2        70.665533
# 16  MT0001IA003      SO2        92.629281
# 17  MT0005IA003      SO2        10.747103
# 18  MT0004IA003      SO2        16.899504
# 19  MT0003IA003      SO2        67.409992
# 20  MT0002IA004      NO2         5.507123
# 21  MT0003IA004      NO2        23.210486
# 22  MT0004IA004      NO2         0.946372
# 23  MT0005IA004      NO2         0.918897
# 24  MT0001IA004      NO2        46.893889
# 25  MT0004IA002     MP25         0.495719
# 26  MT0002IA002     MP25         1.403360
# 27  MT0003IA002     MP25        17.495106
# 28  MT0001IA002     MP25         1.401948
# 29  MT0005IA002     MP25         0.918897

# %%
#df_estacoes_invalidas.to_csv(os.getcwd()+'/data/dicionarios/ESTACOES_INVALIDADAS_MMA.csv',index=False)

# %%
pastas = os.listdir(os.getcwd()+'/data/MQAr_averages')

for pasta in pastas:

    if pasta != 'REP_TEMPORAL.csv' and pasta != '.ipynb_checkpoints':

        print(pasta)

        poluentes = os.listdir(os.getcwd()+'/data/MQAr_averages/'+pasta)

        for pol in poluentes:

            if pol != '.ipynb_checkpoints':

                print(pol)

                for estacao in df_estacoes_invalidas['ESTACAO']:
                    nome_arquivo = f"{estacao}.csv"
                    caminho_arquivo = os.path.join(os.getcwd()+'/data/MQAr_averages/'+pasta+'/'+pol, nome_arquivo)
                    
                    if os.path.exists(caminho_arquivo):
                        os.remove(caminho_arquivo)
                        print(f"Apagado: {nome_arquivo}")
                    else:
                        print(f"Não encontrado: {nome_arquivo}")
# Out:
# anual
# MP10
# Apagado: MT0003IA001.csv
# Apagado: MT0005IA001.csv
# Apagado: MT0004IA001.csv
# Apagado: MT0002IA001.csv
# Apagado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# CO
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Apagado: MT0001IA007.csv
# Apagado: MT0002IA007.csv
# Apagado: MT0004IA007.csv
# Apagado: MT0003IA007.csv
# Apagado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# PTS
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# O3
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Apagado: MT0005IA005.csv
# Apagado: MT0003IA005.csv
# Apagado: MT0002IA005.csv
# Apagado: MT0001IA005.csv
# Apagado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# SO2
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Apagado: MT0002IA003.csv
# Apagado: MT0001IA003.csv
# Apagado: MT0005IA003.csv
# Apagado: MT0004IA003.csv
# Apagado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# NO2
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Apagado: MT0002IA004.csv
# Apagado: MT0003IA004.csv
# Apagado: MT0004IA004.csv
# Apagado: MT0005IA004.csv
# Apagado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# FMC
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# MP25
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Apagado: MT0004IA002.csv
# Apagado: MT0002IA002.csv
# Apagado: MT0003IA002.csv
# Apagado: MT0001IA002.csv
# Apagado: MT0005IA002.csv
# Pb
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# 24
# MP10
# Apagado: MT0003IA001.csv
# Apagado: MT0005IA001.csv
# Apagado: MT0004IA001.csv
# Apagado: MT0002IA001.csv
# Apagado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# PTS
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# SO2
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Apagado: MT0002IA003.csv
# Apagado: MT0001IA003.csv
# Apagado: MT0005IA003.csv
# Apagado: MT0004IA003.csv
# Apagado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# FMC
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# MP25
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Apagado: MT0004IA002.csv
# Apagado: MT0002IA002.csv
# Apagado: MT0003IA002.csv
# Apagado: MT0001IA002.csv
# Apagado: MT0005IA002.csv
# 1
# NO2
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Apagado: MT0002IA004.csv
# Apagado: MT0003IA004.csv
# Apagado: MT0004IA004.csv
# Apagado: MT0005IA004.csv
# Apagado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# rep_temporal_mes_ano
# MP10
# Apagado: MT0003IA001.csv
# Apagado: MT0005IA001.csv
# Apagado: MT0004IA001.csv
# Apagado: MT0002IA001.csv
# Apagado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# CO
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Apagado: MT0001IA007.csv
# Apagado: MT0002IA007.csv
# Apagado: MT0004IA007.csv
# Apagado: MT0003IA007.csv
# Apagado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# PTS
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# O3
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Apagado: MT0005IA005.csv
# Apagado: MT0003IA005.csv
# Apagado: MT0002IA005.csv
# Apagado: MT0001IA005.csv
# Apagado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# SO2
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Apagado: MT0002IA003.csv
# Apagado: MT0001IA003.csv
# Apagado: MT0005IA003.csv
# Apagado: MT0004IA003.csv
# Apagado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# NO2
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Apagado: MT0002IA004.csv
# Apagado: MT0003IA004.csv
# Apagado: MT0004IA004.csv
# Apagado: MT0005IA004.csv
# Apagado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# FMC
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# MP25
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Apagado: MT0004IA002.csv
# Apagado: MT0002IA002.csv
# Apagado: MT0003IA002.csv
# Apagado: MT0001IA002.csv
# Apagado: MT0005IA002.csv
# Pb
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# mensal
# MP10
# Apagado: MT0003IA001.csv
# Apagado: MT0005IA001.csv
# Apagado: MT0004IA001.csv
# Apagado: MT0002IA001.csv
# Apagado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# CO
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Apagado: MT0001IA007.csv
# Apagado: MT0002IA007.csv
# Apagado: MT0004IA007.csv
# Apagado: MT0003IA007.csv
# Apagado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# PTS
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# O3
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Apagado: MT0005IA005.csv
# Apagado: MT0003IA005.csv
# Apagado: MT0002IA005.csv
# Apagado: MT0001IA005.csv
# Apagado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# SO2
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Apagado: MT0002IA003.csv
# Apagado: MT0001IA003.csv
# Apagado: MT0005IA003.csv
# Apagado: MT0004IA003.csv
# Apagado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# NO2
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Apagado: MT0002IA004.csv
# Apagado: MT0003IA004.csv
# Apagado: MT0004IA004.csv
# Apagado: MT0005IA004.csv
# Apagado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# FMC
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# MP25
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Apagado: MT0004IA002.csv
# Apagado: MT0002IA002.csv
# Apagado: MT0003IA002.csv
# Apagado: MT0001IA002.csv
# Apagado: MT0005IA002.csv
# Pb
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# 8
# CO
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Apagado: MT0001IA007.csv
# Apagado: MT0002IA007.csv
# Apagado: MT0004IA007.csv
# Apagado: MT0003IA007.csv
# Apagado: MT0005IA007.csv
# Não encontrado: MT0005IA005.csv
# Não encontrado: MT0003IA005.csv
# Não encontrado: MT0002IA005.csv
# Não encontrado: MT0001IA005.csv
# Não encontrado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv
# O3
# Não encontrado: MT0003IA001.csv
# Não encontrado: MT0005IA001.csv
# Não encontrado: MT0004IA001.csv
# Não encontrado: MT0002IA001.csv
# Não encontrado: MT0001IA001.csv
# Não encontrado: MT0001IA007.csv
# Não encontrado: MT0002IA007.csv
# Não encontrado: MT0004IA007.csv
# Não encontrado: MT0003IA007.csv
# Não encontrado: MT0005IA007.csv
# Apagado: MT0005IA005.csv
# Apagado: MT0003IA005.csv
# Apagado: MT0002IA005.csv
# Apagado: MT0001IA005.csv
# Apagado: MT0004IA005.csv
# Não encontrado: MT0002IA003.csv
# Não encontrado: MT0001IA003.csv
# Não encontrado: MT0005IA003.csv
# Não encontrado: MT0004IA003.csv
# Não encontrado: MT0003IA003.csv
# Não encontrado: MT0002IA004.csv
# Não encontrado: MT0003IA004.csv
# Não encontrado: MT0004IA004.csv
# Não encontrado: MT0005IA004.csv
# Não encontrado: MT0001IA004.csv
# Não encontrado: MT0004IA002.csv
# Não encontrado: MT0002IA002.csv
# Não encontrado: MT0003IA002.csv
# Não encontrado: MT0001IA002.csv
# Não encontrado: MT0005IA002.csv

# %%
caminho_MQAr = os.getcwd() + '/data/MQAr/'

lista_pols = os.listdir(caminho_MQAr)

arquivos_MQAr = pd.DataFrame({'ID_MMA_COMPLETO':[]})

for pol in lista_pols:

    if '.ipynb' not in pol and pol != 'METEREOLOGICO':

        caminho_pol = caminho_MQAr+pol

        estacoes_pols = os.listdir(caminho_pol)

        print(pol)

        for estacao in estacoes_pols:

            if estacao != '.ipynb_checkpoints':

                arquivos_MQAr.loc[len(arquivos_MQAr)] = estacao[:-4]

arquivos_MQAr['ID_MMA'] = arquivos_MQAr['ID_MMA_COMPLETO'].str[:6]

# %%
Monitoramento_MQAr = pd.read_csv(os.getcwd()+'/data/Monitoramento_QAr_BR.csv')

df_monitoramento = pd.DataFrame({'ID_MMA_COMPLETO':Monitoramento_MQAr['ID_MMA_COMPLETO']})

df_monitoramento['ID_MMA'] = df_monitoramento['ID_MMA_COMPLETO'].str[:6]

arquivos_MQAr['BANCO_DADOS'] = arquivos_MQAr['ID_MMA'].isin(df_monitoramento['ID_MMA']).map({True: 'Sim', False: 'Nao'})

print(arquivos_MQAr)

# %%
df_monitoramento

# %%
num_sim = (arquivos_MQAr['BANCO_DADOS'] == 'Sim').sum()
print(num_sim)

# %%
df_nao = arquivos_MQAr[arquivos_MQAr['BANCO_DADOS'] == 'Nao']
print(df_nao)

for id_mma_comp in df_nao['ID_MMA_COMPLETO']:
    if 'PA' in id_mma_comp:
        print(id_mma_comp)

# %%
caminho_MQAr = os.getcwd() + '/data/MQAr/'

lista_pols = os.listdir(caminho_MQAr)

arquivos_MQAr = pd.DataFrame({'ID_MMA_COMPLETO':[]})

for pol in lista_pols:

    if '.ipynb' not in pol and pol != 'METEREOLOGICO':

        caminho_pol = caminho_MQAr+pol

        estacoes_pols = os.listdir(caminho_pol)

        print(pol)

        for estacao in estacoes_pols:

            if estacao != '.ipynb_checkpoints':

                arquivos_MQAr.loc[len(arquivos_MQAr)] = estacao[:-4]

arquivos_MQAr['ID_MMA'] = arquivos_MQAr['ID_MMA_COMPLETO'].str[:6]

# %%
Monitoramento_MQAr = pd.read_csv(os.getcwd()+'/data/Monitoramento_QAr_BR.csv')

df_monitoramento = pd.DataFrame({'ID_MMA_COMPLETO':Monitoramento_MQAr['ID_MMA_COMPLETO']})

df_monitoramento['ID_MMA'] = df_monitoramento['ID_MMA_COMPLETO'].str[:6]

arquivos_MQAr['BANCO_DADOS'] = arquivos_MQAr['ID_MMA'].isin(df_monitoramento['ID_MMA']).map({True: 'Sim', False: 'Nao'})

print(arquivos_MQAr)

# %%
df_monitoramento

# %%
num_sim = (arquivos_MQAr['BANCO_DADOS'] == 'Sim').sum()
print(num_sim)

# %%
df_nao = arquivos_MQAr[arquivos_MQAr['BANCO_DADOS'] == 'Nao']
print(df_nao)

for id_mma_comp in df_nao['ID_MMA_COMPLETO']:
    if 'PA' in id_mma_comp:
        print(id_mma_comp)

# %%
caminho = os.getcwd() + '/data/DADOS_BRUTOS/BRUTO_IEMA/'

estados_iema = os.listdir(caminho)

df_estacao_codigo = pd.DataFrame({
    'Estacao':[],
    'Codigo':[]
})

for estado in estados_iema:

    if '.csv' not in estado and '.ipynb_checkpoints' not in estado:

        lista_anos = os.listdir(caminho+estado)

        print(estado)
    
        print(lista_anos)
    
        df_estado = pd.DataFrame({
            'Data':[], 
            'Hora':[], 
            'Estacao':[], 
            'Codigo':[], 
            'Poluente':[], 
            'Valor':[], 
            'Unidade':[],
            'Tipo':[]})
    
        for ano in lista_anos:

            if '.csv' in ano:

                df = pd.read_csv(caminho+estado+'/'+ano, encoding='ISO-8859-1')
        
                df.columns.values[0] = 'Data'

                if 'Escola CecÃlia Meireles' in df['Estacao']:

                    print(ano)
        
                df_estado = pd.concat([df_estado, df], ignore_index=True)
    
        df_estacao_codigo = pd.concat([df_estacao_codigo,df_estado[['Estacao','Codigo']]], ignore_index=True)

df_estacao_codigo = df_estacao_codigo.drop_duplicates(subset=['Estacao', 'Codigo']).reset_index(drop=True)

# %%
df_estacao_codigo.to_csv(os.getcwd() + '/data/DADOS_BRUTOS/BRUTO_IEMA/IEMA_codigo_estacao.csv', encoding = 'UTF-8', index = False)

# %%
import pandas as pd
import glob
import os
from unidecode import unidecode

# %%
df_estacoes = pd.read_csv(os.getcwd() + '/data/DADOS_BRUTOS/BRUTO_IEMA/IEMA_codigo_estacao.csv', encoding = 'UTF-8')

import pandas as pd
import glob
import os
from unidecode import unidecode

# Caminho da pasta com os arquivos CSV
pasta = os.getcwd() + '/data/DADOS_ESTACOES'

# DataFrame principal
df_principal = df_estacoes.copy()

# Garantir que são strings
df_principal["ID_OEMA"] = df_principal["ID_OEMA"].astype(str)
df_principal["ID_MMA"] = df_principal["ID_MMA"].astype(str)

# Função para remover acentos e padronizar texto
def normalizar(texto):
    if pd.isna(texto):
        return None
    return unidecode(str(texto)).strip().upper()

# Normalizar coluna no DataFrame principal
df_principal["ID_OEMA_norm"] = df_principal["ID_OEMA"].apply(normalizar)

# Criar dicionário de mapeamento OEMA → MMA
mapa_oema_mma = {}

for arquivo in glob.glob(os.path.join(pasta, "*.csv")):
    df = pd.read_csv(arquivo, dtype=str)
    
    if "ID_OEMA" in df.columns and "ID_MMA" in df.columns:
        # Normalizar também nos arquivos
        df["ID_OEMA_norm"] = df["ID_OEMA"].apply(normalizar)
        df["ID_MMA"] = df["ID_MMA"].astype(str)

        pares_validos = df.dropna(subset=["ID_OEMA_norm", "ID_MMA"])
        for _, linha in pares_validos.iterrows():
            mapa_oema_mma[linha["ID_OEMA_norm"]] = linha["ID_MMA"]

# Mapear no DataFrame principal (usando os IDs normalizados)
df_principal["ID_MMA_preenchido"] = df_principal["ID_OEMA_norm"].map(mapa_oema_mma)

# Preencher apenas onde estava vazio
df_principal["ID_MMA"] = df_principal["ID_MMA"].replace("nan", pd.NA)
df_principal["ID_MMA"] = df_principal["ID_MMA"].fillna(df_principal["ID_MMA_preenchido"])

# Remover coluna auxiliar
df_principal = df_principal.drop(columns=["ID_MMA_preenchido", "ID_OEMA_norm"])

df_principal.to_csv(os.getcwd() + '/data/DADOS_BRUTOS/BRUTO_IEMA/IEMA_codigo_estacao_teste.csv', encoding = 'UTF-8', index = False)

# %%
df_estacoes = pd.read_csv(os.getcwd() + '/data/DADOS_BRUTOS/BRUTO_IEMA/IEMA_codigo_estacao_teste.csv', encoding = 'UTF-8')

df_estacoes

# %%
caminho = os.getcwd() + '/data/DADOS_BRUTOS/BRUTO_IEMA/'

df_est = pd.DataFrame({'Data':[],
                   'Hora'    :[],	
                   'Estacao' :[],
                   'Codigo'  :[],
                   'Poluente':[],
                   'Valor'   :[],	
                   'Unidade' :[],
                   'Tipo'    :[]})

arquivos = os.listdir(caminho)

for arquivo in arquivos:
    
    if '.csv' not in arquivo and 'checkpoints' not in arquivo:

        print(arquivo)

        anos = os.listdir(caminho+arquivo)

        for ano in anos:

            if '.csv' in ano:

                df = pd.read_csv(caminho+arquivo+'/'+ano, encoding='ISO-8859-1')

                df = df.rename(columns=lambda x: x.replace('ï»¿', ''))

                df = df.replace('MP2.5', 'MP25', regex=False)

                df_est = pd.concat([df, df_est], ignore_index=True)

# %%
df_est = df_est.merge(df_estacoes[['ID_OEMA', 'ID_MMA']], left_on='Estacao', right_on='ID_OEMA', how='left')

# %%
list(set(df_est['Unidade']))

lista_pols = list(set(df_est['Poluente']))

# %%
tabela_pols = pd.read_csv('/home/nobre/Notebooks/RQAR_2025_book/data/dicionarios/CODIGO_POLUENTES.csv')

def create_QAQCMMA_VALOR(df,pol):

    df = df.rename(columns={'VALOR':'VALOR_ORIGINAL'})

    flags_invalidos = ['!', 'IF', 'IO', 'IC', 'I%', 'IL', 'IE', 'IS', 'IU', 'IM', 'IP', 'ID', 'IT', 'IR',
                       'IM', 'VU', 'ID', 'IF', 'VE', 'IC', 'IN', 'VR', 'IV', 'IO',
                       'Fora da Faixa de Medição', 'Disabilitada Temporariamente', 'Inválido', 
                       'Insuficientes', 'Inexistente']

    df['QAQC_INTERNO'] = ~df['QAQC_INTERNO'].isin(flags_invalidos)
    
    DEFAULT_RANGE_LIMITS = {
        "O3": (0, 500),
        "CO": (0, 50),
        "NO2": (0, 1000),
        "NOX": (0, 2000),
        "SO2": (0, 1000),
        "MP25": (0, 1000),
        "MP10": (0, 2000),
    }

    df['QAQC_MMA'] = df['QAQC_INTERNO']

    if pol in list(DEFAULT_RANGE_LIMITS.keys()):
        lim_min = DEFAULT_RANGE_LIMITS[pol][0]
        lim_max = DEFAULT_RANGE_LIMITS[pol][1]
    else:
        lim_min = 0
        lim_max = np.inf

    df['VALOR'] = df['VALOR_ORIGINAL']

    df['VALOR'] = pd.to_numeric(df['VALOR'], errors='coerce')
    
    df.loc[df['QAQC_MMA'] & (df['VALOR'].isna() | (df['VALOR'] <= lim_min) | (df['VALOR'] >= lim_max)), 'QAQC_MMA'] = False
    
    df.loc[~df['QAQC_MMA'], 'VALOR'] = np.nan
    
    df = df[['DATETIME', 'ANO', 'MES', 'DIA', 'HORA', 'VALOR', 'VALOR_ORIGINAL', 'UNIDADE', 'QAQC_INTERNO', 'QAQC_MMA']]

    return df

print(lista_pols)

def ajustar_hora24(row):
    if row['Hora'].startswith('24'):
        # passa para o dia seguinte
        nova_data = pd.to_datetime(row['Data']) + pd.Timedelta(days=1)
        return nova_data.strftime('%Y-%m-%d') + ' 00:00:00'
    else:
        return row['Data'] + ' ' + row['Hora']

def ug_to_ppm(df):

    df.loc[df["UNIDADE"] == "ug/m3", "VALOR_ORIGINAL"] *= 868.26/10**6
    df.loc[df["UNIDADE"] == "Âµg/mÂ", "VALOR_ORIGINAL"] *= 868.26/10**6
    df.loc[df["UNIDADE"] == "µg/m³", "VALOR_ORIGINAL"] *= 868.26/10**6
    df.loc[df["UNIDADE"] == "µg/m3", "VALOR_ORIGINAL"] *= 868.26/10**6
    df.loc[df["UNIDADE"] == "ppb", "VALOR_ORIGINAL"] *= 1/1000

    df['UNIDADE'] = "ppm"

    return df

# %%
lista_pols = list(set(df_est['Poluente']))



for pol in lista_pols:

    print(pol)

    df_pol = df_est[df_est["Poluente"] == pol]

    lista_estacoes = list(set(df_pol['ID_MMA']))

    print(lista_estacoes)

    for estacao in lista_estacoes:

        if type(estacao) == str:

            cod_poluente = int(tabela_pols.loc[tabela_pols['POLUENTE'] == pol, 'COD_POLUENTE'].values[0])
           
            cod_poluente = f"{cod_poluente:03d}"

            print(cod_poluente)

            df_pol_est = df_pol[df_pol["ID_MMA"] == estacao]

            padrao = os.path.join(os.getcwd() + '/data/MQAr/'+pol+'/', f"{estacao}*.csv")
            arquivos = glob.glob(padrao)

            for arquivo in arquivos:

                print(arquivo)
                
                df_mma = pd.read_csv(arquivo, encoding = 'UTF-8')

                df_iema = df_pol_est[['Data','Hora','Valor','Unidade']]
                
                mask_24 = df_iema['Hora'].str.startswith('24')

                df_iema.loc[mask_24, 'Data'] = pd.to_datetime(df_iema.loc[mask_24, 'Data']) + pd.Timedelta(days=1)
                df_iema.loc[mask_24, 'Hora'] = '00:00:00'
                
                df_iema['Data'] = df_iema['Data'].astype(str)
                
                df_iema['DATETIME'] = pd.to_datetime(df_iema['Data'] + ' ' + df_iema['Hora'], errors='coerce')
                
                df_iema.drop(columns=['Data','Hora'], inplace=True)

                df_iema.rename(columns={'Valor':'VALOR_ORIGINAL','Unidade':'UNIDADE'},inplace=True)

                df_mma['DATETIME'] = pd.to_datetime(df_mma['DATETIME'], errors='coerce')
                df_iema['DATETIME'] = pd.to_datetime(df_iema['DATETIME'], errors='coerce')
                
                df_mma = df_mma.dropna(subset=['DATETIME'])
                df_iema = df_iema.dropna(subset=['DATETIME'])

                if pol == 'CO':
                    df_iema = ug_to_ppm(df_iema)
                
                df_iema = (
                    df_iema.sort_values('VALOR_ORIGINAL', ascending=False)
                           .drop_duplicates(subset='DATETIME', keep='first')
                )
                
                df_final = df_mma.merge(df_iema, on='DATETIME', how='left', suffixes=('', '_df2'))
                
                df_final['VALOR_ORIGINAL'] = df_final['VALOR_ORIGINAL_df2'].combine_first(df_final['VALOR_ORIGINAL'])
                df_final['UNIDADE'] = df_final['UNIDADE_df2'].combine_first(df_final['UNIDADE'])

                df_final['VALOR'] = df_final['VALOR_ORIGINAL']

                df_final.drop(columns=['VALOR_ORIGINAL'], inplace=True)

                df_final = create_QAQCMMA_VALOR(df_final,pol)
                
                print('iema')
                print(df_iema.head())
                print('mma')
                print(df_mma.head())
                print('final')
                print(df_final.head())

                df_final.to_csv(arquivo, index=False)

# %%
df_final = df_mma.merge(df_iema, on='DATETIME', how='left', suffixes=('', '_df2'))

df_mma = pd.read_csv(arquivo, encoding = 'UTF-8')

df_iema = df_pol_est[['Data','Hora','Valor','Unidade']]

mask_24 = df_iema['Hora'].str.startswith('24')

df_iema.loc[mask_24, 'Data'] = pd.to_datetime(df_iema.loc[mask_24, 'Data']) + pd.Timedelta(days=1)
df_iema.loc[mask_24, 'Hora'] = '00:00:00'

df_iema['Data'] = df_iema['Data'].astype(str)

df_iema['DATETIME'] = pd.to_datetime(df_iema['Data'] + ' ' + df_iema['Hora'], errors='coerce')

df_iema.drop(columns=['Data','Hora'], inplace=True)

df_iema.rename(columns={'Valor':'VALOR_ORIGINAL','Unidade':'UNIDADE'},inplace=True)

df_mma['DATETIME'] = pd.to_datetime(df_mma['DATETIME'], errors='coerce')
df_iema['DATETIME'] = pd.to_datetime(df_iema['DATETIME'], errors='coerce')

df_mma = df_mma.dropna(subset=['DATETIME'])
df_iema = df_iema.dropna(subset=['DATETIME'])

if pol == 'CO':
    df_iema = ug_to_ppm(df_iema)

df_iema = (
    df_iema.sort_values('VALOR_ORIGINAL', ascending=False)
           .drop_duplicates(subset='DATETIME', keep='first')
)

df_final = df_mma.merge(df_iema, on='DATETIME', how='left', suffixes=('', '_df2'))

# %%
caminho_MQAr = os.getcwd() + '/data/MQAr/'

lista_pols = os.listdir(caminho_MQAr)

arquivos_MQAr = pd.DataFrame({'ID_MMA_COMPLETO':[]})

for pol in lista_pols:

    if '.ipynb' not in pol and pol != 'METEREOLOGICO':

        caminho_pol = caminho_MQAr+pol

        estacoes_pols = os.listdir(caminho_pol)

        print(pol)

        for estacao in estacoes_pols:

            if estacao != '.ipynb_checkpoints':

                arquivos_MQAr.loc[len(arquivos_MQAr)] = estacao[:-4]

arquivos_MQAr['ID_MMA'] = arquivos_MQAr['ID_MMA_COMPLETO'].str[:6]

# %%
Monitoramento_MQAr = pd.read_csv(os.getcwd()+'/data/Monitoramento_QAr_BR.csv')

df_monitoramento = pd.DataFrame({'ID_MMA_COMPLETO':Monitoramento_MQAr['ID_MMA_COMPLETO']})

df_monitoramento['ID_MMA'] = df_monitoramento['ID_MMA_COMPLETO'].str[:6]

arquivos_MQAr['BANCO_DADOS'] = arquivos_MQAr['ID_MMA'].isin(df_monitoramento['ID_MMA']).map({True: 'Sim', False: 'Nao'})

print(arquivos_MQAr)

# %%
df_monitoramento

# %%
num_sim = (arquivos_MQAr['BANCO_DADOS'] == 'Sim').sum()
print(num_sim)

# %%
df_nao = arquivos_MQAr[arquivos_MQAr['BANCO_DADOS'] == 'Nao']
print(df_nao)

for id_mma_comp in df_nao['ID_MMA_COMPLETO']:
    if 'PA' in id_mma_comp:
        print(id_mma_comp)

# %%
caminho_MQAr = os.getcwd() + '/data/MQAr/'

lista_pols = os.listdir(caminho_MQAr)

arquivos_MQAr = pd.DataFrame({'ID_MMA_COMPLETO':[]})

for pol in lista_pols:

    if '.ipynb' not in pol and pol != 'METEREOLOGICO':

        caminho_pol = caminho_MQAr+pol

        estacoes_pols = os.listdir(caminho_pol)

        print(pol)

        for estacao in estacoes_pols:

            if estacao != '.ipynb_checkpoints':

                arquivos_MQAr.loc[len(arquivos_MQAr)] = estacao[:-4]

arquivos_MQAr['ID_MMA'] = arquivos_MQAr['ID_MMA_COMPLETO'].str[:6]

# %%
Monitoramento_MQAr = pd.read_csv(os.getcwd()+'/data/Monitoramento_QAr_BR.csv')

df_monitoramento = pd.DataFrame({'ID_MMA_COMPLETO':Monitoramento_MQAr['ID_MMA_COMPLETO']})

df_monitoramento['ID_MMA'] = df_monitoramento['ID_MMA_COMPLETO'].str[:6]

arquivos_MQAr['BANCO_DADOS'] = arquivos_MQAr['ID_MMA'].isin(df_monitoramento['ID_MMA']).map({True: 'Sim', False: 'Nao'})

print(arquivos_MQAr)

# %%
df_monitoramento

# %%
num_sim = (arquivos_MQAr['BANCO_DADOS'] == 'Sim').sum()
print(num_sim)

# %%
df_nao = arquivos_MQAr[arquivos_MQAr['BANCO_DADOS'] == 'Nao']
print(df_nao)

for id_mma_comp in df_nao['ID_MMA_COMPLETO']:
    if 'PA' in id_mma_comp:
        print(id_mma_comp)
