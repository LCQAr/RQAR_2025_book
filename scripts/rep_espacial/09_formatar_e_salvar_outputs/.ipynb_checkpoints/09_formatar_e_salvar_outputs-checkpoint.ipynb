# %% [markdown]
# # 1.0 Importando pacotes

# %%
import geopandas as gpd
from pathlib import Path
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2.0 Definindo caminhos

# %%
# Caminho da pasta de inputs
inputs_path = Path('./inputs').resolve()

# Caminho da pasta de outputs
outputs_path = Path('./outputs').resolve()

# Caminhos dos subsets
co_path = inputs_path / 'buffered_subset_co.parquet'
no2_path = inputs_path / 'buffered_subset_no2.parquet'
o3_path = inputs_path / 'buffered_subset_o3.parquet'
pm_path = inputs_path / 'buffered_subset_pm.parquet'
so2_path = inputs_path / 'buffered_subset_so2.parquet'

# %% [markdown]
# # 3.0 Carregando subsets

# %%
buffered_subset_co = gpd.read_parquet(co_path)
buffered_subset_no2 = gpd.read_parquet(no2_path)
buffered_subset_o3 = gpd.read_parquet(o3_path)
buffered_subset_pm = gpd.read_parquet(pm_path)
buffered_subset_so2 = gpd.read_parquet(so2_path)

# %% [markdown]
# # 4.0 Formatando outputs

# %%
# 1) estacoes_completa --------------------------------------------------------------
# Unindo poluentes em um gdf final completo
buffered_stations = pd.concat([buffered_subset_co,
                               buffered_subset_no2,
                               buffered_subset_o3,
                               buffered_subset_pm,
                               buffered_subset_so2])


# 2) rep_espacial -------------------------------------------------------------------
"""
Planilha original de estações de monitoramento + colunas [REP_ESPACIAL_NAME] e [REP_ESPACIAL]
    - REP_ESPACIAL_NAME: nome da classe de representatividade espacial (micro, meso, 
    bairro, urbana)
    - REP_ESPACIAL: tamanho do raio do buffer de representatividade em metros
"""
# Removendo colunas auxiliares
def drop_aux_cols(subset):
    return subset.drop(columns= (list(subset
                                      .filter(like='rep')
                                      .columns) +
                                 list(subset
                                      .filter(like='min')
                                      .columns) +
                                 list(subset
                                      .filter(like='max')
                                      .columns) +
                                 list(subset
                                      .filter(like='k')
                                      .columns) +
                                 list(subset
                                      .filter(like='micro')
                                      .columns) +
                                 list(subset
                                      .filter(like='meso')
                                      .columns) +
                                 list(subset
                                      .filter(like='bairro')
                                      .columns) +
                                 list(subset
                                      .filter(like='urb')
                                      .columns) +
                                 ['EPSG','distance_to_industry',
                                  'Razão Social', 'industry_geom']
                                 )
                       )
# Aplicando função
filtered_stations = drop_aux_cols(buffered_stations)

# %% [markdown]
# # 5.0 Salvando outputs

# %%
# Salvando o GeoDataFrame com a indústria mais próxima de cada estação
buffered_stations.to_parquet(outputs_path / 'estacoes_completa.parquet')

# Salvando o GeoDataFrame de input com as estações, sua classificação de 
# representatividade espacial e o tamanho do buffer
filtered_stations.to_csv(outputs_path + '/rep_espacial.csv')

# %%
filtered_stations.columns
# Out:
# Index(['UF', 'CIDADE', 'CD_MUN', 'ID_OEMA', 'ID_MMA', 'ID_MMA_COMPLETO',
#        'PROPRIETARIO', 'PROP_ENTIDADE', 'OPERADOR', 'OP_ENTIDADE',
#        'FUNCIONAMENTO', 'CATEGORIA', 'METODO', 'CALIBRACAO', 'MARCA', 'MODELO',
#        'POLUENTE', 'COD_POLUENTE', 'MOBILIDADE', 'FINALIDADE', 'STATUS',
#        'INICIO', 'FIM', 'LATITUDE', 'LONGITUDE', 'MONITORAR', 'FONTE',
#        'CERTIFICACAO', 'COD_UF_IBGE', 'ANOS_MONITORADOS', 'BASE_DADOS',
#        'ELEVACAO', 'RECONHECIDA', 'geometry', 'REP_ESPACIAL_NAME',
#        'osm_id_mais_prox_valida', 'REP_ESPACIAL'],
#       dtype='object')

# %%
filtered_stations
# Out:
#      UF                   CIDADE     CD_MUN  \
# 0    PR        São Mateus do Sul  4125605.0
# 1    PR             Ponta Grossa  4119905.0
# 2    RS             Porto Alegre  4314902.0
# 3    PA       São Félix do Xingu  1507300.0
# 4    PA      Ourilândia do Norte  1505437.0
# ..   ..                      ...        ...
# 172  PE                  Ipojuca  2607208.0
# 173  PE                  Ipojuca  2607208.0
# 174  PE                  Ipojuca  2607208.0
# 175  PE  Cabo de Santo Agostinho  2602902.0
# 176  PE                Sirinhaém  2614204.0
#
#                                   ID_OEMA  ID_MMA ID_MMA_COMPLETO  \
# 0                                     SIX  PR0013      PR0013A007
# 1                                     PGA  PR0005      PR0005A007
# 2                       Centro/Rodoviária    None            None
# 3                Estação AQM195 Minerasul  PA0004      PA0004A007
# 4    Estação Comunidade Vila de Bom Jesus  PA0005      PA0005A007
# ..                                    ...     ...             ...
# 172                          Estação Cupe  PE0004      PE0004A003
# 173                          Estação IFPE  PE0001      PE0001A003
# 174                       Estação Ipojuca  PE0002      PE0002A003
# 175                          Estação CPRH  PE0003      PE0003A003
# 176                        Estação  Suape  PE0005      PE0005A003
#
#     PROPRIETARIO PROP_ENTIDADE OPERADOR OP_ENTIDADE  ... CERTIFICACAO  \
# 0           None          None     None        None  ...  Certificada
# 1           None          None     None        None  ...  Certificada
# 2           None          None     None        None  ...  Certificada
# 3           None          None     None        None  ...  Certificada
# 4           None          None     None        None  ...  Certificada
# ..           ...           ...      ...         ...  ...          ...
# 172         None          None     None        None  ...  Certificada
# 173         None          None     None        None  ...  Certificada
# 174         None          None     None        None  ...  Certificada
# 175         None          None     None        None  ...  Certificada
# 176         None          None     None        None  ...  Certificada
#
#     COD_UF_IBGE ANOS_MONITORADOS BASE_DADOS ELEVACAO RECONHECIDA  \
# 0          41.0             None      False      797        None
# 1          41.0             None      False      939        None
# 2          43.0             None      False        6        None
# 3          15.0             None      False      231        None
# 4          15.0             None      False      285        None
# ..          ...              ...        ...      ...         ...
# 172        26.0             None      False       17        None
# 173        26.0             None      False       23        None
# 174        26.0             None      False       11        None
# 175        26.0             None      False       28        None
# 176        26.0             None      False        8        None
#
#                         geometry  REP_ESPACIAL_NAME osm_id_mais_prox_valida  \
# 0    POINT (-50.40821 -25.85898)             bairro                31614533
# 1    POINT (-50.15372 -25.09446)             bairro               722499856
# 2    POINT (-51.21958 -30.02383)             bairro               471664599
# 3        POINT (-51.2673 -6.565)             bairro               296927680
# 4       POINT (-51.0848 -6.5738)             bairro                31487301
# ..                           ...                ...                     ...
# 172     POINT (-35.0398 -8.3996)             bairro               651480482
# 173   POINT (-35.04156 -8.38485)             bairro               542946280
# 174   POINT (-35.01262 -8.43811)             bairro              1302726895
# 175   POINT (-35.02217 -8.33763)             bairro               386100723
# 176   POINT (-35.06901 -8.62347)             bairro               542935971
#
#     REP_ESPACIAL
# 0           4000
# 1           4000
# 2           4000
# 3           4000
# 4           4000
# ..           ...
# 172         4000
# 173         4000
# 174         4000
# 175         4000
# 176         4000
#
# [1745 rows x 37 columns]
