# %% [markdown]
# ## 1.2. Origem dos dados
#
# <div style="text-align: justify"> Foi realizada uma pesquisa nos endereços eletrônicos dos OEMAs (Orgãos Estaduais de Meio Ambiente), com o objetivo de verificar a disponibilidade de informações referentes à qualidade do ar, as características da rede de monitoramento e a publicação de dados, relatórios e planos.</div><br/>
# <div style="text-align: justify"> Em paralelo, foi aplicado um questionário aos OEMAs das 27 unidades federativas (UFs) do Brasil, no período entre 26 de julho e 16 de agosto, visando obter as seguintes informações:
#     <ul>
#       <li>características da rede de monitoramento no estado, se houver;</li>
#       <li>modo de divulgação de dados de qualidade do ar, se houver;</li>
#       <li>interligação com o Sistema MonitorAr;</li>
#       <li>disponibilização dos dados de qualidade do ar para o ano de 2023;</li>
#       <li>elaboração e divulgação de Relatório de Avaliação de Qualidade do Ar;</li>
#       <li>elaboração e aplicação de Plano de Controle de Emissões Atmosféricas;</li>
#       <li>elaboração e disponibilização de Inventário de Emissões Atmosféricas.</li>
#     </ul>
# </div><br/>
# <div style="text-align: justify">O questionário foi preenchido por todos os OEMAs das UFs do Brasil, atingindo uma taxa de retorno de 100%.</div><br/>
# <div style="text-align: justify">As informações obtidas por meio do questionário foram compiladas e, em alguns casos, complementadas com os dados disponíveis no Sistema Nacional de Gestão da Qualidade do Ar (MonitorAr). A Tabela 1 sintetiza a origem dos dados e as características do monitoramento da qualidade do ar nas UFs brasileiras. A Tabela 2 indica a origem dos dados utilizados para a avaliação da qualidade do ar no Brasil no ano de 2023, nas UFs que possuem monitoramento do ar sistemático.</div><br/>
#
# <div class="alert alert-block alert-warning">
#    <b>⚠️ Alerta: </b> Alguns OEMAs informaram ter recebido os dados para o ano de 2023 somente mediante o envio de relatórios periódicos de empreendimentos licenciados que realizam o monitoramento, o que não permite o acesso aos dados em sua fonte. Nos casos em que os dados desses OEMAs estavam disponíveis no Sistema MonitorAr, estes foram utilizados.</p>
# </div>
#
# ⚠️ Alguns OEMAs informaram ter recebido os dados para o ano de 2023 somente mediante o envio de relatórios periódicos de empreendimentos licenciados que realizam o monitoramento, o que não permite o acesso aos dados em sua fonte. Nos casos em que os dados desses OEMAs estavam disponíveis no Sistema MonitorAr, estes foram utilizados.
#
# ℹ️ This is an info message.
#
# ⚠️ Consider this a warning.
#
# ❌ This is a very serious danger message.
#
# ✅ This is an affirmation message.
#
#
# <div style="text-align: justify"></div><br/>
#
# <div style="text-align: justify">Ainda, foram compiladas as informações sobre os Relatórios de Avaliação de Qualidade do Ar, Planos de Controle de Emissão Atmosférica e Inventários de Emissões Atmosféricas dos OEMAs. Essa compilação foi conduzida a partir das informações disponíveis nas páginas eletrônicas de cada OEMA e das respostas ao questionário aplicado pelo MMA. </div>

# %%
# Criar código para ordenar por região e identificar estados que não fazem monitoramento - ver tabelas 1 e 2 do relatório anterior
# Incluir bandeiras dos estados e melhorar o estilo do HTML
# + tags=["hide-input"]
import scripts.flagTables as flagtab
flagtab.table01()
# Out:
# <style type="text/css">
# #T_1728e th {
#   text-align: center;
# }
# #T_1728e_row0_col0, #T_1728e_row0_col1, #T_1728e_row0_col2, #T_1728e_row0_col3, #T_1728e_row1_col0, #T_1728e_row1_col1, #T_1728e_row1_col2, #T_1728e_row1_col3, #T_1728e_row6_col0, #T_1728e_row6_col1, #T_1728e_row6_col2, #T_1728e_row6_col3, #T_1728e_row7_col0, #T_1728e_row7_col1, #T_1728e_row7_col2, #T_1728e_row7_col3, #T_1728e_row17_col0, #T_1728e_row17_col1, #T_1728e_row17_col2, #T_1728e_row17_col3, #T_1728e_row18_col0, #T_1728e_row18_col1, #T_1728e_row18_col2, #T_1728e_row18_col3, #T_1728e_row26_col0, #T_1728e_row26_col1, #T_1728e_row26_col2, #T_1728e_row26_col3, #T_1728e_row27_col0, #T_1728e_row27_col1, #T_1728e_row27_col2, #T_1728e_row27_col3, #T_1728e_row32_col0, #T_1728e_row32_col1, #T_1728e_row32_col2, #T_1728e_row32_col3, #T_1728e_row33_col0, #T_1728e_row33_col1, #T_1728e_row33_col2, #T_1728e_row33_col3, #T_1728e_row37_col0, #T_1728e_row37_col1, #T_1728e_row37_col2, #T_1728e_row37_col3 {
#   background-color: white;
#   color: black;
#   text-align: center;
#   font-weight: bold;
#   font-size: 11px;
# }
# #T_1728e_row2_col0, #T_1728e_row2_col1, #T_1728e_row2_col2, #T_1728e_row2_col3, #T_1728e_row3_col0, #T_1728e_row3_col1, #T_1728e_row3_col2, #T_1728e_row3_col3, #T_1728e_row4_col0, #T_1728e_row4_col1, #T_1728e_row4_col2, #T_1728e_row4_col3, #T_1728e_row5_col0, #T_1728e_row5_col1, #T_1728e_row5_col2, #T_1728e_row5_col3, #T_1728e_row8_col0, #T_1728e_row8_col1, #T_1728e_row8_col2, #T_1728e_row8_col3, #T_1728e_row9_col0, #T_1728e_row9_col1, #T_1728e_row9_col2, #T_1728e_row9_col3, #T_1728e_row10_col0, #T_1728e_row10_col1, #T_1728e_row10_col2, #T_1728e_row10_col3, #T_1728e_row11_col0, #T_1728e_row11_col1, #T_1728e_row11_col2, #T_1728e_row11_col3, #T_1728e_row12_col0, #T_1728e_row12_col1, #T_1728e_row12_col2, #T_1728e_row12_col3, #T_1728e_row13_col0, #T_1728e_row13_col1, #T_1728e_row13_col2, #T_1728e_row13_col3, #T_1728e_row14_col0, #T_1728e_row14_col1, #T_1728e_row14_col2, #T_1728e_row14_col3, #T_1728e_row15_col0, #T_1728e_row15_col1, #T_1728e_row15_col2, #T_1728e_row15_col3, #T_1728e_row16_col0, #T_1728e_row16_col1, #T_1728e_row16_col2, #T_1728e_row16_col3, #T_1728e_row19_col0, #T_1728e_row19_col1, #T_1728e_row19_col2, #T_1728e_row19_col3, #T_1728e_row20_col0, #T_1728e_row20_col1, #T_1728e_row20_col2, #T_1728e_row20_col3, #T_1728e_row21_col0, #T_1728e_row21_col1, #T_1728e_row21_col2, #T_1728e_row21_col3, #T_1728e_row22_col0, #T_1728e_row22_col1, #T_1728e_row22_col2, #T_1728e_row22_col3, #T_1728e_row23_col0, #T_1728e_row23_col1, #T_1728e_row23_col2, #T_1728e_row23_col3, #T_1728e_row24_col0, #T_1728e_row24_col1, #T_1728e_row24_col2, #T_1728e_row24_col3, #T_1728e_row25_col0, #T_1728e_row25_col1, #T_1728e_row25_col2, #T_1728e_row25_col3, #T_1728e_row28_col0, #T_1728e_row28_col1, #T_1728e_row28_col2, #T_1728e_row28_col3, #T_1728e_row29_col0, #T_1728e_row29_col1, #T_1728e_row29_col2, #T_1728e_row29_col3, #T_1728e_row30_col0, #T_1728e_row30_col1, #T_1728e_row30_col2, #T_1728e_row30_col3, #T_1728e_row31_col0, #T_1728e_row31_col1, #T_1728e_row31_col2, #T_1728e_row31_col3, #T_1728e_row34_col0, #T_1728e_row34_col1, #T_1728e_row34_col2, #T_1728e_row34_col3, #T_1728e_row35_col0, #T_1728e_row35_col1, #T_1728e_row35_col2, #T_1728e_row35_col3, #T_1728e_row36_col0, #T_1728e_row36_col1, #T_1728e_row36_col2, #T_1728e_row36_col3 {
#   background-color: #F5F5F5;
#   color: black;
#   text-align: center;
#   font-size: 11px;
# }
# </style>
# <table id="T_1728e">
#   <thead>
#     <tr>
#       <th id="T_1728e_level0_col0" class="col_heading level0 col0" ></th>
#       <th id="T_1728e_level0_col1" class="col_heading level0 col1" >UF</th>
#       <th id="T_1728e_level0_col2" class="col_heading level0 col2" >Realiza monitoramento?</th>
#       <th id="T_1728e_level0_col3" class="col_heading level0 col3" >Fonte</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1728e_row0_col0" class="data row0 col0" ></td>
#       <td id="T_1728e_row0_col1" class="data row0 col1" ></td>
#       <td id="T_1728e_row0_col2" class="data row0 col2" ></td>
#       <td id="T_1728e_row0_col3" class="data row0 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_1728e_row1_col0" class="data row1 col0" ></td>
#       <td id="T_1728e_row1_col1" class="data row1 col1" >Centro-Oeste</td>
#       <td id="T_1728e_row1_col2" class="data row1 col2" ></td>
#       <td id="T_1728e_row1_col3" class="data row1 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_1728e_row2_col0" class="data row2 col0" ><img src= "../_static/bandeiras/DF.png" width="30"></td>
#       <td id="T_1728e_row2_col1" class="data row2 col1" >DF</td>
#       <td id="T_1728e_row2_col2" class="data row2 col2" >Sim</td>
#       <td id="T_1728e_row2_col3" class="data row2 col3" >Consulta 2024</td>
#     </tr>
#     <tr>
#       <td id="T_1728e_row3_col0" class="data row3 col0" ><img src= "../_static/bandeiras/GO.png" width="30"></td>
#       <td id="T_1728e_row3_col1" class="data row3 col1" >GO</td>
#       <td id="T_1728e_row3_col2" class="data row3 col2" >Sim</td>
#       <td id="T_1728e_row3_col3" class="data row3 col3" >Consulta 2024</td>
#     </tr>
#     <tr>
#       <td id="T_1728e_row4_col0" class="data row4 col0" ><img src= "../_static/bandeiras/MT.png" width="30"></td>
#       <td id="T_1728e_row4_col1" class="data row4 col1" >MT</td>
#       <td id="T_1728e_row4_col2" class="data row4 col2" >Sim</td>
#       <td id="T_1728e_row4_col3" class="data row4 col3" >Consulta 2024</td>
#     </tr>
#     <tr>
#       <td id="T_1728e_row5_col0" class="data row5 col0" ><img src= "../_static/bandeiras/MS.png" width="30"></td>
#       <td id="T_1728e_row5_col1" class="data row5 col1" >MS</td>
#       <td id="T_1728e_row5_col2" class="data row5 col2" >Sim</td>
#       <td id="T_1728e_row5_col3" class="data row5 col3" >Consulta 2024</td>
#     </tr>
#     <tr>
#       <td id="T_1728e_row6_col0" class="data row6 col0" ></td>
#       <td id="T_1728e_row6_col1" class="data row6 col1" ></td>
#       <td id="T_1728e_row6_col2" class="data row6 col2" ></td>
#       <td id="T_1728e_row6_col3" class="data row6 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_1728e_row7_col0" class="data row7 col0" ></td>
#       <td id="T_1728e_row7_col1" class="data row7 col1" >Nordeste</td>
#       <td id="T_1728e_row7_col2" class="data row7 col2" ></td>
#       <td id="T_1728e_row7_col3" class="data row7 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_1728e_row8_col0" class="data row8 col0" ><img src= "../_static/bandeiras/AL.png" width="30"></td>
#       <td id="T_1728e_row8_col1" class="data row8 col1" >AL</td>
#       <td id="T_1728e_row8_col2" class="data row8 col2" >Não</td>
#       <td id="T_1728e_row8_col3" class="data row8 col3" >-</td>
#     </tr>
#     <tr>
#       <td id="T_1728e_row9_col0" class="data row9 col0" ><img src= "../_static/bandeiras/BA.png" width="30"></td>
#       <td id="T_1728e_row9_col1" class="data row9 col1" >BA</td>
#       <td id="T_1728e_row9_col2" class="data row9 col2" >Sim</td>
#       <td id="T_1728e_row9_col3" class="data row9 col3" >MonitorAr</td>
#     </tr>
#     <tr>
#       <td id="T_1728e_row10_col0" class="data row10 col0" ><img src= "../_static/bandeiras/CE.png" width="30"></td>
#       <td id="T_1728e_row10_col1" class="data row10 col1" >CE</td>
#       <td id="T_1728e_row10_col2" class="data row10 col2" >Sim</td>
#       <td id="T_1728e_row10_col3" class="data row10 col3" >Consulta 2024</td>
#     </tr>
#     <tr>
#       <td id="T_1728e_row11_col0" class="data row11 col0" ><img src= "../_static/bandeiras/MA.png" width="30"></td>
#       <td id="T_1728e_row11_col1" class="data row11 col1" >MA</td>
#       <td id="T_1728e_row11_col2" class="data row11 col2" >Sim</td>
#       <td id="T_1728e_row11_col3" class="data row11 col3" >MonitorAr, Consulta 2024</td>
#     </tr>
#     <tr>
#       <td id="T_1728e_row12_col0" class="data row12 col0" ><img src= "../_static/bandeiras/PB.png" width="30"></td>
#       <td id="T_1728e_row12_col1" class="data row12 col1" >PB</td>
#       <td id="T_1728e_row12_col2" class="data row12 col2" >Não</td>
#       <td id="T_1728e_row12_col3" class="data row12 col3" >-</td>
#     </tr>
#     <tr>

# %% [markdown]
# ```{warning}
# Os estados que não monitoram a qualidade do ar também responderam a Consulta 2024
# ```
