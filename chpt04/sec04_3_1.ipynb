# %% [markdown]
# # 4.3.1.	Violações dos padrões de qualidade do ar no Brasil

# %%
import sys
sys.path.append("../scripts")

from mapa_violacoes_interativo import mapa_violacoes_interativo
mapa_violacoes_interativo("/home/nobre/Notebooks/RQAR_2025_book")
