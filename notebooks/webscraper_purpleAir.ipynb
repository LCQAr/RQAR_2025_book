# %%
import requests
import pandas as pd
from datetime import datetime
import os
import time

# ================================
# CONFIGURAÇÕES
# ================================
API_KEY = "BF90A113-835D-11F0-BDE5-4201AC1DC121"

# Região geográfica (bounding box)
# Exemplo: litoral de Santa Catarina
NW_LAT, NW_LNG = 5.27, -74.02    # canto Noroeste da Amazônia
SE_LAT, SE_LNG = -33.75, -34.79  # canto Sudeste perto do oceano Atlântico


# Período de interesse
START_DATE = "2025-08-01"
END_DATE   = "2025-08-01"

# Média temporal em minutos (ex: 60 = média horária)
AVERAGE = 60  

# Pasta para salvar os arquivos
OUTPUT_DIR = "purpleair_region_data"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ================================
# FUNÇÃO PARA LISTAR SENSORES NA REGIÃO
# ================================
def get_sensors_in_region(api_key, nw_lat, nw_lng, se_lat, se_lng):
    """Busca todos os sensores dentro de um bounding box"""
    url = "https://api.purpleair.com/v1/sensors"
    headers = {"X-API-Key": api_key}
    
    params = {
        "fields": "sensor_index,name,latitude,longitude,pm2.5_atm,pm1.0_atm,pm10.0_atm,last_seen",
        "location_type": 0,
        "nwlng": nw_lng,
        "nwlat": nw_lat,
        "selng": se_lng,
        "selat": se_lat,
    }
    
    r = requests.get(url, headers=headers, params=params)
    
    if r.status_code == 200:
        data = r.json()
        fields = data["fields"]
        values = data["data"]
        df = pd.DataFrame(values, columns=fields)
        df["last_seen"] = pd.to_datetime(df["last_seen"], unit="s")
        return df
    else:
        print(f"❌ Erro ao buscar sensores: {r.status_code} {r.text}")
        return pd.DataFrame()

# ================================
# FUNÇÃO PARA BAIXAR HISTÓRICO DE UM SENSOR
# ================================
def download_history(sensor_id, start_date, end_date, average=60, api_key=None):
    url = f"https://api.purpleair.com/v1/sensors/{sensor_id}/history"
    
    params = {
        "fields": "pm2.5_atm,pm1.0_atm,pm10.0_atm,temperature,humidity,pressure",
        "start_timestamp": int(datetime.fromisoformat(start_date).timestamp()),
        "end_timestamp": int(datetime.fromisoformat(end_date).timestamp()),
        "average": average,
    }
    
    headers = {"X-API-Key": api_key}
    r = requests.get(url, headers=headers, params=params)
    
    if r.status_code == 200:
        data = r.json()
        if "data" in data and data["data"]:
            fields = data["fields"]
            values = data["data"]
            df = pd.DataFrame(values, columns=fields)
            df["time_stamp"] = pd.to_datetime(df["time_stamp"], unit="s")
            return df
        else:
            print(f"⚠️ Sem dados para o sensor {sensor_id}")
            return None
    else:
        print(f"❌ Erro {r.status_code} no sensor {sensor_id}: {r.text}")
        return None

# ================================
# EXECUÇÃO
# ================================
print("📍 Buscando sensores na região...")
sensors_df = get_sensors_in_region(API_KEY, NW_LAT, NW_LNG, SE_LAT, SE_LNG)

if sensors_df.empty:
    print("Nenhum sensor encontrado.")
else:
    print(f"✅ {len(sensors_df)} sensores encontrados.")

    for _, row in sensors_df.iterrows():
        sid = int(row["sensor_index"])
        name = row["name"].replace(" ", "_") if row["name"] else f"sensor_{sid}"
        
        print(f"\n📥 Baixando histórico do sensor {sid} ({name})...")
        df_hist = download_history(sid, START_DATE, END_DATE, AVERAGE, API_KEY)
        
        if df_hist is not None:
            filename = os.path.join(OUTPUT_DIR, f"{name}_{sid}.csv")
            df_hist.to_csv(filename, index=False)
            print(f"   ✅ Dados salvos em {filename}")
        
        time.sleep(1)  # evitar excesso de requisições
# Out:
# 📍 Buscando sensores na região...
# ✅ 303 sensores encontrados.
#
# 📥 Baixando histórico do sensor 262813 (PELD-TANG)...
# ⚠️ Sem dados para o sensor 262813
#
# 📥 Baixando histórico do sensor 275450 (Vielas_da_Água_Preta)...
# ⚠️ Sem dados para o sensor 275450
#
# 📥 Baixando histórico do sensor 287170 (GEOHealth_TAC_GregorioA)...
# ⚠️ Sem dados para o sensor 287170
#
# 📥 Baixando histórico do sensor 287176 (GEOHealth_MAD_PuertoM_Wasai)...
# ⚠️ Sem dados para o sensor 287176
#
# 📥 Baixando histórico do sensor 25541 (MPAC_PTA_01_Sec.infraestrutura)...
# ⚠️ Sem dados para o sensor 25541
#
# 📥 Baixando histórico do sensor 25551 (MPAC_FIJ_01_promotoria)...
# ⚠️ Sem dados para o sensor 25551
#
# 📥 Baixando histórico do sensor 25891 (MPAC_BJR_01_promotoria)...
# ⚠️ Sem dados para o sensor 25891
#
# 📥 Baixando histórico do sensor 27841 (MPAC_BRL_01_promotoria)...
# ⚠️ Sem dados para o sensor 27841
#
# 📥 Baixando histórico do sensor 31091 (MPAC_TRC_02_ifac)...
# ⚠️ Sem dados para o sensor 31091
#
# 📥 Baixando histórico do sensor 31103 (MPAC_SNM_01_ifac)...
# ⚠️ Sem dados para o sensor 31103
#
# 📥 Baixando histórico do sensor 31105 (MPAC_ABR_01_promotoria)...
# ⚠️ Sem dados para o sensor 31105
#
# 📥 Baixando histórico do sensor 31109 (Ministério_Público_do_Estado_do_Acre_(SEDE))...
# ⚠️ Sem dados para o sensor 31109
#
# 📥 Baixando histórico do sensor 31111 (MPAC_JRD_01_prefeitura)...
# ⚠️ Sem dados para o sensor 31111
#
# 📥 Baixando histórico do sensor 31117 (MPAC_EPL_01_camara)...
# ⚠️ Sem dados para o sensor 31117
#
# 📥 Baixando histórico do sensor 31299 (AcreBioClimaIII_-_UFAC)...
# ⚠️ Sem dados para o sensor 31299
#
# 📥 Baixando histórico do sensor 31509 (UEA-EST)...
# ⚠️ Sem dados para o sensor 31509
#
# 📥 Baixando histórico do sensor 31547 (Meireles-Fortaleza-Brazil)...
# ⚠️ Sem dados para o sensor 31547
#
# 📥 Baixando histórico do sensor 35553 (COER_MDD_PEM)...
# ⚠️ Sem dados para o sensor 35553
#
# 📥 Baixando histórico do sensor 36665 (Casa_magica)...
# ⚠️ Sem dados para o sensor 36665
#
# 📥 Baixando histórico do sensor 39085 (UF_-_Coker_Lab_-_Cacoal_-_Rondônia_-_Brazil)...
# ⚠️ Sem dados para o sensor 39085
#
# 📥 Baixando histórico do sensor 43293 (REDES+_Calibracion_06)...
# ⚠️ Sem dados para o sensor 43293
#
# 📥 Baixando histórico do sensor 43457 (REDES+_Calibracion_07)...
# ⚠️ Sem dados para o sensor 43457
#
# 📥 Baixando histórico do sensor 43459 (REDES+_Calibracion_31)...
# ⚠️ Sem dados para o sensor 43459
#
# 📥 Baixando histórico do sensor 43647 (REDES+_Calibracion_15)...
# ⚠️ Sem dados para o sensor 43647
#
# 📥 Baixando histórico do sensor 43707 (REDES+_Calibracion_38)...
# ⚠️ Sem dados para o sensor 43707
#
# 📥 Baixando histórico do sensor 45277 (REDES+_Calibracion_42)...
# ⚠️ Sem dados para o sensor 45277
#
# 📥 Baixando histórico do sensor 45279 (REDES+_Calibracion_20)...
# ⚠️ Sem dados para o sensor 45279
#
# 📥 Baixando histórico do sensor 45283 (REDES+_Calibracion_11)...
# ⚠️ Sem dados para o sensor 45283
#
# 📥 Baixando histórico do sensor 46357 (REDES+_Calibracion_09)...
# ⚠️ Sem dados para o sensor 46357
#
# 📥 Baixando histórico do sensor 46539 (REDES+_Calibracion_01)...
# ⚠️ Sem dados para o sensor 46539
#
# 📥 Baixando histórico do sensor 46549 (REDES+_Calibracion_59)...
# ⚠️ Sem dados para o sensor 46549
#
# 📥 Baixando histórico do sensor 46555 (REDES+_Calibracion_03)...
# ⚠️ Sem dados para o sensor 46555
#
# 📥 Baixando histórico do sensor 46557 (REDES+_Calibracion_02)...
# ⚠️ Sem dados para o sensor 46557
#
# 📥 Baixando histórico do sensor 46699 (REDES+_Calibracion_04)...
# ⚠️ Sem dados para o sensor 46699
#
# 📥 Baixando histórico do sensor 46709 (REDES+_Calibracion_47)...
# ⚠️ Sem dados para o sensor 46709
#
# 📥 Baixando histórico do sensor 46721 (REDES+_Calibracion_19)...
# ⚠️ Sem dados para o sensor 46721
#
# 📥 Baixando histórico do sensor 46805 (REDES+_Calibracion_05)...
# ⚠️ Sem dados para o sensor 46805
#
# 📥 Baixando histórico do sensor 46813 (Las_Condes_01)...
# ⚠️ Sem dados para o sensor 46813
#
# 📥 Baixando histórico do sensor 46815 (REDES+_Calibracion_13)...
# ⚠️ Sem dados para o sensor 46815
#
# 📥 Baixando histórico do sensor 46831 (Redes+46)...
# ⚠️ Sem dados para o sensor 46831
#
# 📥 Baixando histórico do sensor 46893 (REDES+_Calibracion_21)...
# ⚠️ Sem dados para o sensor 46893
#
# 📥 Baixando histórico do sensor 46897 (REDES+_Calibracion_56)...
# ⚠️ Sem dados para o sensor 46897
#
# 📥 Baixando histórico do sensor 46903 (REDES+_Calibracion_52)...
# ⚠️ Sem dados para o sensor 46903
#
# 📥 Baixando histórico do sensor 46905 (Redes+57)...
# ⚠️ Sem dados para o sensor 46905
#
# 📥 Baixando histórico do sensor 46913 (REDES+_Calibracion_53)...
# ⚠️ Sem dados para o sensor 46913
#
# 📥 Baixando histórico do sensor 47025 (REDES+_Calibracion_27)...
# ⚠️ Sem dados para o sensor 47025
#
# 📥 Baixando histórico do sensor 47033 (REDES+_Calibracion_48)...
# ⚠️ Sem dados para o sensor 47033
#
# 📥 Baixando histórico do sensor 47035 (REDES+_Calibracion_43)...
# ⚠️ Sem dados para o sensor 47035
#
# 📥 Baixando histórico do sensor 47055 (REDES+_Calibracion_26)...
# ⚠️ Sem dados para o sensor 47055
#
# 📥 Baixando histórico do sensor 47057 (REDES+_Calibracion_39)...
# ⚠️ Sem dados para o sensor 47057
#
# 📥 Baixando histórico do sensor 47063 (REDES+_Calibracion_33)...
# ⚠️ Sem dados para o sensor 47063
#
# 📥 Baixando histórico do sensor 47071 (REDES+_Calibracion_36)...
# ⚠️ Sem dados para o sensor 47071
#
# 📥 Baixando histórico do sensor 47079 (Redes+29)...
# ⚠️ Sem dados para o sensor 47079
#
# 📥 Baixando histórico do sensor 47081 (REDES+_Calibracion_37)...
# ⚠️ Sem dados para o sensor 47081
#
# 📥 Baixando histórico do sensor 47099 (REDES+_Calibracion_28)...
# ⚠️ Sem dados para o sensor 47099
#
# 📥 Baixando histórico do sensor 47175 (REDES+_Calibracion_55)...
# ⚠️ Sem dados para o sensor 47175
#
# 📥 Baixando histórico do sensor 47187 (REDES+_Calibracion_17)...
# ⚠️ Sem dados para o sensor 47187
#
# 📥 Baixando histórico do sensor 47191 (REDES+_Calibracion_24)...
# ⚠️ Sem dados para o sensor 47191
#
# 📥 Baixando histórico do sensor 47193 (REDES+_Calibracion_18)...
# ⚠️ Sem dados para o sensor 47193
#
# 📥 Baixando histórico do sensor 47195 (REDES+_Calibracion_10)...
# ⚠️ Sem dados para o sensor 47195
#
# 📥 Baixando histórico do sensor 47197 (REDES+_Calibracion_40)...
# ⚠️ Sem dados para o sensor 47197
#
# 📥 Baixando histórico do sensor 47201 (REDES+_Calibracion_16)...
# ⚠️ Sem dados para o sensor 47201
#
# 📥 Baixando histórico do sensor 47203 (REDES+_Calibracion_12)...
# ⚠️ Sem dados para o sensor 47203
#
# 📥 Baixando histórico do sensor 47205 (REDES+_Calibracion_23)...
# ⚠️ Sem dados para o sensor 47205
#
# 📥 Baixando histórico do sensor 47209 (REDES+_Calibracion_30)...
# ⚠️ Sem dados para o sensor 47209
#
# 📥 Baixando histórico do sensor 47213 (Facultad_de_Ciencias_y_Tecnología)...
# ⚠️ Sem dados para o sensor 47213
#
# 📥 Baixando histórico do sensor 47215 (REDES+_Calibracion_32)...
# ⚠️ Sem dados para o sensor 47215
#
# 📥 Baixando histórico do sensor 47217 (REDES+_Calibracion_25)...
# ⚠️ Sem dados para o sensor 47217
#
# 📥 Baixando histórico do sensor 56663 (MPAC_SNG_01_promotoria)...
# ⚠️ Sem dados para o sensor 56663
#
# 📥 Baixando histórico do sensor 56843 (MPRR_BVB_01_procuradoria)...
# ⚠️ Sem dados para o sensor 56843
#
# 📥 Baixando histórico do sensor 56891 (MPTO_PMW_01_procuradoriageral)...
# ⚠️ Sem dados para o sensor 56891
#
# 📥 Baixando histórico do sensor 57039 (INPA_Roraima)...
# ⚠️ Sem dados para o sensor 57039
#
# 📥 Baixando histórico do sensor 57287 (UFACFloresta)...
# ⚠️ Sem dados para o sensor 57287
#
# 📥 Baixando histórico do sensor 87305 (SAL402101)...
# ⚠️ Sem dados para o sensor 87305
#
# 📥 Baixando histórico do sensor 87341 (CUB400101)...
# ⚠️ Sem dados para o sensor 87341
#
# 📥 Baixando histórico do sensor 91751 (UNAM-EPIAM2)...
# ⚠️ Sem dados para o sensor 91751
#
# 📥 Baixando histórico do sensor 98395 (FAS-Ar)...
# ⚠️ Sem dados para o sensor 98395
#
# 📥 Baixando histórico do sensor 102456 (MPAP_STN_01_procuradoria)...
# ⚠️ Sem dados para o sensor 102456
#
# 📥 Baixando histórico do sensor 103270 (MPAP_FGO_01_promotoria)...
# ⚠️ Sem dados para o sensor 103270
#
# 📥 Baixando histórico do sensor 103306 (MPAP_MZG_01_promotoria)...
# ⚠️ Sem dados para o sensor 103306
#
# 📥 Baixando histórico do sensor 103330 (MPAP_CAL_01_promotoria)...
# ⚠️ Sem dados para o sensor 103330
#
# 📥 Baixando histórico do sensor 103340 (MPAP_MCP_01_procuradoria)...
# ⚠️ Sem dados para o sensor 103340
#
# 📥 Baixando histórico do sensor 103348 (MPAP_LJI_01_promotoria)...
# ⚠️ Sem dados para o sensor 103348
#
# 📥 Baixando histórico do sensor 112090 (Fundo_Alhué)...
# ⚠️ Sem dados para o sensor 112090
#
# 📥 Baixando histórico do sensor 120219 (MPAP_OPE_01_promotoria)...
# ⚠️ Sem dados para o sensor 120219
#
# 📥 Baixando histórico do sensor 127887 (Parque_Nacional_da_Chapada_do_Guimarães)...
# ⚠️ Sem dados para o sensor 127887
#
# 📥 Baixando histórico do sensor 128043 (TI_Kadiwéw)...
# ⚠️ Sem dados para o sensor 128043
#
# 📥 Baixando histórico do sensor 128603 (Estação_Ecológica_de_Cuniã)...
# ⚠️ Sem dados para o sensor 128603
#
# 📥 Baixando histórico do sensor 128613 (UFMT_Sinop)...
# ⚠️ Sem dados para o sensor 128613
#
# 📥 Baixando histórico do sensor 128639 (Guarajá-Mirim_(ICMBio))...
# ⚠️ Sem dados para o sensor 128639
#
# 📥 Baixando histórico do sensor 128665 (Universidad_de_los_Llanos_-_Vereda_Barcelona)...
# ⚠️ Sem dados para o sensor 128665
#
# 📥 Baixando histórico do sensor 128669 (Fazenda_São_Nicolau_(ONF))...
# ⚠️ Sem dados para o sensor 128669
#
# 📥 Baixando histórico do sensor 128701 (REP-Colinas_do_Tocantins)...
# ⚠️ Sem dados para o sensor 128701
#
# 📥 Baixando histórico do sensor 128973 (UNEMAT_-_Alta_Floresta)...
# ⚠️ Sem dados para o sensor 128973
#
# 📥 Baixando histórico do sensor 128983 (TI_Uaçá,_Aldeia_Santa_Izabel)...
# ⚠️ Sem dados para o sensor 128983
#
# 📥 Baixando histórico do sensor 128987 (Tefé_IDSM)...
# ⚠️ Sem dados para o sensor 128987
#
# 📥 Baixando histórico do sensor 128995 (Cuiabá_-_IPAM)...
# ⚠️ Sem dados para o sensor 128995
#
# 📥 Baixando histórico do sensor 128999 (Santarém_(IPAM))...
# ⚠️ Sem dados para o sensor 128999
#
# 📥 Baixando histórico do sensor 129001 (IPAM_Canarana_Office)...
# ⚠️ Sem dados para o sensor 129001
#
# 📥 Baixando histórico do sensor 129007 (Fazenda_Jofre_Velho_-_Panthera)...
# ⚠️ Sem dados para o sensor 129007
#
# 📥 Baixando histórico do sensor 129145 ((IPAM)_Torre_Atto)...
# ⚠️ Sem dados para o sensor 129145
#
# 📥 Baixando histórico do sensor 129571 (CDA-Guaviare)...
# ⚠️ Sem dados para o sensor 129571
#
# 📥 Baixando histórico do sensor 131323 (Cabana)...
# ⚠️ Sem dados para o sensor 131323
#
# 📥 Baixando histórico do sensor 131787 (Pipiripi)...
# ⚠️ Sem dados para o sensor 131787
#
# 📥 Baixando histórico do sensor 132065 (PARNA_Viruá)...
# ⚠️ Sem dados para o sensor 132065
#
# 📥 Baixando histórico do sensor 133225 (Oficina)...
# ⚠️ Sem dados para o sensor 133225
#
# 📥 Baixando histórico do sensor 137722 (Escola_115_Norte)...
# ⚠️ Sem dados para o sensor 137722
#
# 📥 Baixando histórico do sensor 140920 (Atuncolla)...
# ⚠️ Sem dados para o sensor 140920
#
# 📥 Baixando histórico do sensor 140944 (Coata)...
# ⚠️ Sem dados para o sensor 140944
#
# 📥 Baixando histórico do sensor 140976 (Pomata)...
# ⚠️ Sem dados para o sensor 140976
#
# 📥 Baixando histórico do sensor 141522 (Capachica)...
# ⚠️ Sem dados para o sensor 141522
#
# 📥 Baixando histórico do sensor 141632 (Zepita)...
# ⚠️ Sem dados para o sensor 141632
#
# 📥 Baixando histórico do sensor 141644 (Moho)...
# ⚠️ Sem dados para o sensor 141644
#
# 📥 Baixando histórico do sensor 141648 (Kelluyo)...
# ⚠️ Sem dados para o sensor 141648
#
# 📥 Baixando histórico do sensor 141654 (Chucuito)...
# ⚠️ Sem dados para o sensor 141654
#
# 📥 Baixando histórico do sensor 141674 (Ñaupapampa)...
# ⚠️ Sem dados para o sensor 141674
#
# 📥 Baixando histórico do sensor 143166 (Monumento_Tres_Cabezas)...
# ⚠️ Sem dados para o sensor 143166
#
# 📥 Baixando histórico do sensor 143638 (Plaza_Principal_Cobija)...
# ⚠️ Sem dados para o sensor 143638
#
# 📥 Baixando histórico do sensor 151650 (AcreBioClima_-_UFAC)...
# ⚠️ Sem dados para o sensor 151650
#
# 📥 Baixando histórico do sensor 158545 (GEOHealth_UCAY_Purus)...
# ⚠️ Sem dados para o sensor 158545
#
# 📥 Baixando histórico do sensor 158991 (GEOHealth_ARE_Cocachacra)...
# ⚠️ Sem dados para o sensor 158991
#
# 📥 Baixando histórico do sensor 159625 (GEOHealth_AREQ_UNSA_1)...
# ⚠️ Sem dados para o sensor 159625
#
# 📥 Baixando histórico do sensor 160803 (RJ02)...
# ⚠️ Sem dados para o sensor 160803
#
# 📥 Baixando histórico do sensor 160809 (RJ07)...
# ⚠️ Sem dados para o sensor 160809
#
# 📥 Baixando histórico do sensor 160813 (RJ03)...
# ⚠️ Sem dados para o sensor 160813
#
# 📥 Baixando histórico do sensor 160825 (RJ10)...
# ⚠️ Sem dados para o sensor 160825
#
# 📥 Baixando histórico do sensor 160833 (RJ09)...
# ⚠️ Sem dados para o sensor 160833
#
# 📥 Baixando histórico do sensor 160939 (RJ06)...
# ⚠️ Sem dados para o sensor 160939
#
# 📥 Baixando histórico do sensor 161259 (UEA_EDUCAIR_2)...
# ⚠️ Sem dados para o sensor 161259
#
# 📥 Baixando histórico do sensor 161269 (UEA_EducAIR_3)...
# ⚠️ Sem dados para o sensor 161269
#
# 📥 Baixando histórico do sensor 161279 (UEA_EducAIR_5)...
# ⚠️ Sem dados para o sensor 161279
#
# 📥 Baixando histórico do sensor 161281 (UEA_EducAIR_7)...
# ⚠️ Sem dados para o sensor 161281
#
# 📥 Baixando histórico do sensor 161291 (UEA_EducAIR_6)...
# ⚠️ Sem dados para o sensor 161291
#
# 📥 Baixando histórico do sensor 165029 (UEA_EducAIR_10)...
# ⚠️ Sem dados para o sensor 165029
#
# 📥 Baixando histórico do sensor 165043 (UEA_EducAIR_18)...
# ⚠️ Sem dados para o sensor 165043
#
# 📥 Baixando histórico do sensor 165047 (UEA_EducAIR_14)...
# ⚠️ Sem dados para o sensor 165047
#
# 📥 Baixando histórico do sensor 165053 (UEA_EducAIR_12)...
# ⚠️ Sem dados para o sensor 165053
#
# 📥 Baixando histórico do sensor 165063 (UEA_EducAIR_9)...
# ⚠️ Sem dados para o sensor 165063
#
# 📥 Baixando histórico do sensor 165061 (UEA_EducAIR_8)...
# ⚠️ Sem dados para o sensor 165061
#
# 📥 Baixando histórico do sensor 165067 (UEA_EducAIR_11)...
# ⚠️ Sem dados para o sensor 165067
#
# 📥 Baixando histórico do sensor 165065 (UEA_EducAIR_13)...
# ⚠️ Sem dados para o sensor 165065
#
# 📥 Baixando histórico do sensor 165069 (UEA_EducAIR_22)...
# ⚠️ Sem dados para o sensor 165069
#
# 📥 Baixando histórico do sensor 165131 (UEA_EducAIR_17)...
# ⚠️ Sem dados para o sensor 165131
#
# 📥 Baixando histórico do sensor 165141 (UEA_EducAIR_20)...
# ⚠️ Sem dados para o sensor 165141
#
# 📥 Baixando histórico do sensor 165563 (Bairro_Alto)...
# ⚠️ Sem dados para o sensor 165563
#
# 📥 Baixando histórico do sensor 169787 (Universidad_Privada_Boliviana_,_Postgrado)...
# ⚠️ Sem dados para o sensor 169787
#
# 📥 Baixando histórico do sensor 175101 (Casa_Eliete)...
# ⚠️ Sem dados para o sensor 175101
#
# 📥 Baixando histórico do sensor 175235 (Secretaria_Educação)...
# ⚠️ Sem dados para o sensor 175235
#
# 📥 Baixando histórico do sensor 175407 (Colombo_-_Embrapa)...
# ⚠️ Sem dados para o sensor 175407
#
# 📥 Baixando histórico do sensor 175451 (Pombas)...
# ⚠️ Sem dados para o sensor 175451
#
# 📥 Baixando histórico do sensor 175895 (FSP-USP)...
# ⚠️ Sem dados para o sensor 175895
#
# 📥 Baixando histórico do sensor 175917 (Portaria_P1)...
# ⚠️ Sem dados para o sensor 175917
#
# 📥 Baixando histórico do sensor 176189 (RB-BACKUP)...
# ⚠️ Sem dados para o sensor 176189
#
# 📥 Baixando histórico do sensor 176351 (Facultad_de_Tecnologia_-_GAMS_-_Red_MoniCA_Su)...
# ⚠️ Sem dados para o sensor 176351
#
# 📥 Baixando histórico do sensor 176361 (Consejo_Municipal_-_GAMS_-_Red_MoniCA_Su)...
# ⚠️ Sem dados para o sensor 176361
#
# 📥 Baixando histórico do sensor 176405 (CienTec-inside)...
# ⚠️ Sem dados para o sensor 176405
#
# 📥 Baixando histórico do sensor 177605 (UEA_EducAIR_26)...
# ⚠️ Sem dados para o sensor 177605
#
# 📥 Baixando histórico do sensor 177609 (UEA_EducAIR_24)...
# ⚠️ Sem dados para o sensor 177609
#
# 📥 Baixando histórico do sensor 177649 (UEA_EducAIR_25)...
# ⚠️ Sem dados para o sensor 177649
#
# 📥 Baixando histórico do sensor 177655 (UEA_EducAIR_27)...
# ⚠️ Sem dados para o sensor 177655
#
# 📥 Baixando histórico do sensor 180025 (GEOHealth_APURIMAC_Cotabambas)...
# ⚠️ Sem dados para o sensor 180025
#
# 📥 Baixando histórico do sensor 180033 (GEOHealth_APURIMAC_DIRESA_Abancay)...
# ⚠️ Sem dados para o sensor 180033
#
# 📥 Baixando histórico do sensor 180047 (GEOHealth_APURIMAC_DISA_Chincheros)...
# ⚠️ Sem dados para o sensor 180047
#
# 📥 Baixando histórico do sensor 180069 (GEOHealth_CUS_Cusco)...
# ⚠️ Sem dados para o sensor 180069
#
# 📥 Baixando histórico do sensor 180109 (GEOHealth_AREQ_UNSA_2_1)...
# ⚠️ Sem dados para o sensor 180109
#
# 📥 Baixando histórico do sensor 180161 (GEOHealth_CUS_CuscoUNSAAC)...
# ⚠️ Sem dados para o sensor 180161
#
# 📥 Baixando histórico do sensor 180283 (GEOHealth_LOR_Maynas_2)...
# ⚠️ Sem dados para o sensor 180283
#
# 📥 Baixando histórico do sensor 180295 (GEOHealth_LOR_Maynas_1)...
# ⚠️ Sem dados para o sensor 180295
#
# 📥 Baixando histórico do sensor 180313 (GEOhealth_CUS_Huayocari)...
# ⚠️ Sem dados para o sensor 180313
#
# 📥 Baixando histórico do sensor 180317 (GEOHealth_MAD_PuertoM_WyssAcademy)...
# ⚠️ Sem dados para o sensor 180317
#
# 📥 Baixando histórico do sensor 180329 (GEOHealth_CUS_SanJer2)...
# ⚠️ Sem dados para o sensor 180329
#
# 📥 Baixando histórico do sensor 180333 (Juliaca_v2)...
# ⚠️ Sem dados para o sensor 180333
#
# 📥 Baixando histórico do sensor 182027 (UEA_EducAIR_29)...
# ⚠️ Sem dados para o sensor 182027
#
# 📥 Baixando histórico do sensor 182025 (UEA_EducAIR_30)...
# ⚠️ Sem dados para o sensor 182025
#
# 📥 Baixando histórico do sensor 187775 (Londrina_-_UTFPR)...
# ⚠️ Sem dados para o sensor 187775
#
# 📥 Baixando histórico do sensor 187787 (Medianeira_-_UTFPR)...
# ⚠️ Sem dados para o sensor 187787
#
# 📥 Baixando histórico do sensor 187785 (Guarapuava_-_Sao_Cristovao)...
# ⚠️ Sem dados para o sensor 187785
#
# 📥 Baixando histórico do sensor 187799 (Ponta_Grossa_-_Residencial)...
# ⚠️ Sem dados para o sensor 187799
#
# 📥 Baixando histórico do sensor 187801 (Sao_Mateus_do_Sul_-_Vila_Faty)...
# ⚠️ Sem dados para o sensor 187801
#
# 📥 Baixando histórico do sensor 187807 (Francisco_Beltrao_-_Estacao__IDR)...
# ⚠️ Sem dados para o sensor 187807
#
# 📥 Baixando histórico do sensor 187805 (Foz_do_Iguacu_-_Centro)...
# ⚠️ Sem dados para o sensor 187805
#
# 📥 Baixando histórico do sensor 189639 (Cucunubá_-_Urbano)...
# ⚠️ Sem dados para o sensor 189639
#
# 📥 Baixando histórico do sensor 190133 (Tausa_Urbano_(Cuchavira))...
# ⚠️ Sem dados para o sensor 190133
#
# 📥 Baixando histórico do sensor 191873 (LEHCA-02_Alto_Ipiranga)...
# ⚠️ Sem dados para o sensor 191873
#
# 📥 Baixando histórico do sensor 191939 (JD_Brasil_-_LEHCA004)...
# ⚠️ Sem dados para o sensor 191939
#
# 📥 Baixando histórico do sensor 191987 (LEHCA-005-Bela_Vista)...
# ⚠️ Sem dados para o sensor 191987
#
# 📥 Baixando histórico do sensor 195225 (CS_Caracoto)...
# ⚠️ Sem dados para o sensor 195225
#
# 📥 Baixando histórico do sensor 195295 (CS_Pomata_V2)...
# ⚠️ Sem dados para o sensor 195295
#
# 📥 Baixando histórico do sensor 195301 (Azangaro_v2)...
# ⚠️ Sem dados para o sensor 195301
#
# 📥 Baixando histórico do sensor 197673 (LIA-UAGRM-S1)...
# ⚠️ Sem dados para o sensor 197673
#
# 📥 Baixando histórico do sensor 197691 (LIA_UAGRM(MUSEO)_S2)...
# ⚠️ Sem dados para o sensor 197691
#
# 📥 Baixando histórico do sensor 197705 (LIA_UAGM(LAB_ELEC)_S3)...
# ⚠️ Sem dados para o sensor 197705
#
# 📥 Baixando histórico do sensor 202645 (SEMAS_002_JulioCesar_Almirante)...
# ⚠️ Sem dados para o sensor 202645
#
# 📥 Baixando histórico do sensor 202687 (SEMAS_004__Almirante_JoseMalcher)...
# ⚠️ Sem dados para o sensor 202687
#
# 📥 Baixando histórico do sensor 202703 (SEMAS_005_AntonioBaena)...
# ⚠️ Sem dados para o sensor 202703
#
# 📥 Baixando histórico do sensor 202705 (SEMAS_003_PresVargas_SerzedeloCorreia)...
# ⚠️ Sem dados para o sensor 202705
#
# 📥 Baixando histórico do sensor 204149 (SEMA_DCAM_41)...
# ⚠️ Sem dados para o sensor 204149
#
# 📥 Baixando histórico do sensor 204169 (SEMA_DCAM_07)...
# ⚠️ Sem dados para o sensor 204169
#
# 📥 Baixando histórico do sensor 204173 (SEMA_DCAM_24)...
# ⚠️ Sem dados para o sensor 204173
#
# 📥 Baixando histórico do sensor 204185 (SEMA_DCAM_45)...
# ⚠️ Sem dados para o sensor 204185
#
# 📥 Baixando histórico do sensor 204195 (SEMA_DCAM_30)...
# ⚠️ Sem dados para o sensor 204195
#
# 📥 Baixando histórico do sensor 204202 (SEMA_DCAM_39)...
# ⚠️ Sem dados para o sensor 204202
#
# 📥 Baixando histórico do sensor 204207 (SEMA_DCAM_40)...
# ⚠️ Sem dados para o sensor 204207
#
# 📥 Baixando histórico do sensor 204205 (SEMA_DCAM_29)...
# ⚠️ Sem dados para o sensor 204205
#
# 📥 Baixando histórico do sensor 204211 (SEMA_DCAM_17)...
# ⚠️ Sem dados para o sensor 204211
#
# 📥 Baixando histórico do sensor 204213 (SEMA_DCAM_19)...
# ⚠️ Sem dados para o sensor 204213
#
# 📥 Baixando histórico do sensor 204219 (SEMA_DCAM_20)...
# ⚠️ Sem dados para o sensor 204219
#
# 📥 Baixando histórico do sensor 204217 (SEMA_DCAM_31)...
# ⚠️ Sem dados para o sensor 204217
#
# 📥 Baixando histórico do sensor 204993 (LIA_UAGRM(FICH)_S4)...
# ⚠️ Sem dados para o sensor 204993
#
# 📥 Baixando histórico do sensor 205661 (SEMA_DCAM_22)...
# ⚠️ Sem dados para o sensor 205661
#
# 📥 Baixando histórico do sensor 205673 (SEMA_DCAM_57)...
# ⚠️ Sem dados para o sensor 205673
#
# 📥 Baixando histórico do sensor 205679 (SEMA_DCAM_14)...
# ⚠️ Sem dados para o sensor 205679
#
# 📥 Baixando histórico do sensor 205677 (SEMA_DCAM_55)...
# ⚠️ Sem dados para o sensor 205677
#
# 📥 Baixando histórico do sensor 205683 (SEMA_DCAM_52)...
# ⚠️ Sem dados para o sensor 205683
#
# 📥 Baixando histórico do sensor 205689 (SEMA_DCAM_13)...
# ⚠️ Sem dados para o sensor 205689
#
# 📥 Baixando histórico do sensor 205699 (SEMA_DCAM_56)...
# ⚠️ Sem dados para o sensor 205699
#
# 📥 Baixando histórico do sensor 205711 (SEMA_DCAM_61)...
# ⚠️ Sem dados para o sensor 205711
#
# 📥 Baixando histórico do sensor 205709 (SEMA_DCAM_25)...
# ⚠️ Sem dados para o sensor 205709
#
# 📥 Baixando histórico do sensor 205713 (SEMA_DCAM_12)...
# ⚠️ Sem dados para o sensor 205713
#
# 📥 Baixando histórico do sensor 205915 (SEMA_03)...
# ⚠️ Sem dados para o sensor 205915
#
# 📥 Baixando histórico do sensor 205913 (SEMA_DCAM_49)...
# ⚠️ Sem dados para o sensor 205913
#
# 📥 Baixando histórico do sensor 205933 (SEMAS_033_CAM9)...
# ⚠️ Sem dados para o sensor 205933
#
# 📥 Baixando histórico do sensor 205939 (SEMAS_031_CAMERA_ESTACIONAMENTO_ATALAIA)...
# ⚠️ Sem dados para o sensor 205939
#
# 📥 Baixando histórico do sensor 205955 (SEMAS_030_CAMERA_DO_TRALHOTO)...
# ⚠️ Sem dados para o sensor 205955
#
# 📥 Baixando histórico do sensor 205965 (SEMAS_023_CAMERA_CAPANEMA_1)...
# ⚠️ Sem dados para o sensor 205965
#
# 📥 Baixando histórico do sensor 205969 (SEMAS_035_CAM6)...
# ⚠️ Sem dados para o sensor 205969
#
# 📥 Baixando histórico do sensor 205973 (SEMAS_034_CAM5)...
# ⚠️ Sem dados para o sensor 205973
#
# 📥 Baixando histórico do sensor 206199 (SEMAS_016_RAMPA_DO_SKATE_MOSQUEIRO)...
# ⚠️ Sem dados para o sensor 206199
#
# 📥 Baixando histórico do sensor 206203 (SEMAS_026_CAM5_BRAGANÇA)...
# ⚠️ Sem dados para o sensor 206203
#
# 📥 Baixando histórico do sensor 206207 (SEMAS_025_CAM_8_BRAGANÇA)...
# ⚠️ Sem dados para o sensor 206207
#
# 📥 Baixando histórico do sensor 206209 (SEMAS_006_PRESIDENTE_VARGAS_MANOEL_BARATA)...
# ⚠️ Sem dados para o sensor 206209
#
# 📥 Baixando histórico do sensor 206215 (SEMAS_005_TERMINAL_HIDRO_PORTO_FUTUDO)...
# ⚠️ Sem dados para o sensor 206215
#
# 📥 Baixando histórico do sensor 206213 (SAMAS_013_CENTENÁRIO)...
# ⚠️ Sem dados para o sensor 206213
#
# 📥 Baixando histórico do sensor 206219 (SEMAS_011_JULIO_CESAR_P_ALVARES_CABRAL)...
# ⚠️ Sem dados para o sensor 206219
#
# 📥 Baixando histórico do sensor 206217 (SEMAS_021_AV_PA136_ALAMEDA_CAPANEMA)...
# ⚠️ Sem dados para o sensor 206217
#
# 📥 Baixando histórico do sensor 206231 (SEMAS_022_CAM08_BR316_AV_LAURO_SODRÉ)...
# ⚠️ Sem dados para o sensor 206231
#
# 📥 Baixando histórico do sensor 206237 (SEMAS_008_ROBERTO_CAMELIER_TIMBIRAS)...
# ⚠️ Sem dados para o sensor 206237
#
# 📥 Baixando histórico do sensor 206253 (SEMAS_0009_PASS_MIRANDINHA_PEDRO_A_CABRAL)...
# ⚠️ Sem dados para o sensor 206253
#
# 📥 Baixando histórico do sensor 206261 (SEMAS_017_FINAL_DA_LINHA_DO_ICUI)...
# ⚠️ Sem dados para o sensor 206261
#
# 📥 Baixando histórico do sensor 206265 (SEMAS_028_CAM16)...
# ⚠️ Sem dados para o sensor 206265
#
# 📥 Baixando histórico do sensor 206335 (SEMAS_029_CAMERA_EXTRAFARMA)...
# ⚠️ Sem dados para o sensor 206335
#
# 📥 Baixando histórico do sensor 206341 (SEMMA)...
# ⚠️ Sem dados para o sensor 206341
#
# 📥 Baixando histórico do sensor 206669 (SEMA_DCAM_06)...
# ⚠️ Sem dados para o sensor 206669
#
# 📥 Baixando histórico do sensor 206673 (SEMA_DCAM_48)...
# ⚠️ Sem dados para o sensor 206673
#
# 📥 Baixando histórico do sensor 206679 (SEMA_DCAM_03)...
# ⚠️ Sem dados para o sensor 206679
#
# 📥 Baixando histórico do sensor 206681 (SEMA_DCAM_08)...
# ⚠️ Sem dados para o sensor 206681
#
# 📥 Baixando histórico do sensor 206685 (SEMA_DCAM_42)...
# ⚠️ Sem dados para o sensor 206685
#
# 📥 Baixando histórico do sensor 206691 (SEMA_DCAM_09)...
# ⚠️ Sem dados para o sensor 206691
#
# 📥 Baixando histórico do sensor 206695 (SEMA_DCAM_27)...
# ⚠️ Sem dados para o sensor 206695
#
# 📥 Baixando histórico do sensor 206693 (SEMA_DCAM_05)...
# ⚠️ Sem dados para o sensor 206693
#
# 📥 Baixando histórico do sensor 206697 (SEMA_DCAM_04)...
# ⚠️ Sem dados para o sensor 206697
#
# 📥 Baixando histórico do sensor 206701 (SEMA_DCAM_02)...
# ⚠️ Sem dados para o sensor 206701
#
# 📥 Baixando histórico do sensor 206707 (SEMA_DCAM_54)...
# ⚠️ Sem dados para o sensor 206707
#
# 📥 Baixando histórico do sensor 206711 (SEMA_DC_14)...
# ⚠️ Sem dados para o sensor 206711
#
# 📥 Baixando histórico do sensor 206713 (SEMA_DCAM_50)...
# ⚠️ Sem dados para o sensor 206713
#
# 📥 Baixando histórico do sensor 206717 (SEMA_DCAM_10)...
# ⚠️ Sem dados para o sensor 206717
#
# 📥 Baixando histórico do sensor 206725 (SEMA)...
# ⚠️ Sem dados para o sensor 206725
#
# 📥 Baixando histórico do sensor 206735 (SEMA_DCAM_51)...
# ⚠️ Sem dados para o sensor 206735
#
# 📥 Baixando histórico do sensor 206739 (SEMA_DCAM_62)...
# ⚠️ Sem dados para o sensor 206739
#
# 📥 Baixando histórico do sensor 208605 (Punto_1)...
# ⚠️ Sem dados para o sensor 208605
#
# 📥 Baixando histórico do sensor 208633 (Punto_2)...
# ⚠️ Sem dados para o sensor 208633
#
# 📥 Baixando histórico do sensor 209693 ((IPAM)_Base_Porto_Murtinho_(ICMBIO))...
# ⚠️ Sem dados para o sensor 209693
#
# 📥 Baixando histórico do sensor 209697 ((IPAM)_SEMMAS_São_Felix_do_Xingu)...
# ⚠️ Sem dados para o sensor 209697
#
# 📥 Baixando histórico do sensor 209719 ((IPAM)_São_Luís)...
# ⚠️ Sem dados para o sensor 209719
#
# 📥 Baixando histórico do sensor 209723 (UFRA-CP2)...
# ⚠️ Sem dados para o sensor 209723
#
# 📥 Baixando histórico do sensor 209735 ((IPAM)_TI_MÃE_MARIA_(ALDEIAKYIKATÊJÊ))...
# ⚠️ Sem dados para o sensor 209735
#
# 📥 Baixando histórico do sensor 209733 (IPAM_51_Aldeia_Vista_Alegre)...
# ⚠️ Sem dados para o sensor 209733
#
# 📥 Baixando histórico do sensor 209737 ((IPAM)_PREVFOGO_-_Corumbá)...
# ⚠️ Sem dados para o sensor 209737
#
# 📥 Baixando histórico do sensor 209750 ((IPAM)_Medicilândia)...
# ⚠️ Sem dados para o sensor 209750
#
# 📥 Baixando histórico do sensor 209755 ((IPAM)_TI_Serra_da_Moça)...
# ⚠️ Sem dados para o sensor 209755
#
# 📥 Baixando histórico do sensor 209769 ((IPAM)_TI_Xerente)...
# ⚠️ Sem dados para o sensor 209769
#
# 📥 Baixando histórico do sensor 209773 ((IPAM)_Brigada_Alter_do_Chão)...
# ⚠️ Sem dados para o sensor 209773
#
# 📥 Baixando histórico do sensor 209779 ((IPAM)_Instituto_Ambiental_Rio_Perdido_-_Juína)...
# ⚠️ Sem dados para o sensor 209779
#
# 📥 Baixando histórico do sensor 212951 (Sutatausa_-_Urbano_(Cuchavira))...
# ⚠️ Sem dados para o sensor 212951
#
# 📥 Baixando histórico do sensor 213375 (Cucunubá_-_Pueblo_Viejo_(Panamá))...
# ⚠️ Sem dados para o sensor 213375
#
# 📥 Baixando histórico do sensor 219595 (IFRO_calama_(karolinska))...
# ⚠️ Sem dados para o sensor 219595
#
# 📥 Baixando histórico do sensor 219803 (AJJA_01)...
# ⚠️ Sem dados para o sensor 219803
#
# 📥 Baixando histórico do sensor 223683 (UFPA-ICB)...
# ⚠️ Sem dados para o sensor 223683
#
# 📥 Baixando histórico do sensor 223871 (HLP)...
# ⚠️ Sem dados para o sensor 223871
#
# 📥 Baixando histórico do sensor 232893 (ASA_N_Quadra_311)...
# ⚠️ Sem dados para o sensor 232893
#
# 📥 Baixando histórico do sensor 233203 (CS_Putina_V2)...
# ⚠️ Sem dados para o sensor 233203
#
# 📥 Baixando histórico do sensor 233269 (Ilave_V2)...
# ⚠️ Sem dados para o sensor 233269
#
# 📥 Baixando histórico do sensor 237811 (La_Paz,_Calacoto)...
# ⚠️ Sem dados para o sensor 237811
#
# 📥 Baixando histórico do sensor 237813 (La_Paz,_Sopocachi_building)...
# ⚠️ Sem dados para o sensor 237813
#
# 📥 Baixando histórico do sensor 241605 (SEMA-UFMT-VG)...
# ⚠️ Sem dados para o sensor 241605
#
# 📥 Baixando histórico do sensor 241609 (SEMA-Barao_de_Melgaço)...
# ⚠️ Sem dados para o sensor 241609
#
# 📥 Baixando histórico do sensor 241655 (SEMA-IPAM-SÃO_FELIX_DO_ARAGUAIA)...
# ⚠️ Sem dados para o sensor 241655
#
# 📥 Baixando histórico do sensor 241667 (SEMA-UNEMAT-BARRABUGRES)...
# ⚠️ Sem dados para o sensor 241667
#
# 📥 Baixando histórico do sensor 241691 (SEMA-UFMT-PGFA)...
# ⚠️ Sem dados para o sensor 241691
#
# 📥 Baixando histórico do sensor 241693 (SEMA-IFMT-PRIMAVERA_DO_LESTE)...
# ⚠️ Sem dados para o sensor 241693
#
# 📥 Baixando histórico do sensor 242077 (SEMA-IFMT-CAMPO_NOVO_DO_PARECIS)...
# ⚠️ Sem dados para o sensor 242077
#
# 📥 Baixando histórico do sensor 242083 (SEMA-MT_SEDE)...
# ⚠️ Sem dados para o sensor 242083
#
# 📥 Baixando histórico do sensor 242087 (SEMA-SABA-Poconé)...
# ⚠️ Sem dados para o sensor 242087
#
# 📥 Baixando histórico do sensor 242091 (SEMA-IFMT-PONTES_E_LACERDA)...
# ⚠️ Sem dados para o sensor 242091
#
# 📥 Baixando histórico do sensor 243063 (UnB_Odisseia_Paranoá_(CEM_01))...
# ⚠️ Sem dados para o sensor 243063
#
# 📥 Baixando histórico do sensor 243067 (UnB_Odisseia_Cafuringa)...
# ⚠️ Sem dados para o sensor 243067
#
# 📥 Baixando histórico do sensor 243621 (UnB_Odisseia_Gama)...
# ⚠️ Sem dados para o sensor 243621
#
# 📥 Baixando histórico do sensor 246273 (GEOHealth_APURIMAC_Andahuaylas)...
# ⚠️ Sem dados para o sensor 246273
#
# 📥 Baixando histórico do sensor 246425 (GEOHealth_CUS_CcapacmarcaOefa1)...
# ⚠️ Sem dados para o sensor 246425
#
# 📥 Baixando histórico do sensor 246449 (GEOHealth_CUS_CcapacmarcaOefa2)...
# ⚠️ Sem dados para o sensor 246449
#
# 📥 Baixando histórico do sensor 246453 (GEOHealth_AREQ_Yura)...
# ⚠️ Sem dados para o sensor 246453
#
# 📥 Baixando histórico do sensor 246457 (GEOHealth_CUS_CcapacmarcaOefa3)...
# ⚠️ Sem dados para o sensor 246457
#
# 📥 Baixando histórico do sensor 251937 (Universidad_Privada_Boliviana,_Campus_Achocalla)...
# ⚠️ Sem dados para o sensor 251937
