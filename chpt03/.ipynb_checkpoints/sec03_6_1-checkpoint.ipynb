# %% [markdown]
# ### 3.6.1. Representatividade espacial das estações - BRUNO E MARCOS

# %% [markdown]
#             Tabela 11 – Cobertura das redes de monitoramento da qualidade do ar no Brasil considerando a área total do país e a
#                 área urbana. Análise realizada utilizando dados do IBGE (IBGE, 2019; IBGE, 2022
#
#             Tabela 12 – Cobertura das redes de monitoramento da qualidade do ar nas UFs brasileiras considerando a área total e
#                 urbana de cada UF. Análise realizada utilizando dados do IBGE (2019; 2022a)
#
#             Figura 7 – Percentual de cobertura das redes de monitoramento da qualidade do ar (ativas) nas UFs brasileiras
#
#                 considerando a área urbana. Análise realizada utilizando dados do IBGE (IBGE, 2019; IBGE, 2022a)

# %% [markdown]
# **VEICULARES**
#
# * Baixar dados do geofabrik
#
# https://download.geofabrik.de/south-america/brazil.html
#
# * Usar planilha RQAR_2025_book/data/Monitoramento_Qar_BR_teste.csv
# * Determinar menor distância entre ponto de monitoramento e via com Quadro 2 – Posicionamento de monitores de material particulado em relação às vias de tráfego.
#   https://www.gov.br/mma/pt-br/assuntos/meio-ambiente-urbano-recursos-hidricos-qualidade-ambiental/qualidade-do-ar/guia-tecnico-para-o-monitoramento-e-avaliacao-da-qualidade-do-ar.pdf
#
# **INDÚSTRIAS**
# * Determinar distância entre ponto de monitoramento e indústrias utilizando dado que o Fábio possui
#
# **CLASSIFICAÇÃO**
#
#   https://www.gov.br/mma/pt-br/assuntos/meio-ambiente-urbano-recursos-hidricos-qualidade-ambiental/qualidade-do-ar/guia-tecnico-para-o-monitoramento-e-avaliacao-da-qualidade-do-ar.pdf

# %% [markdown]
# **Determinar altura do ponto de medição utilizando dados do SRTM**   marcos
# utilizar dados baixados do SRTM no servidor Artaxo

# %%
csv['UF'].unique()
# Out:
# array(['AC', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG', 'MS',
#        'MT', 'PA', 'PE', 'PR', 'RJ', 'RS', 'SC', 'SP'], dtype=object)

# %%
import os
import math
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# ---- Seleção da estação ----
subset_mask = (csv['ID_OEMA'] == 'Centro') & (csv['UF'] == 'SP')
subset = csv.loc[subset_mask]

if subset.empty:
    raise ValueError("Nenhuma estação encontrada para os filtros dados.")

lat = subset['LATITUDE'].iloc[0]
lon = subset['LONGITUDE'].iloc[0]

lat_prefixo = 's' if lat < 0 else 'n'
lon_prefixo = 'w' if lon < 0 else 'e'

if lat < 0:
    lat_num = math.ceil(abs(lat))
else:
    lat_num = math.floor(abs(lat))

if lon < 0:
    lon_num = math.ceil(abs(lon))
else:
    lon_num = math.floor(abs(lon))

lat_str = f"{lat_num:02d}"
lon_str = f"{lon_num:03d}"

filename = f"{lat_prefixo}{lat_str}_{lon_prefixo}{lon_str}_1arc_v3.tif"
print("Arquivo SRTM:", filename)

# ---- Abrir o raster ----
filepath = os.path.join(DirSRTM, filename)
with rasterio.open(filepath) as dem_data:
    dem_array = dem_data.read(1)
    extent = [
        dem_data.bounds.left, dem_data.bounds.right,
        dem_data.bounds.bottom, dem_data.bounds.top
    ]
    nodata = dem_data.nodata  # valor de NoData do raster

# ---- Criar máscara de dados válidos ----
if nodata is not None:
    dem_array = np.where(dem_array == nodata, np.nan, dem_array)

# ---- Plotar ----
fig, ax = plt.subplots(figsize=(8, 6))
img = ax.imshow(
    dem_array, extent=extent, cmap="terrain",
    origin="upper"
)
plt.colorbar(img, ax=ax, label="Elevação (m)")

# Localização da estação
ax.scatter(lon, lat, color="red", s=60, marker="x", label="Estação")

ax.set_title(f"SRTM - {filename}")
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.legend()

plt.show()
# Out:
# Arquivo SRTM: s24_w047_1arc_v3.tif

# %%
csv.head()
# Out:
#    UF        CIDADE   CD_MUN                 ID_OEMA  ID_MMA ID_MMA_COMPLETO  \
# 0  AC    Rio Branco  1200401       AcreBioClima UFAC  AC0007             NaN
# 1  AC        Bujari  1200138  MPAC_BJR_01_promotoria  AC0009             NaN
# 2  AC  Assis Brasil  1200054  MPAC_ABR_01_promotoria     NaN             NaN
# 3  AC  Assis Brasil  1200054       MPAC_ABR_02_SEMSA     NaN             NaN
# 4  AC    Acrelândia  1200013  MPAC_ACL_01_promotoria     NaN             NaN
#
#    PROPRIETARIO PROP_ENTIDADE  OPERADOR OP_ENTIDADE  ... INICIO  FIM  \
# 0           NaN           NaN       NaN         NaN  ...    NaN  NaN
# 1           NaN           NaN       NaN         NaN  ...    NaN  NaN
# 2           NaN           NaN       NaN         NaN  ...    NaN  NaN
# 3           NaN           NaN       NaN         NaN  ...    NaN  NaN
# 4           NaN           NaN       NaN         NaN  ...    NaN  NaN
#
#    LATITUDE  LONGITUDE  MONITORAR          FONTE     CERTIFICACAO  \
# 0   -9.9573   -67.8687        NaN  Consulta 2024  Não Certificada
# 1   -9.8292   -67.9539        NaN  Consulta 2024  Não Certificada
# 2  -10.9400   -69.5672        NaN  Consulta 2024  Não Certificada
# 3  -10.9406   -69.5678        NaN  Consulta 2024  Não Certificada
# 4  -10.0741   -67.0511        NaN  Consulta 2024  Não Certificada
#
#    COD_UF_IBGE  ELEVACAO  BASE_DADOS
# 0           12       158       False
# 1           12       212       False
# 2           12       244       False
# 3           12       243       False
# 4           12       210       False
#
# [5 rows x 32 columns]

# %%
s
# Out:
#       UF       CIDADE   CD_MUN ID_OEMA  ID_MMA ID_MMA_COMPLETO  PROPRIETARIO  \
# 559   MG  Barra Longa  3105707  Centro  MG0018     MG0018RA007           NaN
# 560   MG  Barra Longa  3105707  Centro  MG0018     MG0018RA001           NaN
# 561   MG  Barra Longa  3105707  Centro  MG0018     MG0018RA002           NaN
# 562   MG  Barra Longa  3105707  Centro  MG0018     MG0018RA005           NaN
# 563   MG  Barra Longa  3105707  Centro  MG0018     MG0018RA008           NaN
# 2208  SP    São Paulo  3550308  Centro  SP0094     SP0094RA018           NaN
# 2209  SP    São Paulo  3550308  Centro  SP0094     SP0094RA004           NaN
# 2210  SP    São Paulo  3550308  Centro  SP0094     SP0094RA001           NaN
# 2211  SP    São Paulo  3550308  Centro  SP0094     SP0094RA007           NaN
# 2212  SP    São Paulo  3550308  Centro  SP0094     SP0094RA017           NaN
#
#      PROP_ENTIDADE  OPERADOR OP_ENTIDADE  ...               INICIO  \
# 559        Privado       NaN     Privado  ...                  NaN
# 560        Privado       NaN     Privado  ...                  NaN
# 561        Privado       NaN     Privado  ...                  NaN
# 562        Privado       NaN     Privado  ...                  NaN
# 563        Privado       NaN     Privado  ...                  NaN
# 2208           NaN       NaN         NaN  ...  2005-08-23 02:00:00
# 2209           NaN       NaN         NaN  ...  2005-08-23 02:00:00
# 2210           NaN       NaN         NaN  ...  2006-09-25 14:00:00
# 2211           NaN       NaN         NaN  ...  2005-08-23 01:00:00
# 2212           NaN       NaN         NaN  ...               2005.0
#
#                       FIM   LATITUDE  LONGITUDE  MONITORAR            FONTE  \
# 559                   NaN -20.282569 -43.040342        NaN  Coleta Interna
# 560                   NaN -20.282569 -43.040342        NaN  Coleta Interna
# 561                   NaN -20.282569 -43.040342        NaN  Coleta Interna
# 562                   NaN -20.282569 -43.040342        NaN  Coleta Interna
# 563                   NaN -20.282569 -43.040342        NaN  Coleta Interna
# 2208  2006-09-13 13:00:00 -23.547806 -46.642415        NaN              NaN
# 2209  2006-09-13 13:00:00 -23.547806 -46.642415        NaN              NaN
# 2210  2010-02-09 00:00:00 -23.547806 -46.642415        NaN              NaN
# 2211  2010-02-09 00:00:00 -23.547806 -46.642415        NaN              NaN
# 2212               2006.0 -23.547806 -46.642415        NaN              NaN
#
#      CERTIFICACAO  COD_UF_IBGE  ELEVACAO  BASE_DADOS
# 559   Certificada           31      None       False
# 560   Certificada           31      None       False
# 561   Certificada           31      None       False
# 562   Certificada           31      None       False
# 563   Certificada           31      None       False
# 2208          NaN           35      None        True
# 2209          NaN           35      None        True
# 2210          NaN           35      None        True
# 2211          NaN           35      None        True
# 2212          NaN           35      None       False
#
# [10 rows x 32 columns]

# %%
cvEleva, estacoes_negativas = getElevSRTM(DirSRTM, s)
# Out:
# === Rodando UF: MG ===
# Erro na estação Centro da UF MG: index 12772 is out of bounds for axis 0 with size 3601
# === Rodando UF: SP ===
# Erro na estação Centro da UF SP: index 12772 is out of bounds for axis 0 with size 3601
# /tmp/ipykernel_309936/2761086674.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv['ELEVACAO'] = None

# %%
s = csv[csv['ID_OEMA'] == 'Centro']
for uf in s['UF'].unique():
    print(f"=== Rodando UF: {uf} ===")
    csv_uf = s[s['UF'] == uf]
    print(csv_uf)
# Out:
# === Rodando UF: MG ===
#      UF       CIDADE   CD_MUN ID_OEMA  ID_MMA ID_MMA_COMPLETO  PROPRIETARIO  \
# 559  MG  Barra Longa  3105707  Centro  MG0018     MG0018RA007           NaN
# 560  MG  Barra Longa  3105707  Centro  MG0018     MG0018RA001           NaN
# 561  MG  Barra Longa  3105707  Centro  MG0018     MG0018RA002           NaN
# 562  MG  Barra Longa  3105707  Centro  MG0018     MG0018RA005           NaN
# 563  MG  Barra Longa  3105707  Centro  MG0018     MG0018RA008           NaN
#
#     PROP_ENTIDADE  OPERADOR OP_ENTIDADE  ... INICIO  FIM   LATITUDE  \
# 559       Privado       NaN     Privado  ...    NaN  NaN -20.282569
# 560       Privado       NaN     Privado  ...    NaN  NaN -20.282569
# 561       Privado       NaN     Privado  ...    NaN  NaN -20.282569
# 562       Privado       NaN     Privado  ...    NaN  NaN -20.282569
# 563       Privado       NaN     Privado  ...    NaN  NaN -20.282569
#
#      LONGITUDE  MONITORAR            FONTE CERTIFICACAO  COD_UF_IBGE  \
# 559 -43.040342        NaN  Coleta Interna   Certificada           31
# 560 -43.040342        NaN  Coleta Interna   Certificada           31
# 561 -43.040342        NaN  Coleta Interna   Certificada           31
# 562 -43.040342        NaN  Coleta Interna   Certificada           31
# 563 -43.040342        NaN  Coleta Interna   Certificada           31
#
#      ELEVACAO  BASE_DADOS
# 559      None       False
# 560      None       False
# 561      None       False
# 562      None       False
# 563      None       False
#
# [5 rows x 32 columns]
# === Rodando UF: SP ===
#       UF     CIDADE   CD_MUN ID_OEMA  ID_MMA ID_MMA_COMPLETO  PROPRIETARIO  \
# 2208  SP  São Paulo  3550308  Centro  SP0094     SP0094RA018           NaN
# 2209  SP  São Paulo  3550308  Centro  SP0094     SP0094RA004           NaN
# 2210  SP  São Paulo  3550308  Centro  SP0094     SP0094RA001           NaN
# 2211  SP  São Paulo  3550308  Centro  SP0094     SP0094RA007           NaN
# 2212  SP  São Paulo  3550308  Centro  SP0094     SP0094RA017           NaN
#
#      PROP_ENTIDADE  OPERADOR OP_ENTIDADE  ...               INICIO  \
# 2208           NaN       NaN         NaN  ...  2005-08-23 02:00:00
# 2209           NaN       NaN         NaN  ...  2005-08-23 02:00:00
# 2210           NaN       NaN         NaN  ...  2006-09-25 14:00:00
# 2211           NaN       NaN         NaN  ...  2005-08-23 01:00:00
# 2212           NaN       NaN         NaN  ...               2005.0
#
#                       FIM   LATITUDE  LONGITUDE  MONITORAR  FONTE  \
# 2208  2006-09-13 13:00:00 -23.547806 -46.642415        NaN    NaN
# 2209  2006-09-13 13:00:00 -23.547806 -46.642415        NaN    NaN
# 2210  2010-02-09 00:00:00 -23.547806 -46.642415        NaN    NaN
# 2211  2010-02-09 00:00:00 -23.547806 -46.642415        NaN    NaN
# 2212               2006.0 -23.547806 -46.642415        NaN    NaN
#
#      CERTIFICACAO  COD_UF_IBGE  ELEVACAO  BASE_DADOS
# 2208          NaN           35      None        True
# 2209          NaN           35      None        True
# 2210          NaN           35      None        True
# 2211          NaN           35      None        True
# 2212          NaN           35      None       False
#
# [5 rows x 32 columns]

# %%
import pandas as pd
import os
import rasterio
import matplotlib.pyplot as plt
import pandas as pd
import math
from shapely.geometry import Point, mapping
from rasterio.mask import mask
import numpy as np

def corrige_elevacoes(csv_neg, estacoes_negativas, DirSRTM):

    csv_neg['ELEVACAO'] = None  # cria/zera a coluna de saída
    # Loop em cada estação única
    for estacao in csv_neg['ID_OEMA'].unique():
        subset_mask = csv_neg['ID_OEMA'] == estacao
        subset = csv_neg.loc[subset_mask]

        filename = estacoes_negativas[estacao]
        dem_data = rasterio.open(DirSRTM + filename[0])
        dem_array = dem_data.read(1)


        elevations = []
        for _, row_data in subset.iterrows():
            # obtém índice do pixel
            row, col = dem_data.index(row_data['LONGITUDE'], row_data['LATITUDE'])
            elev = dem_array[row, col]

            # cria buffer de ~1km em torno do ponto
            ponto = Point(row_data['LONGITUDE'], row_data['LATITUDE'])
            buffer = ponto.buffer(0.1)
            out_image, _ = mask(dem_data, [mapping(buffer)], crop=True)

            # média dos valores positivos dentro do buffer
            elev_corrigido = np.nanmean(out_image[0][out_image[0] > 0])
            elevations.append(int(elev_corrigido))

        # Salva de volta no dataframe
        csv_neg.loc[subset_mask, 'ELEVACAO'] = elevations

    return csv_neg


def getElevSRTM(DirSRTM, csv):
    
    csv['ELEVACAO'] = None
    estacoes_negativas = {}

    # Loop por UF
    for uf in csv['UF'].unique():
        csv_uf = csv[csv['UF'] == uf]

        # Loop por estação dentro da UF
        for estacao in csv_uf['ID_OEMA'].unique():
            mask = (csv['ID_OEMA'] == estacao) & (csv['UF'] == uf)
            subset = csv.loc[mask]

            try:
                # Prefixos de latitude e longitude
                lat_prefixo = 's' if subset['LATITUDE'].iloc[0] < 0 else 'n'
                lon_prefixo = 'w' if subset['LONGITUDE'].iloc[0] < 0 else 'e'

                # Número do arquivo SRTM
                if lat_prefixo == 's':
                    lat_num = math.ceil(abs(subset['LATITUDE'].iloc[0]))
                else:
                    lat_num = math.floor(abs(subset['LATITUDE'].iloc[0]))

                lon_num = math.ceil(abs(subset['LONGITUDE'].iloc[0]))
                filename = f"{lat_prefixo}{str(lat_num).zfill(2)}_{lon_prefixo}{str(lon_num).zfill(3)}_1arc_v3.tif"

                # Carregar arquivo
                path = os.path.join(DirSRTM, filename)
                dem_data = rasterio.open(path)
                dem_array = dem_data.read(1)

                elevations = []

                for _, row_data in subset.iterrows():
                    row, col = dem_data.index(row_data['LONGITUDE'], row_data['LATITUDE'])
                    elev = dem_array[row, col]

                    if elev < 0:
                        estacoes_negativas.setdefault(estacao, []).append(filename)

                    elevations.append(elev)

                # Atualiza a coluna ELEVACAO no CSV original
                csv.loc[mask, 'ELEVACAO'] = elevations

            except Exception as e:
                print(f"Erro na estação {estacao} ({filename}): {e}")
                continue

    # Corrigir as estações com erro (mantendo sua função existente)
    csv_neg = csv[csv['ID_OEMA'].isin(estacoes_negativas.keys())]
    csv_cor = corrige_elevacoes(csv_neg, estacoes_negativas, DirSRTM)
    csv.loc[csv_cor.index, 'ELEVACAO'] = csv_cor['ELEVACAO']

    return csv, estacoes_negativas

# Caminho para a pasta de dados
rootPath = os.path.dirname(os.getcwd())
# Lendo o csv
csv = pd.read_csv(rootPath+'/data/Monitoramento_QAr_BR.csv')

DirSRTM = "/home/nobre/SRTM/"
csvEleva, estacoes_negativas  = getElevSRTM(DirSRTM, csv)
csvEleva.to_csv(rootPath + '/data/Monitoramento_QAr_BR.csv', index=False)
# Out:
# /tmp/ipykernel_309936/2206650261.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   csv_neg['ELEVACAO'] = None  # cria/zera a coluna de saída

# %%
import scripts.flagTables as flagtab
columnsSelector = ["","UF","ID_OEMA", "Poluente","Status",'Categoria','Funcionamento','Elevação']
aqmData = flagtab.flagTable(columnsSelector)
searchPaneColumns=[1,4]
flagtab.tabela_iterativa(aqmData,searchPaneColumns)
# Out:
# <script type="module">
#     const { set_or_remove_dark_class } = await import(window._itables_2_5_1);
#     set_or_remove_dark_class();
# </script>
# <script>
# function injectCSS(base64CSS) {
#     const cssText = atob(base64CSS);
#     const style = document.createElement('style');
#     style.textContent = cssText;
#     document.head.appendChild(style);
# }
#
# async function injectModule(base64JS) {
#     const jsText = atob(base64JS);
#     const blob = new Blob([jsText], { type: 'application/javascript' });
#     const url = URL.createObjectURL(blob);
#     const module = await import(url);
#     URL.revokeObjectURL(url);
#     return module;
# }
#
# if (!window._itables_2_5_1) {
#     injectCSS("...");
#     window._itables_2_5_1 = injectModule("...");
#     window._itables_2_5_1.then(() => {
#         window.dispatchEvent(new Event("itables-2.5.1-ready"));
#     });
# }
# </script>
#
# <div style="vertical-align:middle; text-align:left">
# <noscript>
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# This is the <code>init_notebook_mode</code> cell from ITables v2.5.1<br>
# (you should not see this message - is your notebook <it>trusted</it>?)
# </noscript>
# </div>
# <style>
#     /* Removendo os estilos anteriores do campo de busca */
#     div.dt-search > input {
#       all: unset !important
#     }
#
#     /* Reestilizando campo de busca */
#     div.dt-search > input {
#           /* background-color: #FFFFFF !important; */
#           border: 1px solid rgba(27, 31, 35, 0.15) !important;
#           border-radius: 6px !important;
#           padding: .5em .4em !important;
#           margin-left: 0.6em !important;
#
#     }
#
#     /* Reestilizando itens de navegação entre páginas */
#     nav > .dt-paging-button {
#       background-color: transparent;
#       border: 1px solid rgba(27, 31, 35, 0.15) !important;
#       border-radius: 6px !important;
#
#     }
#     nav > .current {
#       background-color: #F3F4F6 !important;
#       text-decoration: none !important;
#       transition-duration: 0.1s !important;
#     }
#
#     /* Removendo os estilos anteriores dos botões */
#     div.dt-buttons > .dt-button,
#     div.dt-buttons > .dt-button:hover,
#     div.dt-buttons > .dt-button:disabled,
#     div.dt-buttons > .dt-button:active,
#     div.dt-buttons > .dt-button:focus,
#     div.dt-buttons > .dt-button:before,
#     div.dt-buttons > .dt-button:hover:not(.disabled),
#     div.dt-buttons > .dt-button:focus:not(.disabled),
#     div.dt-buttons > .dt-button:active:not(.disabled),
#     div.dt-buttons > .dt-button:-webkit-details-marker {
#       all: unset !important;
#     }
#
#     /* Reestilizando botões */
#     div.dt-buttons > .dt-button {
#       appearance: none !important;
#       background-color: #FAFBFC !important;
#       border: 1px solid rgba(27, 31, 35, 0.15) !important;
#       border-radius: 6px !important;
#       box-shadow: rgba(27, 31, 35, 0.04) 0 1px 0, rgba(255, 255, 255, 0.25) 0 1px 0 inset !important;
#       box-sizing: border-box !important;
#       color: #24292E !important;
#       cursor: pointer !important;
#       display: inline-block !important;
#       font-family: -apple-system, system-ui, "Segoe UI", Helvetica, Arial, sans-serif, "Apple Color Emoji", "Segoe UI Emoji" !important;
#       font-size: 14px !important;
#       font-weight: 500 !important;
#       line-height: 20px !important;
#       list-style: none !important;
#       padding: 6px 16px !important;
#       position: relative !important;
#       transition: background-color 0.2s cubic-bezier(0.3, 0, 0.5, 1) !important;
#       user-select: none !important;
#       -webkit-user-select: none !important;
#       touch-action: manipulation !important;
#       vertical-align: middle !important;
#       white-space: nowrap !important;
#       word-wrap: break-word !important;
#       background: unset !important;
#     }
#
#     div.dt-buttons > .dt-button:hover {
#       background-color: #F3F4F6 !important;
#       text-decoration: none !important;
#       transition-duration: 0.1s !important;
#     }
#
#     div.dt-buttons > .dt-button:disabled {
#       background-color: #FAFBFC !important;
#       border-color: rgba(27, 31, 35, 0.15) !important;
#       color: #959DA5 !important;
#       cursor: default !important;
#     }
#
#     div.dt-buttons > .dt-button:active {
#       background-color: #EDEFF2 !important;
#       box-shadow: rgba(225, 228, 232, 0.2) 0 1px 0 inset !important;
#       transition: none 0s !important;
#     }
#
#     div.dt-buttons > .dt-button:focus {
#       outline: 1px transparent !important;
#     }
#
#     div.dt-buttons > .dt-button:before {
#       display: none !important;
#     }
#
#     div.dt-buttons > .dt-button:-webkit-details-marker {
#       display: none !important;
#     }
#     </style>
# <!--| quarto-html-table-processing: none -->
# <table id="itables_b7091af2_3544_4e31_8c15_cde1bbfd9a11"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.1 from the <code>init_notebook_mode</code> cell...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <script type="module">
#     (async () => {
#         async function init() {
#             const { ITable, jQuery: $ } = await window._itables_2_5_1;
#
#             document.querySelectorAll("#itables_b7091af2_3544_4e31_8c15_cde1bbfd9a11:not(.dataTable)").forEach(table => {
#                 if (!(table instanceof HTMLTableElement))
#                     return;
#
#                 let dt_args = {"buttons": ["copyHtml5", "csvHtml5"], "layout": {"topStart": "buttons", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging", "top2": "searchPanes"}, "searchPanes": {"layout": "columns-3", "cascadePanes": true, "columns": [1, 4]}, "keys": true, "escape": false, "index": false, "lengthMenu": [5, 10, 25], "order": [], "text_in_header_can_be_selected": true, "columnDefs": [{"targets": "_all", "className": "dt-rigth"}, {"targets": [0, 1], "width": "60px", "className": "dt-right"}], "classes": ["display", "compact", "stripe"], "style": {"font-size": "11px", "white-space": "normal", "div.dt-buttons button {font-size": "10px !important", "padding": "4px 6px"}, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th></th>\n      <th>UF</th>\n      <th>ID_OEMA</th>\n      <th>Poluente</th>\n      <th>Status</th>\n      <th>Categoria</th>\n      <th>Funcionamento</th>\n      <th>Eleva\u00e7\u00e3o</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_ACL_01_promotoria\", \"MP25\", \"Ativa\", \"-\", \"Autom\\u00e1tica\", 210], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_ABR_01_promotoria\", \"MP25\", \"Ativa\", \"-\", \"Autom\\u00e1tica\", 244], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_ABR_02_SEMSA\", \"MP25\", \"Inativa\", \"-\", \"Autom\\u00e1tica\", 243], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_BRL_01_promotoria\", \"MP25\", \"Ativa\", \"-\", \"Autom\\u00e1tica\", 194], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_BRL_02_radiofm90.3\", \"MP25\", \"Inativa\", \"-\", \"Autom\\u00e1tica\", 191], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_BJR_01_promotoria\", \"MP25\", \"Ativa\", \"-\", \"Autom\\u00e1tica\", 212], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_CPX_01_qpm\", \"MP25\", \"Inativa\", \"-\", \"Autom\\u00e1tica\", 213], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_CZS_01_promotoria\", \"MP25\", \"Ativa\", \"-\", \"Autom\\u00e1tica\", 183], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_CZS_02_ciosp\", \"MP25\", \"Ativa\", \"-\", \"Autom\\u00e1tica\", 214], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"UFACFloresta\", \"MP25\", \"Ativa\", \"-\", \"Autom\\u00e1tica\", 218], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_EPL_01_camara\", \"MP25\", \"Ativa\", \"-\", \"Autom\\u00e1tica\", 235], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_EPL_02_escola.joao.pedro\", \"MP25\", \"Ativa\", \"-\", \"Autom\\u00e1tica\", 223], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_FIJ_01_promotoria\", \"MP25\", \"Ativa\", \"-\", \"Autom\\u00e1tica\", 160], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_JRD_01_prefeitura\", \"MP25\", \"Ativa\", \"-\", \"Autom\\u00e1tica\", 267], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_MUR_01_Promotoria\", \"MP25\", \"Ativa\", \"-\", \"Autom\\u00e1tica\", 165], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_MTH_01_semec\", \"MP25\", \"Inativa\", \"-\", \"Autom\\u00e1tica\", 222], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_MNL_01_promotoria\", \"MP25\", \"Ativa\", \"-\", \"Autom\\u00e1tica\", 198], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\", \"MPAC_PLC_01_promotoria\", \"MP25\", \"Ativa\", \"-\", \"Autom\\u00e1tica\", 136], [\"<img src= \\\"../_static/bandeiras/AC.png\\\" width=\\\"30\\\">\", \"AC\ ...
