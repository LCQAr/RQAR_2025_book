# %% [markdown]
# #### 3.4. Operação e manutenção das estações e controle de qualidade
#
# TEXTO SOBRE OPERAÇÃO, MANUTENÇÃO E CONTROLE DE QUALIDADE

# %% [markdown]
# **Lista por estação no apêndice**

# %%
import scripts.flagTables as flagtab
columnsSelector = ["","UF","ID_OEMA", "Status","Poluente",'Categoria','Funcionamento','Calibração']
aqmData = flagtab.flagTable(columnsSelector)
searchPaneColumns=[2]
flagtab.tabela_iterativa(aqmData,searchPaneColumns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 3
#       1 import scripts.flagTables as flagtab
#       2 columnsSelector = ["","UF","ID_OEMA", "Status","Poluente",'Categoria','Funcionamento','Calibração','Marca','Modelo' ]
# ----> 3 aqmData = flagtab.flagTable(columnsSelector)
#       4 searchPaneColumns=[2]
#       5 flagtab.tabela_iterativa(aqmData,searchPaneColumns)
#
# File ~/Notebooks/.venv/lib/python3.13/site-packages/scripts/flagTables.py:731, in flagTable(columnsSelector)
#     728 aqmDataGrouped = columns_renamer(aqmDataGrouped)
#     730 # Seleciona as colunas para uso
# --> 731 aqmDataGrouped = aqmDataGrouped[columnsSelector]
#     733 return aqmDataGrouped
#
# File ~/Notebooks/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111     if is_iterator(key):
#    4112         key = list(key)
# ...

# %% [markdown]
# #### 3.4.1. Frequência de manutenção e calibração

# %% [markdown]
# **Figura com manutenção adequada e inadequada**
#
# **Tabela por estado**

# %% [markdown]
# #### 3.4.2. Metodologia de tratamento dos dados e controle de qualidade

# %% [markdown]
# **Figura com controle e sem controle**
#
# **Tabela por estado**

# %%
import os
import pandas as pd
rootPath = os.path.dirname(os.getcwd())
    
# Lendo o csv
aqmData = pd.read_csv(rootPath+'/data/Monitoramento_QAr_BR.csv')

# %%
aqmData
# Out:
#       UF                   CIDADE     CD_MUN       ID_OEMA ID_MMA  \
# 0     AM    Presidente Figueiredo  1303536.0  SEMA_DCAM_49    NaN
# 1     AM    Presidente Figueiredo  1303536.0  SEMA_DCAM_49    NaN
# 2     AM         Rio Preto da Eva  1303569.0  SEMA_DCAM_50    NaN
# 3     AM         Rio Preto da Eva  1303569.0  SEMA_DCAM_51    NaN
# 4     AM  São Sebastião do Uatumã  1303957.0  SEMA_DCAM_55    NaN
# ...   ..                      ...        ...           ...    ...
# 2191  MA                 São Luís  2111300.0   Vila Sarney    NaN
# 2192  MA                 São Luís  2111300.0   Vila Sarney    NaN
# 2193  MA                 São Luís  2111300.0   Vila Sarney    NaN
# 2194  MA                 São Luís  2111300.0   Vila Sarney    NaN
# 2195  MA                 São Luís  2111300.0   Vila Sarney    NaN
#
#      ID_MMA_COMPLETO  PROPRIETARIO  PROP_ENTIDADE  OPERADOR  OP_ENTIDADE  ...  \
# 0                NaN           NaN            NaN       NaN          NaN  ...
# ...
